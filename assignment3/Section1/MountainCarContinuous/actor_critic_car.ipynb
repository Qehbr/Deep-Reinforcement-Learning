# %%
import os
import time
import gymnasium
import numpy as np
import optuna
import torch
from assignment3.Section1.MountainCarContinuous.actor_critic_car_loop import actor_critic

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def objective(trial):
    # Define hyperparameter space
    env_name = "MountainCarContinuous-v0"
    log_dir = "runs/actor_critic"

    hidden_sizes = trial.suggest_categorical('hidden_sizes', [
        (64,), (128,), (256,), (128, 64), (256, 128)
    ])
    alpha = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    episodes = 1000
    gamma = trial.suggest_float('gamma', 0.8, 0.99)
    entropy_coeff = trial.suggest_float('entropy_coeff', 1e-5, 1e-1, log=True)
    start_noise_std = trial.suggest_float('start_noise_std', 0.01, 0.3)
    end_noise_std = trial.suggest_float('end_noise_std', 0.01, 0.3)
    noise_decay = trial.suggest_float('noise_decay', 0.99, 0.9999)

    # Log the hyperparameters being used in this trial
    print(f"Trial {trial.number}:")
    print(f"  hidden_sizes: {hidden_sizes}")
    print(f"  alpha: {alpha}")
    print(f"  gamma: {gamma}")
    print(f"  entropy_coeff: {entropy_coeff}")
    print(f"  start_noise_std: {start_noise_std}")
    print(f"  end_noise_std: {end_noise_std}")
    print(f"  noise_decay: {noise_decay}")

    # Train the agent with these hyperparameters
    policy_net, value_net, rewards, train_time, avg_reward_50 = actor_critic(
        env_name=env_name,
        input_dim=6,  # MountainCarContinuous state dimension
        output_dim=3,  # Single action dimension
        hidden_sizes_theta=hidden_sizes,
        hidden_sizes_w=hidden_sizes,
        alpha_theta=alpha,
        alpha_w=alpha,
        episodes=episodes,
        gamma=gamma,
        entropy_coeff=entropy_coeff,  # Entropy bonus coefficient
        start_noise_std=start_noise_std,  # Initial noise
        end_noise_std=end_noise_std,  # Final noise
        noise_decay=noise_decay,  # Decay rate for noise
        log_dir=f"{log_dir}/{env_name}_g{gamma}_at{alpha}"
    )

    # Log the result of this trial
    print(f"  Average Reward: {avg_reward_50}")
    print(f"  Training Time: {train_time:.2f} seconds\n")

    return avg_reward_50

# %%
# Create a study object and specify the direction of optimization
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())

# Optimize the objective function over a number of trials
study.optimize(objective, n_trials=1000, timeout=60 * 60 * 20)  # e.g., 100 trials or 1 hour

# Print the best hyperparameters
print("Best Hyperparameters:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
print(f"Best Average Reward: {study.best_value}")
# Out:
# [I 2025-01-02 21:43:18,867] A new study created in memory with name: no-name-64039150-2dc9-4912-b259-018a3a8915cb
# Trial 0:
#   hidden_sizes: (128,)
#   alpha: 0.0024352069422591835
#   gamma: 0.9532889056602523
#   entropy_coeff: 3.558978004690944e-05
#   start_noise_std: 0.1571416650213371
#   end_noise_std: 0.058061693879282984
#   noise_decay: 0.9983021693682942
# Episode 1: Reward=-48.78, Avg(100)=-48.78, Avg(50)=-48.78, Noise STD=0.1571
# Episode 2: Reward=-91.30, Avg(100)=-70.04, Avg(50)=-70.04, Noise STD=0.1569
# Episode 3: Reward=-92.05, Avg(100)=-77.38, Avg(50)=-77.38, Noise STD=0.1566
# Episode 4: Reward=-92.68, Avg(100)=-81.20, Avg(50)=-81.20, Noise STD=0.1563
# Episode 5: Reward=-93.70, Avg(100)=-83.70, Avg(50)=-83.70, Noise STD=0.1561
# Episode 6: Reward=23.33, Avg(100)=-65.86, Avg(50)=-65.86, Noise STD=0.1558
# Episode 7: Reward=-91.04, Avg(100)=-69.46, Avg(50)=-69.46, Noise STD=0.1555
# Episode 8: Reward=11.03, Avg(100)=-59.40, Avg(50)=-59.40, Noise STD=0.1553
# Episode 9: Reward=-92.14, Avg(100)=-63.04, Avg(50)=-63.04, Noise STD=0.1550
# Episode 10: Reward=-93.62, Avg(100)=-66.09, Avg(50)=-66.09, Noise STD=0.1548
# Episode 11: Reward=68.26, Avg(100)=-53.88, Avg(50)=-53.88, Noise STD=0.1545
# Episode 12: Reward=-93.74, Avg(100)=-57.20, Avg(50)=-57.20, Noise STD=0.1542
# Episode 13: Reward=41.12, Avg(100)=-49.64, Avg(50)=-49.64, Noise STD=0.1540
# Episode 14: Reward=-94.50, Avg(100)=-52.84, Avg(50)=-52.84, Noise STD=0.1537
# Episode 15: Reward=27.67, Avg(100)=-47.48, Avg(50)=-47.48, Noise STD=0.1534
# Episode 16: Reward=-94.89, Avg(100)=-50.44, Avg(50)=-50.44, Noise STD=0.1532
# Episode 17: Reward=-94.40, Avg(100)=-53.03, Avg(50)=-53.03, Noise STD=0.1529
# Episode 18: Reward=-92.81, Avg(100)=-55.24, Avg(50)=-55.24, Noise STD=0.1527
# Episode 19: Reward=-93.44, Avg(100)=-57.25, Avg(50)=-57.25, Noise STD=0.1524
# Episode 20: Reward=-95.34, Avg(100)=-59.15, Avg(50)=-59.15, Noise STD=0.1521
# Episode 21: Reward=44.99, Avg(100)=-54.19, Avg(50)=-54.19, Noise STD=0.1519
# Episode 22: Reward=-93.61, Avg(100)=-55.98, Avg(50)=-55.98, Noise STD=0.1516
# Episode 23: Reward=-92.02, Avg(100)=-57.55, Avg(50)=-57.55, Noise STD=0.1514
# Episode 24: Reward=-91.28, Avg(100)=-58.96, Avg(50)=-58.96, Noise STD=0.1511
# Episode 25: Reward=-94.11, Avg(100)=-60.36, Avg(50)=-60.36, Noise STD=0.1509
# Episode 26: Reward=-91.96, Avg(100)=-61.58, Avg(50)=-61.58, Noise STD=0.1506
# Episode 27: Reward=50.64, Avg(100)=-57.42, Avg(50)=-57.42, Noise STD=0.1504
# Episode 28: Reward=-92.43, Avg(100)=-58.67, Avg(50)=-58.67, Noise STD=0.1501
# Episode 29: Reward=-92.86, Avg(100)=-59.85, Avg(50)=-59.85, Noise STD=0.1498
# Episode 30: Reward=-92.48, Avg(100)=-60.94, Avg(50)=-60.94, Noise STD=0.1496
# Episode 31: Reward=-92.67, Avg(100)=-61.96, Avg(50)=-61.96, Noise STD=0.1493
# Episode 32: Reward=-93.46, Avg(100)=-62.95, Avg(50)=-62.95, Noise STD=0.1491
# Episode 33: Reward=-93.85, Avg(100)=-63.88, Avg(50)=-63.88, Noise STD=0.1488
# Episode 34: Reward=-93.01, Avg(100)=-64.74, Avg(50)=-64.74, Noise STD=0.1486
# Episode 35: Reward=-92.65, Avg(100)=-65.54, Avg(50)=-65.54, Noise STD=0.1483
# Episode 36: Reward=-91.80, Avg(100)=-66.27, Avg(50)=-66.27, Noise STD=0.1481
# Episode 37: Reward=-92.82, Avg(100)=-66.98, Avg(50)=-66.98, Noise STD=0.1478
# Episode 38: Reward=-92.57, Avg(100)=-67.66, Avg(50)=-67.66, Noise STD=0.1476
# Episode 39: Reward=-92.13, Avg(100)=-68.28, Avg(50)=-68.28, Noise STD=0.1473
# Episode 40: Reward=-92.96, Avg(100)=-68.90, Avg(50)=-68.90, Noise STD=0.1471
# Episode 41: Reward=-92.30, Avg(100)=-69.47, Avg(50)=-69.47, Noise STD=0.1468
# Episode 42: Reward=-93.29, Avg(100)=-70.04, Avg(50)=-70.04, Noise STD=0.1466
# Episode 43: Reward=8.50, Avg(100)=-68.21, Avg(50)=-68.21, Noise STD=0.1463
# Episode 44: Reward=47.12, Avg(100)=-65.59, Avg(50)=-65.59, Noise STD=0.1461
# Episode 45: Reward=-94.93, Avg(100)=-66.24, Avg(50)=-66.24, Noise STD=0.1458
# Episode 46: Reward=-94.85, Avg(100)=-66.87, Avg(50)=-66.87, Noise STD=0.1456
# Episode 47: Reward=45.93, Avg(100)=-64.47, Avg(50)=-64.47, Noise STD=0.1453
# Episode 48: Reward=20.31, Avg(100)=-62.70, Avg(50)=-62.70, Noise STD=0.1451
# Episode 49: Reward=-97.06, Avg(100)=-63.40, Avg(50)=-63.40, Noise STD=0.1448
# Episode 50: Reward=27.61, Avg(100)=-61.58, Avg(50)=-61.58, Noise STD=0.1446
# Episode 51: Reward=-96.94, Avg(100)=-62.27, Avg(50)=-62.54, Noise STD=0.1443
# Episode 52: Reward=-98.22, Avg(100)=-62.97, Avg(50)=-62.68, Noise STD=0.1441
# Episode 53: Reward=-98.64, Avg(100)=-63.64, Avg(50)=-62.81, Noise STD=0.1439
# Episode 54: Reward=-99.00, Avg(100)=-64.29, Avg(50)=-62.94, Noise STD=0.1436
# Episode 55: Reward=-99.65, Avg(100)=-64.94, Avg(50)=-63.06, Noise STD=0.1434
# Episode 56: Reward=-99.90, Avg(100)=-65.56, Avg(50)=-65.52, Noise STD=0.1431
# Episode 57: Reward=-99.81, Avg(100)=-66.16, Avg(50)=-65.70, Noise STD=0.1429
# Episode 58: Reward=-99.90, Avg(100)=-66.74, Avg(50)=-67.92, Noise STD=0.1426
# Episode 59: Reward=-99.90, Avg(100)=-67.30, Avg(50)=-68.07, Noise STD=0.1424
# Episode 60: Reward=-99.90, Avg(100)=-67.85, Avg(50)=-68.20, Noise STD=0.1422
# Episode 61: Reward=-99.90, Avg(100)=-68.37, Avg(50)=-71.56, Noise STD=0.1419
# Episode 62: Reward=-99.90, Avg(100)=-68.88, Avg(50)=-71.69, Noise STD=0.1417
# Episode 63: Reward=-99.50, Avg(100)=-69.37, Avg(50)=-74.50, Noise STD=0.1414
# Episode 64: Reward=-99.63, Avg(100)=-69.84, Avg(50)=-74.60, Noise STD=0.1412
# Episode 65: Reward=-99.55, Avg(100)=-70.30, Avg(50)=-77.14, Noise STD=0.1409
# Episode 66: Reward=-98.66, Avg(100)=-70.73, Avg(50)=-77.22, Noise STD=0.1407
# Episode 67: Reward=-98.05, Avg(100)=-71.14, Avg(50)=-77.29, Noise STD=0.1405
# Episode 68: Reward=-99.23, Avg(100)=-71.55, Avg(50)=-77.42, Noise STD=0.1402
# Episode 69: Reward=16.67, Avg(100)=-70.27, Avg(50)=-75.22, Noise STD=0.1400
# Episode 70: Reward=-97.03, Avg(100)=-70.65, Avg(50)=-75.25, Noise STD=0.1398
# Episode 71: Reward=35.28, Avg(100)=-69.16, Avg(50)=-75.45, Noise STD=0.1395
# Episode 72: Reward=-98.22, Avg(100)=-69.56, Avg(50)=-75.54, Noise STD=0.1393
# Episode 73: Reward=-94.53, Avg(100)=-69.91, Avg(50)=-75.59, Noise STD=0.1390
# Episode 74: Reward=55.37, Avg(100)=-68.21, Avg(50)=-72.66, Noise STD=0.1388
# Episode 75: Reward=15.17, Avg(100)=-67.10, Avg(50)=-70.47, Noise STD=0.1386
# Episode 76: Reward=-98.18, Avg(100)=-67.51, Avg(50)=-70.60, Noise STD=0.1383
# Episode 77: Reward=-97.67, Avg(100)=-67.90, Avg(50)=-73.56, Noise STD=0.1381
# Episode 78: Reward=42.09, Avg(100)=-66.49, Avg(50)=-70.87, Noise STD=0.1379
# Episode 79: Reward=-92.34, Avg(100)=-66.82, Avg(50)=-70.86, Noise STD=0.1376
# Episode 80: Reward=-95.96, Avg(100)=-67.18, Avg(50)=-70.93, Noise STD=0.1374
# Episode 81: Reward=-93.11, Avg(100)=-67.50, Avg(50)=-70.94, Noise STD=0.1372
# Episode 82: Reward=-93.48, Avg(100)=-67.82, Avg(50)=-70.94, Noise STD=0.1369
# Episode 83: Reward=-96.90, Avg(100)=-68.17, Avg(50)=-71.00, Noise STD=0.1367
# Episode 84: Reward=47.63, Avg(100)=-66.79, Avg(50)=-68.19, Noise STD=0.1365
# Episode 85: Reward=-96.14, Avg(100)=-67.14, Avg(50)=-68.26, Noise STD=0.1362
# Episode 86: Reward=-98.63, Avg(100)=-67.50, Avg(50)=-68.39, Noise STD=0.1360
# Episode 87: Reward=-97.97, Avg(100)=-67.85, Avg(50)=-68.50, Noise STD=0.1358
# Episode 88: Reward=-97.25, Avg(100)=-68.19, Avg(50)=-68.59, Noise STD=0.1355
# Episode 89: Reward=-97.96, Avg(100)=-68.52, Avg(50)=-68.71, Noise STD=0.1353
# Episode 90: Reward=-96.77, Avg(100)=-68.84, Avg(50)=-68.78, Noise STD=0.1351
# Episode 91: Reward=24.17, Avg(100)=-67.81, Avg(50)=-66.45, Noise STD=0.1349
# Episode 92: Reward=28.70, Avg(100)=-66.76, Avg(50)=-64.01, Noise STD=0.1346
# Episode 93: Reward=-98.11, Avg(100)=-67.10, Avg(50)=-66.15, Noise STD=0.1344
# Episode 94: Reward=45.13, Avg(100)=-65.91, Avg(50)=-66.19, Noise STD=0.1342
# Episode 95: Reward=-98.65, Avg(100)=-66.25, Avg(50)=-66.26, Noise STD=0.1339
# Episode 96: Reward=-99.59, Avg(100)=-66.60, Avg(50)=-66.36, Noise STD=0.1337
# Episode 97: Reward=-98.99, Avg(100)=-66.93, Avg(50)=-69.25, Noise STD=0.1335
# Episode 98: Reward=-97.35, Avg(100)=-67.24, Avg(50)=-71.61, Noise STD=0.1333
# Episode 99: Reward=-99.07, Avg(100)=-67.57, Avg(50)=-71.65, Noise STD=0.1330
# Episode 100: Reward=-99.81, Avg(100)=-67.89, Avg(50)=-74.20, Noise STD=0.1328
# Episode 101: Reward=-99.90, Avg(100)=-68.40, Avg(50)=-74.26, Noise STD=0.1326
# Episode 102: Reward=-99.82, Avg(100)=-68.48, Avg(50)=-74.29, Noise STD=0.1324
# Episode 103: Reward=-99.82, Avg(100)=-68.56, Avg(50)=-74.31, Noise STD=0.1321
# Episode 104: Reward=-99.90, Avg(100)=-68.63, Avg(50)=-74.33, Noise STD=0.1319
# Episode 105: Reward=-99.90, Avg(100)=-68.70, Avg(50)=-74.33, Noise STD=0.1317
# Episode 106: Reward=-99.04, Avg(100)=-69.92, Avg(50)=-74.32, Noise STD=0.1315
# Episode 107: Reward=17.35, Avg(100)=-68.84, Avg(50)=-71.97, Noise STD=0.1312
# Episode 108: Reward=-98.18, Avg(100)=-69.93, Avg(50)=-71.94, Noise STD=0.1310
# Episode 109: Reward=-97.84, Avg(100)=-69.99, Avg(50)=-71.90, Noise STD=0.1308
# Episode 110: Reward=-96.48, Avg(100)=-70.01, Avg(50)=-71.83, Noise STD=0.1306
# Episode 111: Reward=-97.82, Avg(100)=-71.67, Avg(50)=-71.79, Noise STD=0.1304
# Episode 112: Reward=-95.55, Avg(100)=-71.69, Avg(50)=-71.70, Noise STD=0.1301
# Episode 113: Reward=43.80, Avg(100)=-71.67, Avg(50)=-68.83, Noise STD=0.1299
# Episode 114: Reward=14.54, Avg(100)=-70.58, Avg(50)=-66.55, Noise STD=0.1297
# Episode 115: Reward=-94.98, Avg(100)=-71.80, Avg(50)=-66.46, Noise STD=0.1295
# Episode 116: Reward=-94.17, Avg(100)=-71.79, Avg(50)=-66.37, Noise STD=0.1292
# Episode 117: Reward=-98.00, Avg(100)=-71.83, Avg(50)=-66.37, Noise STD=0.1290
# Episode 118: Reward=-99.42, Avg(100)=-71.90, Avg(50)=-66.37, Noise STD=0.1288
# Episode 119: Reward=37.86, Avg(100)=-70.58, Avg(50)=-65.95, Noise STD=0.1286
# Episode 120: Reward=-98.82, Avg(100)=-70.62, Avg(50)=-65.98, Noise STD=0.1284
# Episode 121: Reward=-98.59, Avg(100)=-72.05, Avg(50)=-68.66, Noise STD=0.1282
# Episode 122: Reward=-98.24, Avg(100)=-72.10, Avg(50)=-68.66, Noise STD=0.1279
# Episode 123: Reward=22.35, Avg(100)=-70.96, Avg(50)=-66.32, Noise STD=0.1277
# Episode 124: Reward=27.76, Avg(100)=-69.77, Avg(50)=-66.88, Noise STD=0.1275
# Episode 125: Reward=-96.96, Avg(100)=-69.80, Avg(50)=-69.12, Noise STD=0.1273
# Episode 126: Reward=5.06, Avg(100)=-68.83, Avg(50)=-67.05, Noise STD=0.1271
# Episode 127: Reward=-98.91, Avg(100)=-70.32, Avg(50)=-67.08, Noise STD=0.1269
# Episode 128: Reward=-99.04, Avg(100)=-70.39, Avg(50)=-69.90, Noise STD=0.1266
# Episode 129: Reward=-97.55, Avg(100)=-70.43, Avg(50)=-70.01, Noise STD=0.1264
# Episode 130: Reward=35.89, Avg(100)=-69.15, Avg(50)=-67.37, Noise STD=0.1262
# Episode 131: Reward=-97.23, Avg(100)=-69.20, Avg(50)=-67.45, Noise STD=0.1260
# Episode 132: Reward=-95.46, Avg(100)=-69.22, Avg(50)=-67.49, Noise STD=0.1258
# Episode 133: Reward=-96.93, Avg(100)=-69.25, Avg(50)=-67.49, Noise STD=0.1256
# Episode 134: Reward=38.99, Avg(100)=-67.93, Avg(50)=-67.66, Noise STD=0.1254
# Episode 135: Reward=-97.70, Avg(100)=-67.98, Avg(50)=-67.70, Noise STD=0.1251
# Episode 136: Reward=-98.40, Avg(100)=-68.04, Avg(50)=-67.69, Noise STD=0.1249
# Episode 137: Reward=65.23, Avg(100)=-66.46, Avg(50)=-64.43, Noise STD=0.1247
# Episode 138: Reward=35.53, Avg(100)=-65.18, Avg(50)=-61.77, Noise STD=0.1245
# Episode 139: Reward=-98.95, Avg(100)=-65.25, Avg(50)=-61.79, Noise STD=0.1243
# Episode 140: Reward=8.88, Avg(100)=-64.23, Avg(50)=-59.68, Noise STD=0.1241
# Episode 141: Reward=-98.87, Avg(100)=-64.30, Avg(50)=-62.14, Noise STD=0.1239
# Episode 142: Reward=-98.76, Avg(100)=-64.35, Avg(50)=-64.69, Noise STD=0.1237
# Episode 143: Reward=-99.64, Avg(100)=-65.43, Avg(50)=-64.72, Noise STD=0.1235
# Episode 144: Reward=-99.20, Avg(100)=-66.90, Avg(50)=-67.61, Noise STD=0.1232
# Episode 145: Reward=-99.88, Avg(100)=-66.95, Avg(50)=-67.63, Noise STD=0.1230
# Episode 146: Reward=-99.90, Avg(100)=-67.00, Avg(50)=-67.64, Noise STD=0.1228
# Episode 147: Reward=-99.90, Avg(100)=-68.45, Avg(50)=-67.65, Noise STD=0.1226
# Episode 148: Reward=-99.90, Avg(100)=-69.66, Avg(50)=-67.71, Noise STD=0.1224
# Episode 149: Reward=-99.90, Avg(100)=-69.68, Avg(50)=-67.72, Noise STD=0.1222
# Episode 150: Reward=-99.90, Avg(100)=-70.96, Avg(50)=-67.72, Noise STD=0.1220
# Episode 151: Reward=-99.90, Avg(100)=-70.99, Avg(50)=-67.72, Noise STD=0.1218
# Episode 152: Reward=-99.90, Avg(100)=-71.01, Avg(50)=-67.73, Noise STD=0.1216
# Episode 153: Reward=-99.90, Avg(100)=-71.02, Avg(50)=-67.73, Noise STD=0.1214
# Episode 154: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-67.73, Noise STD=0.1212
# Episode 155: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-67.73, Noise STD=0.1210
# Episode 156: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-67.74, Noise STD=0.1208
# Episode 157: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-70.09, Noise STD=0.1205
# Episode 158: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-70.12, Noise STD=0.1203
# Episode 159: Reward=-99.72, Avg(100)=-71.03, Avg(50)=-70.16, Noise STD=0.1201
# Episode 160: Reward=-99.90, Avg(100)=-71.03, Avg(50)=-70.23, Noise STD=0.1199
# Episode 161: Reward=-99.55, Avg(100)=-71.03, Avg(50)=-70.26, Noise STD=0.1197
# Episode 162: Reward=-99.04, Avg(100)=-71.02, Avg(50)=-70.33, Noise STD=0.1195
# Episode 163: Reward=-99.90, Avg(100)=-71.02, Avg(50)=-73.21, Noise STD=0.1193
# Episode 164: Reward=-99.75, Avg(100)=-71.02, Avg(50)=-75.49, Noise STD=0.1191
# Episode 165: Reward=-99.82, Avg(100)=-71.03, Avg(50)=-75.59, Noise STD=0.1189
# Episode 166: Reward=-99.71, Avg(100)=-71.04, Avg(50)=-75.70, Noise STD=0.1187
# Episode 167: Reward=-99.81, Avg(100)=-71.05, Avg(50)=-75.74, Noise STD=0.1185
# Episode 168: Reward=-99.90, Avg(100)=-71.06, Avg(50)=-75.75, Noise STD=0.1183
# Episode 169: Reward=-99.74, Avg(100)=-72.22, Avg(50)=-78.50, Noise STD=0.1181
# Episode 170: Reward=-99.90, Avg(100)=-72.25, Avg(50)=-78.52, Noise STD=0.1179
# Episode 171: Reward=-99.90, Avg(100)=-73.60, Avg(50)=-78.55, Noise STD=0.1177
# Episode 172: Reward=-99.90, Avg(100)=-73.62, Avg(50)=-78.58, Noise STD=0.1175
# Episode 173: Reward=-99.90, Avg(100)=-73.68, Avg(50)=-81.03, Noise STD=0.1173
# Episode 174: Reward=-99.90, Avg(100)=-75.23, Avg(50)=-83.58, Noise STD=0.1171
# Episode 175: Reward=-99.90, Avg(100)=-76.38, Avg(50)=-83.64, Noise STD=0.1169
# Episode 176: Reward=-99.90, Avg(100)=-76.40, Avg(50)=-85.74, Noise STD=0.1167
# Episode 177: Reward=-99.90, Avg(100)=-76.42, Avg(50)=-85.76, Noise STD=0.1165
# Episode 178: Reward=-99.90, Avg(100)=-77.84, Avg(50)=-85.77, Noise STD=0.1163
# Episode 179: Reward=-99.90, Avg(100)=-77.91, Avg(50)=-85.82, Noise STD=0.1161
# Episode 180: Reward=-99.90, Avg(100)=-77.95, Avg(50)=-88.54, Noise STD=0.1159
# Episode 181: Reward=-99.90, Avg(100)=-78.02, Avg(50)=-88.59, Noise STD=0.1157
# Episode 182: Reward=-99.90, Avg(100)=-78.08, Avg(50)=-88.68, Noise STD=0.1155
# Episode 183: Reward=-99.90, Avg(100)=-78.11, Avg(50)=-88.74, Noise STD=0.1153
# Episode 184: Reward=-99.90, Avg(100)=-79.59, Avg(50)=-91.52, Noise STD=0.1151
# Episode 185: Reward=-99.90, Avg(100)=-79.63, Avg(50)=-91.56, Noise STD=0.1149
# Episode 186: Reward=-99.90, Avg(100)=-79.64, Avg(50)=-91.59, Noise STD=0.1148
# Episode 187: Reward=-99.90, Avg(100)=-79.66, Avg(50)=-94.89, Noise STD=0.1146
# Episode 188: Reward=-99.90, Avg(100)=-79.69, Avg(50)=-97.60, Noise STD=0.1144
# Episode 189: Reward=-99.90, Avg(100)=-79.71, Avg(50)=-97.62, Noise STD=0.1142
# Episode 190: Reward=-99.90, Avg(100)=-79.74, Avg(50)=-99.80, Noise STD=0.1140
# Episode 191: Reward=-99.90, Avg(100)=-80.98, Avg(50)=-99.82, Noise STD=0.1138
# Episode 192: Reward=-99.90, Avg(100)=-82.26, Avg(50)=-99.84, Noise STD=0.1136
# Episode 193: Reward=-99.90, Avg(100)=-82.28, Avg(50)=-99.84, Noise STD=0.1134
# Episode 194: Reward=-99.90, Avg(100)=-83.73, Avg(50)=-99.86, Noise STD=0.1132
# Episode 195: Reward=-99.90, Avg(100)=-83.74, Avg(50)=-99.86, Noise STD=0.1130
# Episode 196: Reward=-99.90, Avg(100)=-83.75, Avg(50)=-99.86, Noise STD=0.1128
# Episode 197: Reward=-99.90, Avg(100)=-83.76, Avg(50)=-99.86, Noise STD=0.1126
# Episode 198: Reward=-99.90, Avg(100)=-83.78, Avg(50)=-99.86, Noise STD=0.1124
# Episode 199: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1122
# Episode 200: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1121
# Episode 201: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1119
# Episode 202: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1117
# Episode 203: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1115
# Episode 204: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1113
# Episode 205: Reward=-99.90, Avg(100)=-83.79, Avg(50)=-99.86, Noise STD=0.1111
# Episode 206: Reward=-99.90, Avg(100)=-83.80, Avg(50)=-99.86, Noise STD=0.1109
# Episode 207: Reward=-99.90, Avg(100)=-84.97, Avg(50)=-99.86, Noise STD=0.1107
# Episode 208: Reward=-99.90, Avg(100)=-84.99, Avg(50)=-99.86, Noise STD=0.1105
# Episode 209: Reward=-99.90, Avg(100)=-85.01, Avg(50)=-99.86, Noise STD=0.1104
# Episode 210: Reward=-99.90, Avg(100)=-85.05, Avg(50)=-99.86, Noise STD=0.1102
# Episode 211: Reward=-99.90, Avg(100)=-85.07, Avg(50)=-99.87, Noise STD=0.1100
# Episode 212: Reward=-99.90, Avg(100)=-85.11, Avg(50)=-99.89, Noise STD=0.1098
# Episode 213: Reward=-99.90, Avg(100)=-86.55, Avg(50)=-99.89, Noise STD=0.1096
# Episode 214: Reward=-99.90, Avg(100)=-87.69, Avg(50)=-99.89, Noise STD=0.1094
# Episode 215: Reward=-99.90, Avg(100)=-87.74, Avg(50)=-99.89, Noise STD=0.1092
# Episode 216: Reward=-99.90, Avg(100)=-87.80, Avg(50)=-99.90, Noise STD=0.1090
# Episode 217: Reward=-99.90, Avg(100)=-87.82, Avg(50)=-99.90, Noise STD=0.1089
# Episode 218: Reward=-99.90, Avg(100)=-87.82, Avg(50)=-99.90, Noise STD=0.1087
# Episode 219: Reward=-99.90, Avg(100)=-89.20, Avg(50)=-99.90, Noise STD=0.1085
# Episode 220: Reward=-99.90, Avg(100)=-89.21, Avg(50)=-99.90, Noise STD=0.1083
# Episode 221: Reward=-99.90, Avg(100)=-89.22, Avg(50)=-99.90, Noise STD=0.1081
# Episode 222: Reward=-99.90, Avg(100)=-89.24, Avg(50)=-99.90, Noise STD=0.1079
# Episode 223: Reward=-99.90, Avg(100)=-90.46, Avg(50)=-99.90, Noise STD=0.1078
# Episode 224: Reward=-99.90, Avg(100)=-91.74, Avg(50)=-99.90, Noise STD=0.1076
# Episode 225: Reward=-99.90, Avg(100)=-91.77, Avg(50)=-99.90, Noise STD=0.1074
# Episode 226: Reward=-99.90, Avg(100)=-92.82, Avg(50)=-99.90, Noise STD=0.1072
# Episode 227: Reward=-99.90, Avg(100)=-92.83, Avg(50)=-99.90, Noise STD=0.1070
# Episode 228: Reward=-99.90, Avg(100)=-92.84, Avg(50)=-99.90, Noise STD=0.1068
# Episode 229: Reward=-99.90, Avg(100)=-92.86, Avg(50)=-99.90, Noise STD=0.1067
# Episode 230: Reward=-99.90, Avg(100)=-94.22, Avg(50)=-99.90, Noise STD=0.1065
# Episode 231: Reward=-99.90, Avg(100)=-94.24, Avg(50)=-99.90, Noise STD=0.1063
# Episode 232: Reward=-99.90, Avg(100)=-94.29, Avg(50)=-99.90, Noise STD=0.1061
# Episode 233: Reward=-99.90, Avg(100)=-94.32, Avg(50)=-99.90, Noise STD=0.1059
# Episode 234: Reward=-99.90, Avg(100)=-95.71, Avg(50)=-99.90, Noise STD=0.1058
# Episode 235: Reward=-99.90, Avg(100)=-95.73, Avg(50)=-99.90, Noise STD=0.1056
# Episode 236: Reward=-99.90, Avg(100)=-95.74, Avg(50)=-99.90, Noise STD=0.1054
# Episode 237: Reward=-99.90, Avg(100)=-97.40, Avg(50)=-99.90, Noise STD=0.1052
# Episode 238: Reward=-99.90, Avg(100)=-98.75, Avg(50)=-99.90, Noise STD=0.1050
# Episode 239: Reward=-99.90, Avg(100)=-98.76, Avg(50)=-99.90, Noise STD=0.1049
# Episode 240: Reward=-99.90, Avg(100)=-99.85, Avg(50)=-99.90, Noise STD=0.1047
# Episode 241: Reward=-99.90, Avg(100)=-99.86, Avg(50)=-99.90, Noise STD=0.1045
# Episode 242: Reward=-99.90, Avg(100)=-99.87, Avg(50)=-99.90, Noise STD=0.1043
# Episode 243: Reward=-99.90, Avg(100)=-99.87, Avg(50)=-99.90, Noise STD=0.1042
# Episode 244: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1040
# Episode 245: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1038
# Episode 246: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1036
# Episode 247: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1035
# Episode 248: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1033
# Episode 249: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1031
# Episode 250: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1029
# Episode 251: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1028
# Episode 252: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1026
# Episode 253: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1024
# Episode 254: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1022
# Episode 255: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1021
# Episode 256: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1019
# Episode 257: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1017
# Episode 258: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1015
# Episode 259: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1014
# Episode 260: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1012
# Episode 261: Reward=-99.90, Avg(100)=-99.88, Avg(50)=-99.90, Noise STD=0.1010
# Episode 262: Reward=-99.90, Avg(100)=-99.89, Avg(50)=-99.90, Noise STD=0.1009
# Episode 263: Reward=-99.90, Avg(100)=-99.89, Avg(50)=-99.90, Noise STD=0.1007
# Episode 264: Reward=-99.90, Avg(100)=-99.89, Avg(50)=-99.90, Noise STD=0.1005
# Episode 265: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.1003
# Episode 266: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.1002
# Episode 267: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.1000
# Episode 268: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0998
# Episode 269: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0997
# Episode 270: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0995
# Episode 271: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0993
# Episode 272: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0992
# Episode 273: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0990
# Episode 274: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0988
# Episode 275: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0986
# Episode 276: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0985
# Episode 277: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0983
# Episode 278: Reward=-99.80, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0981
# Episode 279: Reward=-98.82, Avg(100)=-99.89, Avg(50)=-99.88, Noise STD=0.0980
# Episode 280: Reward=-99.52, Avg(100)=-99.88, Avg(50)=-99.87, Noise STD=0.0978
# Episode 281: Reward=68.85, Avg(100)=-98.20, Avg(50)=-96.49, Noise STD=0.0976
# Episode 282: Reward=54.78, Avg(100)=-96.65, Avg(50)=-93.40, Noise STD=0.0975
# Episode 283: Reward=-98.93, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0973
# Episode 284: Reward=-99.78, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0971
# Episode 285: Reward=-99.90, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0970
# Episode 286: Reward=-99.90, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0968
# Episode 287: Reward=-99.81, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0967
# Episode 288: Reward=-99.90, Avg(100)=-96.64, Avg(50)=-93.38, Noise STD=0.0965
# Episode 289: Reward=-99.36, Avg(100)=-96.63, Avg(50)=-93.37, Noise STD=0.0963
# Episode 290: Reward=-98.43, Avg(100)=-96.62, Avg(50)=-93.34, Noise STD=0.0962
# Episode 291: Reward=-97.45, Avg(100)=-96.59, Avg(50)=-93.29, Noise STD=0.0960
# Episode 292: Reward=12.66, Avg(100)=-95.47, Avg(50)=-91.04, Noise STD=0.0958
# Episode 293: Reward=-95.53, Avg(100)=-95.42, Avg(50)=-90.95, Noise STD=0.0957
# Episode 294: Reward=8.13, Avg(100)=-94.34, Avg(50)=-88.79, Noise STD=0.0955
# Episode 295: Reward=40.54, Avg(100)=-92.94, Avg(50)=-85.98, Noise STD=0.0954
# Episode 296: Reward=-99.50, Avg(100)=-92.94, Avg(50)=-85.97, Noise STD=0.0952
# Episode 297: Reward=-99.55, Avg(100)=-92.93, Avg(50)=-85.96, Noise STD=0.0950
# Episode 298: Reward=-99.02, Avg(100)=-92.92, Avg(50)=-85.95, Noise STD=0.0949
# Episode 299: Reward=65.95, Avg(100)=-91.26, Avg(50)=-82.63, Noise STD=0.0947
# Episode 300: Reward=12.25, Avg(100)=-90.14, Avg(50)=-80.39, Noise STD=0.0945
# Episode 301: Reward=-98.90, Avg(100)=-90.13, Avg(50)=-80.37, Noise STD=0.0944
# Episode 302: Reward=-99.53, Avg(100)=-90.13, Avg(50)=-80.36, Noise STD=0.0942
# Episode 303: Reward=-99.69, Avg(100)=-90.13, Avg(50)=-80.35, Noise STD=0.0941
# Episode 304: Reward=24.31, Avg(100)=-88.89, Avg(50)=-77.87, Noise STD=0.0939
# Episode 305: Reward=-98.80, Avg(100)=-88.87, Avg(50)=-77.85, Noise STD=0.0937
# Episode 306: Reward=-99.66, Avg(100)=-88.87, Avg(50)=-77.84, Noise STD=0.0936
# Episode 307: Reward=-98.76, Avg(100)=-88.86, Avg(50)=-77.82, Noise STD=0.0934
# Episode 308: Reward=-95.30, Avg(100)=-88.81, Avg(50)=-77.73, Noise STD=0.0933
# Episode 309: Reward=31.21, Avg(100)=-87.50, Avg(50)=-75.11, Noise STD=0.0931
# Episode 310: Reward=-98.55, Avg(100)=-87.49, Avg(50)=-75.08, Noise STD=0.0930
# Episode 311: Reward=-99.05, Avg(100)=-87.48, Avg(50)=-75.06, Noise STD=0.0928
# Episode 312: Reward=-98.89, Avg(100)=-87.47, Avg(50)=-75.04, Noise STD=0.0926
# Episode 313: Reward=-99.82, Avg(100)=-87.47, Avg(50)=-75.04, Noise STD=0.0925
# Episode 314: Reward=-99.90, Avg(100)=-87.47, Avg(50)=-75.04, Noise STD=0.0923
# Episode 315: Reward=-99.87, Avg(100)=-87.47, Avg(50)=-75.04, Noise STD=0.0922
# Episode 316: Reward=-99.90, Avg(100)=-87.47, Avg(50)=-75.04, Noise STD=0.0920
# Episode 317: Reward=-99.54, Avg(100)=-87.47, Avg(50)=-75.03, Noise STD=0.0919
# Episode 318: Reward=-99.76, Avg(100)=-87.46, Avg(50)=-75.03, Noise STD=0.0917
# Episode 319: Reward=-98.72, Avg(100)=-87.45, Avg(50)=-75.01, Noise STD=0.0915
# Episode 320: Reward=22.39, Avg(100)=-86.23, Avg(50)=-72.56, Noise STD=0.0914
# Episode 321: Reward=-98.67, Avg(100)=-86.22, Avg(50)=-72.54, Noise STD=0.0912
# Episode 322: Reward=37.51, Avg(100)=-84.84, Avg(50)=-69.79, Noise STD=0.0911
# Episode 323: Reward=56.93, Avg(100)=-83.28, Avg(50)=-66.65, Noise STD=0.0909
# Episode 324: Reward=51.01, Avg(100)=-81.77, Avg(50)=-63.63, Noise STD=0.0908
# Episode 325: Reward=-96.07, Avg(100)=-81.73, Avg(50)=-63.56, Noise STD=0.0906
# Episode 326: Reward=-96.66, Avg(100)=-81.70, Avg(50)=-63.49, Noise STD=0.0905
# Episode 327: Reward=21.00, Avg(100)=-80.49, Avg(50)=-61.07, Noise STD=0.0903
# Episode 328: Reward=50.45, Avg(100)=-78.98, Avg(50)=-58.07, Noise STD=0.0902
# Episode 329: Reward=41.52, Avg(100)=-77.57, Avg(50)=-55.26, Noise STD=0.0900
# Episode 330: Reward=-96.32, Avg(100)=-77.53, Avg(50)=-55.20, Noise STD=0.0898
# Episode 331: Reward=-97.81, Avg(100)=-77.51, Avg(50)=-58.53, Noise STD=0.0897
# Episode 332: Reward=52.36, Avg(100)=-75.99, Avg(50)=-58.58, Noise STD=0.0895
# Episode 333: Reward=47.79, Avg(100)=-74.51, Avg(50)=-55.65, Noise STD=0.0894
# Episode 334: Reward=22.19, Avg(100)=-73.29, Avg(50)=-53.21, Noise STD=0.0892
# Episode 335: Reward=-96.10, Avg(100)=-73.25, Avg(50)=-53.13, Noise STD=0.0891
# Episode 336: Reward=15.40, Avg(100)=-72.10, Avg(50)=-50.82, Noise STD=0.0889
# Episode 337: Reward=61.18, Avg(100)=-70.49, Avg(50)=-47.60, Noise STD=0.0888
# Episode 338: Reward=38.22, Avg(100)=-69.11, Avg(50)=-44.84, Noise STD=0.0886
# Episode 339: Reward=13.54, Avg(100)=-67.97, Avg(50)=-42.58, Noise STD=0.0885
# Episode 340: Reward=-93.73, Avg(100)=-67.91, Avg(50)=-42.49, Noise STD=0.0883
# Episode 341: Reward=-95.32, Avg(100)=-67.87, Avg(50)=-42.45, Noise STD=0.0882
# Episode 342: Reward=-97.46, Avg(100)=-67.84, Avg(50)=-44.65, Noise STD=0.0880
# Episode 343: Reward=52.96, Avg(100)=-66.31, Avg(50)=-41.68, Noise STD=0.0879
# Episode 344: Reward=81.22, Avg(100)=-64.50, Avg(50)=-40.22, Noise STD=0.0877
# Episode 345: Reward=20.19, Avg(100)=-63.30, Avg(50)=-40.62, Noise STD=0.0876
# Episode 346: Reward=26.93, Avg(100)=-62.03, Avg(50)=-38.10, Noise STD=0.0874
# Episode 347: Reward=49.11, Avg(100)=-60.54, Avg(50)=-35.12, Noise STD=0.0873
# Episode 348: Reward=42.62, Avg(100)=-59.12, Avg(50)=-32.29, Noise STD=0.0871
# Episode 349: Reward=24.85, Avg(100)=-57.87, Avg(50)=-33.11, Noise STD=0.0870
# Episode 350: Reward=-98.63, Avg(100)=-57.86, Avg(50)=-35.33, Noise STD=0.0868
# Episode 351: Reward=-99.28, Avg(100)=-57.85, Avg(50)=-35.34, Noise STD=0.0867
# Episode 352: Reward=-99.80, Avg(100)=-57.85, Avg(50)=-35.34, Noise STD=0.0865
# Episode 353: Reward=-99.54, Avg(100)=-57.85, Avg(50)=-35.34, Noise STD=0.0864
# Episode 354: Reward=-99.56, Avg(100)=-57.84, Avg(50)=-37.82, Noise STD=0.0863
# Episode 355: Reward=13.91, Avg(100)=-56.71, Avg(50)=-35.56, Noise STD=0.0861
# Episode 356: Reward=-99.81, Avg(100)=-56.70, Avg(50)=-35.57, Noise STD=0.0860
# Episode 357: Reward=30.25, Avg(100)=-55.40, Avg(50)=-32.99, Noise STD=0.0858
# Episode 358: Reward=-99.68, Avg(100)=-55.40, Avg(50)=-33.07, Noise STD=0.0857
# Episode 359: Reward=-98.91, Avg(100)=-55.39, Avg(50)=-35.68, Noise STD=0.0855
# Episode 360: Reward=-99.01, Avg(100)=-55.38, Avg(50)=-35.69, Noise STD=0.0854
# Episode 361: Reward=-98.73, Avg(100)=-55.37, Avg(50)=-35.68, Noise STD=0.0852
# Episode 362: Reward=-99.20, Avg(100)=-55.36, Avg(50)=-35.69, Noise STD=0.0851
# Episode 363: Reward=-96.44, Avg(100)=-55.33, Avg(50)=-35.62, Noise STD=0.0849
# Episode 364: Reward=-93.66, Avg(100)=-55.27, Avg(50)=-35.49, Noise STD=0.0848
# Episode 365: Reward=-93.73, Avg(100)=-55.20, Avg(50)=-35.37, Noise STD=0.0847
# Episode 366: Reward=-96.91, Avg(100)=-55.18, Avg(50)=-35.31, Noise STD=0.0845
# Episode 367: Reward=-99.17, Avg(100)=-55.17, Avg(50)=-35.30, Noise STD=0.0844
# Episode 368: Reward=-95.03, Avg(100)=-55.12, Avg(50)=-35.21, Noise STD=0.0842
# Episode 369: Reward=-94.18, Avg(100)=-55.06, Avg(50)=-35.12, Noise STD=0.0841
# Episode 370: Reward=-95.24, Avg(100)=-55.02, Avg(50)=-37.47, Noise STD=0.0839
# Episode 371: Reward=-95.58, Avg(100)=-54.97, Avg(50)=-37.41, Noise STD=0.0838
# Episode 372: Reward=-95.52, Avg(100)=-54.93, Avg(50)=-40.07, Noise STD=0.0837
# Episode 373: Reward=-96.69, Avg(100)=-54.90, Avg(50)=-43.14, Noise STD=0.0835
# Episode 374: Reward=-92.57, Avg(100)=-54.82, Avg(50)=-46.01, Noise STD=0.0834
# Episode 375: Reward=58.89, Avg(100)=-53.23, Avg(50)=-42.91, Noise STD=0.0832
# Episode 376: Reward=19.81, Avg(100)=-52.04, Avg(50)=-40.58, Noise STD=0.0831
# Episode 377: Reward=-99.79, Avg(100)=-52.04, Avg(50)=-43.00, Noise STD=0.0829
# Episode 378: Reward=-99.13, Avg(100)=-52.03, Avg(50)=-45.99, Noise STD=0.0828
# Episode 379: Reward=-99.50, Avg(100)=-52.04, Avg(50)=-48.81, Noise STD=0.0827
# Episode 380: Reward=-99.87, Avg(100)=-52.04, Avg(50)=-48.88, Noise STD=0.0825
# Episode 381: Reward=-99.90, Avg(100)=-53.73, Avg(50)=-48.92, Noise STD=0.0824
# Episode 382: Reward=-99.90, Avg(100)=-55.27, Avg(50)=-51.97, Noise STD=0.0822
# Episode 383: Reward=-99.78, Avg(100)=-55.28, Avg(50)=-54.92, Noise STD=0.0821
# Episode 384: Reward=-99.83, Avg(100)=-55.28, Avg(50)=-57.36, Noise STD=0.0820
# Episode 385: Reward=-99.70, Avg(100)=-55.28, Avg(50)=-57.43, Noise STD=0.0818
# Episode 386: Reward=-99.65, Avg(100)=-55.28, Avg(50)=-59.74, Noise STD=0.0817
# Episode 387: Reward=66.79, Avg(100)=-53.61, Avg(50)=-59.62, Noise STD=0.0816
# Episode 388: Reward=-99.76, Avg(100)=-53.61, Avg(50)=-62.38, Noise STD=0.0814
# Episode 389: Reward=-99.90, Avg(100)=-53.62, Avg(50)=-64.65, Noise STD=0.0813
# Episode 390: Reward=-99.90, Avg(100)=-53.63, Avg(50)=-64.77, Noise STD=0.0811
# Episode 391: Reward=-99.90, Avg(100)=-53.66, Avg(50)=-64.87, Noise STD=0.0810
# Episode 392: Reward=-99.80, Avg(100)=-54.78, Avg(50)=-64.91, Noise STD=0.0809
# Episode 393: Reward=-99.85, Avg(100)=-54.82, Avg(50)=-67.97, Noise STD=0.0807
# Episode 394: Reward=-99.90, Avg(100)=-55.90, Avg(50)=-71.59, Noise STD=0.0806
# Episode 395: Reward=-99.78, Avg(100)=-57.31, Avg(50)=-73.99, Noise STD=0.0804
# Episode 396: Reward=-99.90, Avg(100)=-57.31, Avg(50)=-76.53, Noise STD=0.0803
# Episode 397: Reward=-99.90, Avg(100)=-57.32, Avg(50)=-79.51, Noise STD=0.0802
# Episode 398: Reward=-99.90, Avg(100)=-57.32, Avg(50)=-82.36, Noise STD=0.0800
# Episode 399: Reward=-99.90, Avg(100)=-58.98, Avg(50)=-84.85, Noise STD=0.0799
# Episode 400: Reward=-99.90, Avg(100)=-60.10, Avg(50)=-84.88, Noise STD=0.0798
# Episode 401: Reward=-99.90, Avg(100)=-60.11, Avg(50)=-84.89, Noise STD=0.0796
# Episode 402: Reward=-99.90, Avg(100)=-60.12, Avg(50)=-84.89, Noise STD=0.0795
# Episode 403: Reward=-99.90, Avg(100)=-60.12, Avg(50)=-84.90, Noise STD=0.0794
# Episode 404: Reward=-99.90, Avg(100)=-61.36, Avg(50)=-84.91, Noise STD=0.0792
# Episode 405: Reward=-99.90, Avg(100)=-61.37, Avg(50)=-87.18, Noise STD=0.0791
# Episode 406: Reward=-99.90, Avg(100)=-61.38, Avg(50)=-87.19, Noise STD=0.0790
# Episode 407: Reward=-99.90, Avg(100)=-61.39, Avg(50)=-89.79, Noise STD=0.0788
# Episode 408: Reward=-99.90, Avg(100)=-61.43, Avg(50)=-89.79, Noise STD=0.0787
# Episode 409: Reward=-99.90, Avg(100)=-62.74, Avg(50)=-89.81, Noise STD=0.0786
# Episode 410: Reward=-99.90, Avg(100)=-62.76, Avg(50)=-89.83, Noise STD=0.0784
# Episode 411: Reward=-99.90, Avg(100)=-62.77, Avg(50)=-89.85, Noise STD=0.0783
# Episode 412: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-89.87, Noise STD=0.0782
# Episode 413: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-89.94, Noise STD=0.0780
# Episode 414: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-90.06, Noise STD=0.0779
# Episode 415: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-90.18, Noise STD=0.0778
# Episode 416: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-90.24, Noise STD=0.0776
# Episode 417: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-90.26, Noise STD=0.0775
# Episode 418: Reward=-99.90, Avg(100)=-62.78, Avg(50)=-90.36, Noise STD=0.0774
# Episode 419: Reward=-99.90, Avg(100)=-62.79, Avg(50)=-90.47, Noise STD=0.0772
# Episode 420: Reward=-99.90, Avg(100)=-64.02, Avg(50)=-90.56, Noise STD=0.0771
# Episode 421: Reward=-99.90, Avg(100)=-64.03, Avg(50)=-90.65, Noise STD=0.0770
# Episode 422: Reward=-99.90, Avg(100)=-65.40, Avg(50)=-90.74, Noise STD=0.0768
# Episode 423: Reward=-99.90, Avg(100)=-66.97, Avg(50)=-90.80, Noise STD=0.0767
# Episode 424: Reward=-99.90, Avg(100)=-68.48, Avg(50)=-90.95, Noise STD=0.0766
# Episode 425: Reward=-99.90, Avg(100)=-68.52, Avg(50)=-94.12, Noise STD=0.0765
# Episode 426: Reward=-99.90, Avg(100)=-68.55, Avg(50)=-96.52, Noise STD=0.0763
# Episode 427: Reward=-99.90, Avg(100)=-69.76, Avg(50)=-96.52, Noise STD=0.0762
# Episode 428: Reward=-99.90, Avg(100)=-71.26, Avg(50)=-96.54, Noise STD=0.0761
# Episode 429: Reward=-99.90, Avg(100)=-72.68, Avg(50)=-96.54, Noise STD=0.0759
# Episode 430: Reward=-99.90, Avg(100)=-72.71, Avg(50)=-96.55, Noise STD=0.0758
# Episode 431: Reward=-99.90, Avg(100)=-72.74, Avg(50)=-96.55, Noise STD=0.0757
# Episode 432: Reward=-99.90, Avg(100)=-74.26, Avg(50)=-96.55, Noise STD=0.0755
# Episode 433: Reward=-99.90, Avg(100)=-75.73, Avg(50)=-96.55, Noise STD=0.0754
# Episode 434: Reward=-99.90, Avg(100)=-76.96, Avg(50)=-96.55, Noise STD=0.0753
# Episode 435: Reward=-99.90, Avg(100)=-76.99, Avg(50)=-96.55, Noise STD=0.0752
# Episode 436: Reward=-99.90, Avg(100)=-78.15, Avg(50)=-96.56, Noise STD=0.0750
# Episode 437: Reward=-99.90, Avg(100)=-79.76, Avg(50)=-99.89, Noise STD=0.0749
# Episode 438: Reward=-99.90, Avg(100)=-81.14, Avg(50)=-99.89, Noise STD=0.0748
# Episode 439: Reward=-99.90, Avg(100)=-82.27, Avg(50)=-99.89, Noise STD=0.0747
# Episode 440: Reward=-99.90, Avg(100)=-82.33, Avg(50)=-99.89, Noise STD=0.0745
# Episode 441: Reward=-99.90, Avg(100)=-82.38, Avg(50)=-99.89, Noise STD=0.0744
# Episode 442: Reward=-99.90, Avg(100)=-82.40, Avg(50)=-99.90, Noise STD=0.0743
# Episode 443: Reward=-99.90, Avg(100)=-83.93, Avg(50)=-99.90, Noise STD=0.0741
# Episode 444: Reward=-99.90, Avg(100)=-85.74, Avg(50)=-99.90, Noise STD=0.0740
# Episode 445: Reward=-99.90, Avg(100)=-86.95, Avg(50)=-99.90, Noise STD=0.0739
# Episode 446: Reward=-99.90, Avg(100)=-88.21, Avg(50)=-99.90, Noise STD=0.0738
# Episode 447: Reward=-99.90, Avg(100)=-89.70, Avg(50)=-99.90, Noise STD=0.0736
# Episode 448: Reward=-99.90, Avg(100)=-91.13, Avg(50)=-99.90, Noise STD=0.0735
# Episode 449: Reward=-99.90, Avg(100)=-92.38, Avg(50)=-99.90, Noise STD=0.0734
# Episode 450: Reward=-99.90, Avg(100)=-92.39, Avg(50)=-99.90, Noise STD=0.0733
# Episode 451: Reward=-99.90, Avg(100)=-92.40, Avg(50)=-99.90, Noise STD=0.0731
# Episode 452: Reward=-99.90, Avg(100)=-92.40, Avg(50)=-99.90, Noise STD=0.0730
# Episode 453: Reward=-99.90, Avg(100)=-92.40, Avg(50)=-99.90, Noise STD=0.0729
# Episode 454: Reward=-99.90, Avg(100)=-92.40, Avg(50)=-99.90, Noise STD=0.0728
# Episode 455: Reward=-99.90, Avg(100)=-93.54, Avg(50)=-99.90, Noise STD=0.0727
# Episode 456: Reward=-99.90, Avg(100)=-93.54, Avg(50)=-99.90, Noise STD=0.0725
# Episode 457: Reward=-99.90, Avg(100)=-94.84, Avg(50)=-99.90, Noise STD=0.0724
# Episode 458: Reward=-99.90, Avg(100)=-94.85, Avg(50)=-99.90, Noise STD=0.0723
# Episode 459: Reward=-99.90, Avg(100)=-94.86, Avg(50)=-99.90, Noise STD=0.0722
# Episode 460: Reward=-99.90, Avg(100)=-94.87, Avg(50)=-99.90, Noise STD=0.0720
# Episode 461: Reward=-99.90, Avg(100)=-94.88, Avg(50)=-99.90, Noise STD=0.0719
# Episode 462: Reward=-99.90, Avg(100)=-94.88, Avg(50)=-99.90, Noise STD=0.0718
# Episode 463: Reward=-99.90, Avg(100)=-94.92, Avg(50)=-99.90, Noise STD=0.0717
# Episode 464: Reward=-99.90, Avg(100)=-94.98, Avg(50)=-99.90, Noise STD=0.0715
# Episode 465: Reward=-99.90, Avg(100)=-95.04, Avg(50)=-99.90, Noise STD=0.0714
# Episode 466: Reward=-99.90, Avg(100)=-95.07, Avg(50)=-99.90, Noise STD=0.0713
# Episode 467: Reward=-99.90, Avg(100)=-95.08, Avg(50)=-99.90, Noise STD=0.0712
# Episode 468: Reward=-99.90, Avg(100)=-95.13, Avg(50)=-99.90, Noise STD=0.0711
# Episode 469: Reward=-99.90, Avg(100)=-95.19, Avg(50)=-99.90, Noise STD=0.0709
# Episode 470: Reward=-99.90, Avg(100)=-95.23, Avg(50)=-99.90, Noise STD=0.0708
# Episode 471: Reward=-99.90, Avg(100)=-95.28, Avg(50)=-99.90, Noise STD=0.0707
# Episode 472: Reward=-99.90, Avg(100)=-95.32, Avg(50)=-99.90, Noise STD=0.0706
# Episode 473: Reward=-99.90, Avg(100)=-95.35, Avg(50)=-99.90, Noise STD=0.0705
# Episode 474: Reward=-99.90, Avg(100)=-95.42, Avg(50)=-99.90, Noise STD=0.0703
# Episode 475: Reward=-99.90, Avg(100)=-97.01, Avg(50)=-99.90, Noise STD=0.0702
# Episode 476: Reward=-99.90, Avg(100)=-98.21, Avg(50)=-99.90, Noise STD=0.0701
# Episode 477: Reward=-99.90, Avg(100)=-98.21, Avg(50)=-99.90, Noise STD=0.0700
# Episode 478: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0699
# Episode 479: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0697
# Episode 480: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0696
# Episode 481: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0695
# Episode 482: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0694
# Episode 483: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0693
# Episode 484: Reward=-99.90, Avg(100)=-98.22, Avg(50)=-99.90, Noise STD=0.0692
# Episode 485: Reward=-99.90, Avg(100)=-98.23, Avg(50)=-99.90, Noise STD=0.0690
# Episode 486: Reward=-99.90, Avg(100)=-98.23, Avg(50)=-99.90, Noise STD=0.0689
# Episode 487: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0688
# Episode 488: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0687
# Episode 489: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0686
# Episode 490: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0685
# Episode 491: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0683
# Episode 492: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0682
# Episode 493: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0681
# Episode 494: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0680
# Episode 495: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0679
# Episode 496: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0678
# Episode 497: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0676
# Episode 498: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0675
# Episode 499: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0674
# Episode 500: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0673
# Episode 501: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0672
# Episode 502: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0671
# Episode 503: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0670
# Episode 504: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0668
# Episode 505: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0667
# Episode 506: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0666
# Episode 507: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0665
# Episode 508: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0664
# Episode 509: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0663
# Episode 510: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0662
# Episode 511: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0661
# Episode 512: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0659
# Episode 513: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0658
# Episode 514: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0657
# Episode 515: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0656
# Episode 516: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0655
# Episode 517: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0654
# Episode 518: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0653
# Episode 519: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0652
# Episode 520: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0651
# Episode 521: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0649
# Episode 522: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0648
# Episode 523: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0647
# Episode 524: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0646
# Episode 525: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0645
# Episode 526: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0644
# Episode 527: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0643
# Episode 528: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0642
# Episode 529: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0641
# Episode 530: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0640
# Episode 531: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0638
# Episode 532: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0637
# Episode 533: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0636
# Episode 534: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0635
# Episode 535: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0634
# Episode 536: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0633
# Episode 537: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0632
# Episode 538: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0631
# Episode 539: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0630
# Episode 540: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0629
# Episode 541: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0628
# Episode 542: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0627
# Episode 543: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0626
# Episode 544: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0625
# Episode 545: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0623
# Episode 546: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0622
# Episode 547: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0621
# Episode 548: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0620
# Episode 549: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0619
# Episode 550: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0618
# Episode 551: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0617
# Episode 552: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0616
# Episode 553: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0615
# Episode 554: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0614
# Episode 555: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0613
# Episode 556: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0612
# Episode 557: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0611
# Episode 558: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0610
# Episode 559: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0609
# Episode 560: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0608
# Episode 561: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0607
# Episode 562: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0606
# Episode 563: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0605
# Episode 564: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0604
# Episode 565: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0603
# Episode 566: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0602
# Episode 567: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0601
# Episode 568: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0600
# Episode 569: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0599
# Episode 570: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0598
# Episode 571: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0597
# Episode 572: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0596
# Episode 573: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0595
# Episode 574: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0594
# Episode 575: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0592
# Episode 576: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0591
# Episode 577: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0590
# Episode 578: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0589
# Episode 579: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0588
# Episode 580: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0587
# Episode 581: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0586
# Episode 582: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0585
# Episode 583: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0584
# Episode 584: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0584
# Episode 585: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0583
# Episode 586: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0582
# Episode 587: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 588: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 589: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 590: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 591: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 592: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 593: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 594: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 595: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 596: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 597: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 598: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 599: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 600: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 601: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 602: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 603: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 604: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 605: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 606: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 607: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 608: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 609: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 610: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 611: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 612: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# Episode 613: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.0581
# ...
# Episode 805: Reward=-93.45, Avg(100)=-79.86, Avg(50)=-76.85, Noise STD=0.1317
# Episode 806: Reward=-92.55, Avg(100)=-79.86, Avg(50)=-76.82, Noise STD=0.1317
# Episode 807: Reward=-91.35, Avg(100)=-79.85, Avg(50)=-76.83, Noise STD=0.1317
# Episode 808: Reward=-93.37, Avg(100)=-79.87, Avg(50)=-76.82, Noise STD=0.1317
# Episode 809: Reward=-92.34, Avg(100)=-79.87, Avg(50)=-76.81, Noise STD=0.1317
# Episode 810: Reward=-93.66, Avg(100)=-79.88, Avg(50)=-76.83, Noise STD=0.1317
# Episode 811: Reward=-92.13, Avg(100)=-79.88, Avg(50)=-76.80, Noise STD=0.1317
# Episode 812: Reward=-91.99, Avg(100)=-79.87, Avg(50)=-78.81, Noise STD=0.1317
# Episode 813: Reward=-92.86, Avg(100)=-79.88, Avg(50)=-78.80, Noise STD=0.1317
# Episode 814: Reward=-93.60, Avg(100)=-79.89, Avg(50)=-78.81, Noise STD=0.1317
# Episode 815: Reward=-93.71, Avg(100)=-79.91, Avg(50)=-78.84, Noise STD=0.1317
# Episode 816: Reward=-92.38, Avg(100)=-79.89, Avg(50)=-78.84, Noise STD=0.1317
# Episode 817: Reward=-92.23, Avg(100)=-79.89, Avg(50)=-78.82, Noise STD=0.1317
# Episode 818: Reward=-93.64, Avg(100)=-81.06, Avg(50)=-78.84, Noise STD=0.1317
# Episode 819: Reward=-93.96, Avg(100)=-81.07, Avg(50)=-78.86, Noise STD=0.1317
# Episode 820: Reward=-92.86, Avg(100)=-81.06, Avg(50)=-78.86, Noise STD=0.1317
# Episode 821: Reward=-93.05, Avg(100)=-81.06, Avg(50)=-78.88, Noise STD=0.1317
# Episode 822: Reward=14.95, Avg(100)=-79.96, Avg(50)=-76.71, Noise STD=0.1317
# Episode 823: Reward=-92.17, Avg(100)=-79.96, Avg(50)=-78.87, Noise STD=0.1317
# Episode 824: Reward=-92.30, Avg(100)=-79.96, Avg(50)=-78.84, Noise STD=0.1317
# Episode 825: Reward=-93.00, Avg(100)=-79.95, Avg(50)=-81.00, Noise STD=0.1317
# Episode 826: Reward=-93.05, Avg(100)=-79.96, Avg(50)=-81.01, Noise STD=0.1317
# Episode 827: Reward=-91.95, Avg(100)=-79.96, Avg(50)=-80.99, Noise STD=0.1317
# Episode 828: Reward=-93.19, Avg(100)=-79.96, Avg(50)=-81.00, Noise STD=0.1317
# Episode 829: Reward=-92.10, Avg(100)=-79.95, Avg(50)=-84.22, Noise STD=0.1317
# Episode 830: Reward=-91.85, Avg(100)=-79.94, Avg(50)=-84.19, Noise STD=0.1317
# Episode 831: Reward=-92.38, Avg(100)=-79.93, Avg(50)=-84.17, Noise STD=0.1317
# Episode 832: Reward=-93.59, Avg(100)=-81.27, Avg(50)=-84.18, Noise STD=0.1317
# Episode 833: Reward=-93.99, Avg(100)=-82.57, Avg(50)=-84.21, Noise STD=0.1317
# Episode 834: Reward=-93.34, Avg(100)=-82.57, Avg(50)=-86.27, Noise STD=0.1317
# Episode 835: Reward=-92.75, Avg(100)=-82.58, Avg(50)=-86.26, Noise STD=0.1317
# Episode 836: Reward=-92.75, Avg(100)=-82.59, Avg(50)=-86.23, Noise STD=0.1317
# Episode 837: Reward=-93.18, Avg(100)=-82.59, Avg(50)=-86.22, Noise STD=0.1317
# Episode 838: Reward=-92.47, Avg(100)=-82.58, Avg(50)=-86.24, Noise STD=0.1317
# Episode 839: Reward=-92.23, Avg(100)=-82.57, Avg(50)=-86.21, Noise STD=0.1317
# Episode 840: Reward=-91.72, Avg(100)=-82.56, Avg(50)=-86.17, Noise STD=0.1317
# Episode 841: Reward=-91.59, Avg(100)=-82.55, Avg(50)=-86.13, Noise STD=0.1317
# Episode 842: Reward=-91.85, Avg(100)=-82.54, Avg(50)=-88.63, Noise STD=0.1317
# Episode 843: Reward=-92.35, Avg(100)=-83.71, Avg(50)=-88.59, Noise STD=0.1317
# Episode 844: Reward=-91.49, Avg(100)=-83.70, Avg(50)=-88.56, Noise STD=0.1317
# Episode 845: Reward=-92.62, Avg(100)=-83.70, Avg(50)=-88.53, Noise STD=0.1317
# Episode 846: Reward=-92.76, Avg(100)=-83.70, Avg(50)=-88.54, Noise STD=0.1317
# Episode 847: Reward=-91.82, Avg(100)=-83.70, Avg(50)=-88.52, Noise STD=0.1317
# Episode 848: Reward=-92.33, Avg(100)=-83.69, Avg(50)=-88.50, Noise STD=0.1317
# Episode 849: Reward=50.27, Avg(100)=-82.27, Avg(50)=-85.64, Noise STD=0.1317
# Episode 850: Reward=-92.38, Avg(100)=-82.26, Avg(50)=-85.62, Noise STD=0.1317
# Episode 851: Reward=-92.00, Avg(100)=-82.25, Avg(50)=-85.60, Noise STD=0.1317
# Episode 852: Reward=-93.19, Avg(100)=-82.25, Avg(50)=-87.63, Noise STD=0.1317
# Episode 853: Reward=-92.79, Avg(100)=-82.25, Avg(50)=-87.64, Noise STD=0.1317
# Episode 854: Reward=-92.07, Avg(100)=-82.24, Avg(50)=-87.62, Noise STD=0.1317
# Episode 855: Reward=-92.15, Avg(100)=-82.22, Avg(50)=-87.60, Noise STD=0.1317
# Episode 856: Reward=-92.61, Avg(100)=-82.21, Avg(50)=-87.60, Noise STD=0.1317
# Episode 857: Reward=-92.11, Avg(100)=-82.22, Avg(50)=-87.61, Noise STD=0.1317
# Episode 858: Reward=-90.92, Avg(100)=-82.19, Avg(50)=-87.56, Noise STD=0.1317
# Episode 859: Reward=-92.16, Avg(100)=-82.18, Avg(50)=-87.56, Noise STD=0.1317
# Episode 860: Reward=43.24, Avg(100)=-80.82, Avg(50)=-84.82, Noise STD=0.1317
# Episode 861: Reward=27.02, Avg(100)=-79.62, Avg(50)=-82.44, Noise STD=0.1317
# Episode 862: Reward=31.06, Avg(100)=-79.40, Avg(50)=-79.98, Noise STD=0.1317
# Episode 863: Reward=-93.13, Avg(100)=-79.39, Avg(50)=-79.98, Noise STD=0.1317
# Episode 864: Reward=7.77, Avg(100)=-78.39, Avg(50)=-77.96, Noise STD=0.1317
# Episode 865: Reward=54.80, Avg(100)=-76.91, Avg(50)=-74.99, Noise STD=0.1317
# Episode 866: Reward=-93.55, Avg(100)=-76.92, Avg(50)=-75.01, Noise STD=0.1317
# Episode 867: Reward=7.67, Avg(100)=-75.92, Avg(50)=-73.01, Noise STD=0.1317
# Episode 868: Reward=20.95, Avg(100)=-74.78, Avg(50)=-70.72, Noise STD=0.1317
# Episode 869: Reward=-92.56, Avg(100)=-74.77, Avg(50)=-70.69, Noise STD=0.1317
# Episode 870: Reward=-92.64, Avg(100)=-74.77, Avg(50)=-70.69, Noise STD=0.1317
# Episode 871: Reward=31.84, Avg(100)=-73.54, Avg(50)=-68.19, Noise STD=0.1317
# Episode 872: Reward=-92.61, Avg(100)=-73.53, Avg(50)=-70.34, Noise STD=0.1317
# Episode 873: Reward=-92.62, Avg(100)=-74.61, Avg(50)=-70.35, Noise STD=0.1317
# Episode 874: Reward=-93.23, Avg(100)=-74.61, Avg(50)=-70.37, Noise STD=0.1317
# Episode 875: Reward=-92.43, Avg(100)=-75.68, Avg(50)=-70.36, Noise STD=0.1317
# Episode 876: Reward=20.45, Avg(100)=-74.55, Avg(50)=-68.09, Noise STD=0.1317
# Episode 877: Reward=14.45, Avg(100)=-73.48, Avg(50)=-65.96, Noise STD=0.1317
# Episode 878: Reward=-92.37, Avg(100)=-73.47, Avg(50)=-65.94, Noise STD=0.1317
# Episode 879: Reward=53.96, Avg(100)=-73.62, Avg(50)=-63.02, Noise STD=0.1317
# Episode 880: Reward=58.19, Avg(100)=-72.11, Avg(50)=-60.02, Noise STD=0.1317
# Episode 881: Reward=15.33, Avg(100)=-71.02, Avg(50)=-57.87, Noise STD=0.1317
# Episode 882: Reward=22.03, Avg(100)=-69.87, Avg(50)=-55.55, Noise STD=0.1317
# Episode 883: Reward=-92.61, Avg(100)=-69.87, Avg(50)=-55.53, Noise STD=0.1317
# Episode 884: Reward=-93.66, Avg(100)=-70.90, Avg(50)=-55.53, Noise STD=0.1317
# Episode 885: Reward=-93.56, Avg(100)=-70.90, Avg(50)=-55.55, Noise STD=0.1317
# Episode 886: Reward=-93.60, Avg(100)=-70.90, Avg(50)=-55.57, Noise STD=0.1317
# Episode 887: Reward=-92.99, Avg(100)=-70.89, Avg(50)=-55.56, Noise STD=0.1317
# Episode 888: Reward=-91.06, Avg(100)=-70.89, Avg(50)=-55.53, Noise STD=0.1317
# Episode 889: Reward=-91.47, Avg(100)=-70.87, Avg(50)=-55.52, Noise STD=0.1317
# Episode 890: Reward=-93.59, Avg(100)=-70.86, Avg(50)=-55.56, Noise STD=0.1317
# Episode 891: Reward=-93.57, Avg(100)=-70.86, Avg(50)=-55.60, Noise STD=0.1317
# Episode 892: Reward=-92.91, Avg(100)=-72.12, Avg(50)=-55.62, Noise STD=0.1317
# Episode 893: Reward=-93.38, Avg(100)=-72.11, Avg(50)=-55.64, Noise STD=0.1317
# Episode 894: Reward=-93.01, Avg(100)=-72.11, Avg(50)=-55.67, Noise STD=0.1317
# Episode 895: Reward=32.15, Avg(100)=-70.85, Avg(50)=-53.17, Noise STD=0.1317
# Episode 896: Reward=9.44, Avg(100)=-69.83, Avg(50)=-51.13, Noise STD=0.1317
# Episode 897: Reward=30.84, Avg(100)=-68.60, Avg(50)=-48.68, Noise STD=0.1317
# Episode 898: Reward=-93.10, Avg(100)=-68.60, Avg(50)=-48.69, Noise STD=0.1317
# Episode 899: Reward=67.20, Avg(100)=-67.00, Avg(50)=-48.35, Noise STD=0.1317
# Episode 900: Reward=-92.10, Avg(100)=-66.99, Avg(50)=-48.35, Noise STD=0.1317
# Episode 901: Reward=-92.38, Avg(100)=-66.98, Avg(50)=-48.35, Noise STD=0.1317
# Episode 902: Reward=34.56, Avg(100)=-66.72, Avg(50)=-45.80, Noise STD=0.1317
# Episode 903: Reward=-92.90, Avg(100)=-66.72, Avg(50)=-45.80, Noise STD=0.1317
# Episode 904: Reward=35.41, Avg(100)=-65.44, Avg(50)=-43.25, Noise STD=0.1317
# Episode 905: Reward=-92.35, Avg(100)=-65.43, Avg(50)=-43.26, Noise STD=0.1317
# Episode 906: Reward=-92.21, Avg(100)=-65.42, Avg(50)=-43.25, Noise STD=0.1317
# Episode 907: Reward=-93.22, Avg(100)=-65.44, Avg(50)=-43.27, Noise STD=0.1317
# Episode 908: Reward=-92.95, Avg(100)=-65.44, Avg(50)=-43.31, Noise STD=0.1317
# Episode 909: Reward=-92.62, Avg(100)=-65.44, Avg(50)=-43.32, Noise STD=0.1317
# Episode 910: Reward=-91.54, Avg(100)=-65.42, Avg(50)=-46.02, Noise STD=0.1317
# Episode 911: Reward=-91.90, Avg(100)=-65.42, Avg(50)=-48.39, Noise STD=0.1317
# Episode 912: Reward=-92.27, Avg(100)=-65.42, Avg(50)=-50.86, Noise STD=0.1317
# Episode 913: Reward=-92.37, Avg(100)=-65.41, Avg(50)=-50.84, Noise STD=0.1317
# Episode 914: Reward=61.09, Avg(100)=-63.87, Avg(50)=-49.78, Noise STD=0.1317
# Episode 915: Reward=-91.80, Avg(100)=-63.85, Avg(50)=-52.71, Noise STD=0.1317
# Episode 916: Reward=-92.36, Avg(100)=-63.85, Avg(50)=-52.69, Noise STD=0.1317
# Episode 917: Reward=-92.63, Avg(100)=-63.85, Avg(50)=-54.69, Noise STD=0.1317
# Episode 918: Reward=-92.63, Avg(100)=-63.84, Avg(50)=-56.96, Noise STD=0.1317
# Episode 919: Reward=-93.52, Avg(100)=-63.84, Avg(50)=-56.98, Noise STD=0.1317
# Episode 920: Reward=33.32, Avg(100)=-62.58, Avg(50)=-54.46, Noise STD=0.1317
# Episode 921: Reward=-91.67, Avg(100)=-62.56, Avg(50)=-56.93, Noise STD=0.1317
# Episode 922: Reward=73.89, Avg(100)=-61.97, Avg(50)=-53.61, Noise STD=0.1317
# Episode 923: Reward=-93.66, Avg(100)=-61.99, Avg(50)=-53.63, Noise STD=0.1317
# Episode 924: Reward=-92.23, Avg(100)=-61.99, Avg(50)=-53.61, Noise STD=0.1317
# Episode 925: Reward=-93.80, Avg(100)=-62.00, Avg(50)=-53.63, Noise STD=0.1317
# Episode 926: Reward=-92.83, Avg(100)=-61.99, Avg(50)=-55.90, Noise STD=0.1317
# Episode 927: Reward=-93.75, Avg(100)=-62.01, Avg(50)=-58.06, Noise STD=0.1317
# Episode 928: Reward=-92.80, Avg(100)=-62.01, Avg(50)=-58.07, Noise STD=0.1317
# Episode 929: Reward=-93.63, Avg(100)=-62.02, Avg(50)=-61.02, Noise STD=0.1317
# Episode 930: Reward=-93.37, Avg(100)=-62.04, Avg(50)=-64.05, Noise STD=0.1317
# Episode 931: Reward=55.60, Avg(100)=-60.56, Avg(50)=-63.25, Noise STD=0.1317
# Episode 932: Reward=23.10, Avg(100)=-59.39, Avg(50)=-63.23, Noise STD=0.1317
# Episode 933: Reward=57.01, Avg(100)=-57.88, Avg(50)=-60.24, Noise STD=0.1317
# Episode 934: Reward=-92.10, Avg(100)=-57.87, Avg(50)=-60.20, Noise STD=0.1317
# Episode 935: Reward=28.03, Avg(100)=-56.66, Avg(50)=-57.77, Noise STD=0.1317
# Episode 936: Reward=-93.12, Avg(100)=-56.66, Avg(50)=-57.76, Noise STD=0.1317
# Episode 937: Reward=-92.63, Avg(100)=-56.66, Avg(50)=-57.76, Noise STD=0.1317
# Episode 938: Reward=10.78, Avg(100)=-55.63, Avg(50)=-55.72, Noise STD=0.1317
# Episode 939: Reward=-93.48, Avg(100)=-55.64, Avg(50)=-55.76, Noise STD=0.1317
# Episode 940: Reward=-93.18, Avg(100)=-55.65, Avg(50)=-55.75, Noise STD=0.1317
# Episode 941: Reward=-92.97, Avg(100)=-55.67, Avg(50)=-55.74, Noise STD=0.1317
# Episode 942: Reward=-92.56, Avg(100)=-55.67, Avg(50)=-55.73, Noise STD=0.1317
# Episode 943: Reward=-92.95, Avg(100)=-55.68, Avg(50)=-55.72, Noise STD=0.1317
# Episode 944: Reward=52.02, Avg(100)=-54.25, Avg(50)=-52.82, Noise STD=0.1317
# Episode 945: Reward=14.87, Avg(100)=-53.17, Avg(50)=-53.17, Noise STD=0.1317
# Episode 946: Reward=-91.90, Avg(100)=-53.16, Avg(50)=-55.19, Noise STD=0.1317
# Episode 947: Reward=54.60, Avg(100)=-51.70, Avg(50)=-54.72, Noise STD=0.1317
# Episode 948: Reward=-92.46, Avg(100)=-51.70, Avg(50)=-54.71, Noise STD=0.1317
# Episode 949: Reward=-92.48, Avg(100)=-53.13, Avg(50)=-57.90, Noise STD=0.1317
# Episode 950: Reward=37.37, Avg(100)=-51.83, Avg(50)=-55.31, Noise STD=0.1317
# Episode 951: Reward=59.72, Avg(100)=-50.31, Avg(50)=-52.27, Noise STD=0.1317
# Episode 952: Reward=-91.19, Avg(100)=-50.29, Avg(50)=-54.78, Noise STD=0.1317
# Episode 953: Reward=-94.02, Avg(100)=-50.30, Avg(50)=-54.81, Noise STD=0.1317
# Episode 954: Reward=-92.93, Avg(100)=-50.31, Avg(50)=-57.37, Noise STD=0.1317
# Episode 955: Reward=-93.23, Avg(100)=-50.32, Avg(50)=-57.39, Noise STD=0.1317
# Episode 956: Reward=-93.70, Avg(100)=-50.33, Avg(50)=-57.42, Noise STD=0.1317
# Episode 957: Reward=17.56, Avg(100)=-49.24, Avg(50)=-55.21, Noise STD=0.1317
# Episode 958: Reward=-92.06, Avg(100)=-49.25, Avg(50)=-55.19, Noise STD=0.1317
# Episode 959: Reward=-93.01, Avg(100)=-49.26, Avg(50)=-55.20, Noise STD=0.1317
# Episode 960: Reward=-91.54, Avg(100)=-50.61, Avg(50)=-55.20, Noise STD=0.1317
# Episode 961: Reward=48.14, Avg(100)=-50.39, Avg(50)=-52.39, Noise STD=0.1317
# Episode 962: Reward=-91.54, Avg(100)=-51.62, Avg(50)=-52.38, Noise STD=0.1317
# Episode 963: Reward=-91.75, Avg(100)=-51.61, Avg(50)=-52.37, Noise STD=0.1317
# Episode 964: Reward=40.38, Avg(100)=-51.28, Avg(50)=-52.78, Noise STD=0.1317
# Episode 965: Reward=-93.40, Avg(100)=-52.76, Avg(50)=-52.81, Noise STD=0.1317
# Episode 966: Reward=50.90, Avg(100)=-51.32, Avg(50)=-49.95, Noise STD=0.1317
# Episode 967: Reward=-93.83, Avg(100)=-52.33, Avg(50)=-49.97, Noise STD=0.1317
# Episode 968: Reward=30.67, Avg(100)=-52.24, Avg(50)=-47.51, Noise STD=0.1317
# Episode 969: Reward=-92.94, Avg(100)=-52.24, Avg(50)=-47.49, Noise STD=0.1317
# Episode 970: Reward=-91.80, Avg(100)=-52.23, Avg(50)=-50.00, Noise STD=0.1317
# Episode 971: Reward=17.36, Avg(100)=-52.38, Avg(50)=-47.82, Noise STD=0.1317
# Episode 972: Reward=-93.09, Avg(100)=-52.38, Avg(50)=-51.16, Noise STD=0.1317
# Episode 973: Reward=-91.56, Avg(100)=-52.37, Avg(50)=-51.11, Noise STD=0.1317
# Episode 974: Reward=16.93, Avg(100)=-51.27, Avg(50)=-48.93, Noise STD=0.1317
# Episode 975: Reward=8.52, Avg(100)=-50.26, Avg(50)=-46.88, Noise STD=0.1317
# Episode 976: Reward=-92.42, Avg(100)=-51.39, Avg(50)=-46.88, Noise STD=0.1317
# Episode 977: Reward=-92.82, Avg(100)=-52.46, Avg(50)=-46.86, Noise STD=0.1317
# Episode 978: Reward=43.95, Avg(100)=-51.10, Avg(50)=-44.12, Noise STD=0.1317
# Episode 979: Reward=-92.40, Avg(100)=-52.56, Avg(50)=-44.10, Noise STD=0.1317
# Episode 980: Reward=-94.33, Avg(100)=-54.09, Avg(50)=-44.12, Noise STD=0.1317
# Episode 981: Reward=-92.62, Avg(100)=-55.17, Avg(50)=-47.08, Noise STD=0.1317
# Episode 982: Reward=-93.13, Avg(100)=-56.32, Avg(50)=-49.41, Noise STD=0.1317
# Episode 983: Reward=-93.02, Avg(100)=-56.32, Avg(50)=-52.41, Noise STD=0.1317
# Episode 984: Reward=-93.87, Avg(100)=-56.32, Avg(50)=-52.44, Noise STD=0.1317
# Episode 985: Reward=-91.53, Avg(100)=-56.30, Avg(50)=-54.83, Noise STD=0.1317
# Episode 986: Reward=-92.29, Avg(100)=-56.29, Avg(50)=-54.82, Noise STD=0.1317
# Episode 987: Reward=-92.44, Avg(100)=-56.28, Avg(50)=-54.81, Noise STD=0.1317
# Episode 988: Reward=34.52, Avg(100)=-55.03, Avg(50)=-54.34, Noise STD=0.1317
# Episode 989: Reward=-91.97, Avg(100)=-55.03, Avg(50)=-54.31, Noise STD=0.1317
# Episode 990: Reward=-93.32, Avg(100)=-55.03, Avg(50)=-54.31, Noise STD=0.1317
# Episode 991: Reward=41.02, Avg(100)=-53.68, Avg(50)=-51.63, Noise STD=0.1317
# Episode 992: Reward=-92.26, Avg(100)=-53.68, Avg(50)=-51.62, Noise STD=0.1317
# Episode 993: Reward=-92.29, Avg(100)=-53.67, Avg(50)=-51.61, Noise STD=0.1317
# Episode 994: Reward=-93.41, Avg(100)=-53.67, Avg(50)=-54.52, Noise STD=0.1317
# Episode 995: Reward=-93.20, Avg(100)=-54.92, Avg(50)=-56.68, Noise STD=0.1317
# Episode 996: Reward=-93.53, Avg(100)=-55.95, Avg(50)=-56.71, Noise STD=0.1317
# Episode 997: Reward=-92.44, Avg(100)=-57.19, Avg(50)=-59.65, Noise STD=0.1317
# Episode 998: Reward=-92.62, Avg(100)=-57.18, Avg(50)=-59.66, Noise STD=0.1317
# Episode 999: Reward=-93.80, Avg(100)=-58.79, Avg(50)=-59.68, Noise STD=0.1317
# [I 2025-01-03 18:11:34,420] Trial 24 finished with value: 6.754542688874871 and parameters: {'hidden_sizes': (128, 64), 'alpha': 0.00013871319874410632, 'gamma': 0.9191319288558385, 'entropy_coeff': 0.0002692435286833037, 'start_noise_std': 0.18077712135304377, 'end_noise_std': 0.1316735914314744, 'noise_decay': 0.9966354684861523}. Best is trial 9 with value: 12.037644487601224.
# Episode 1000: Reward=-92.54, Avg(100)=-58.80, Avg(50)=-62.28, Noise STD=0.1317
#   Average Reward: 6.754542688874871
#   Training Time: 3046.84 seconds
#
# Best Hyperparameters:
#   hidden_sizes: (256,)
#   alpha: 0.000432860862913505
#   gamma: 0.9571389501004702
#   entropy_coeff: 0.0075942800574955
#   start_noise_std: 0.12655319079849925
#   end_noise_std: 0.2507795275354682
#   noise_decay: 0.9952850823459259
# Best Average Reward: 12.037644487601224
