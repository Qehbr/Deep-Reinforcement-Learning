# %%
import optuna
import torch
from torch import nn

from assignment3.Section1.CartPole_AcroBot.dim_alignment import max_input_dim, max_output_dim
from assignment3.Section1.CartPole_AcroBot.models import PolicyNetwork, ValueNetwork
from assignment3.Section1.CartPole_AcroBot.device import get_device
from assignment3.Section1.MountainCarContinuous.models import UnifiedPolicyNetwork
from assignment3.Section2.actor_critic_finetune import actor_critic_finetune

# %%
device = get_device()

# Define hidden sizes (reuse from CartPole if compatible)
hidden_sizes = [32, 64, 32]

# %%
def extract_hidden_layers(cartpole_model, unified_model):
    """
    Transfers the weights of the hidden layers from the CartPole model to the Unified model.
    Assumes that both models have the same architecture for hidden layers.
    """
    cartpole_layers = [module for module in cartpole_model.model]
    unified_layers = [module for module in unified_model.model]

    for cp_layer, un_layer in zip(cartpole_layers, unified_layers):
        if isinstance(cp_layer, nn.Linear) and isinstance(un_layer, nn.Linear):
            un_layer.weight.data = cp_layer.weight.data.clone()
            un_layer.bias.data = cp_layer.bias.data.clone()

    return unified_model

# %%
def objective(trial):

    # Hyperparameter search space
    alpha_theta = trial.suggest_loguniform('alpha_theta', 1e-5, 1e-2)
    alpha_w = trial.suggest_loguniform('alpha_w', 1e-5, 1e-2)
    gamma = trial.suggest_uniform('gamma', 0.90, 0.999)
    entropy_coeff = trial.suggest_uniform('entropy_coeff', 0.0, 0.1)
    start_noise_std = trial.suggest_uniform('start_noise_std', 0.05, 0.3)
    end_noise_std = trial.suggest_uniform('end_noise_std', 0.25, 0.5)
    noise_decay = trial.suggest_uniform('noise_decay', 0.90, 0.999)

    episodes = 1000  # You can also make this a hyperparameter if desired

    # Define the unique log directory for this trial
    log_dir = f"runs/cartPole-mountainCar_trial_{trial.number}"

    # Print the trial number and hyperparameters in red
    hyperparams = {
        'alpha_theta': alpha_theta,
        'alpha_w': alpha_w,
        'gamma': gamma,
        'entropy_coeff': entropy_coeff,
        'start_noise_std': start_noise_std,
        'end_noise_std': end_noise_std,
        'noise_decay': noise_decay
    }
    hyperparams_str = ', '.join([f"{key}={value:.6f}" for key, value in hyperparams.items()])
    print(f"Starting Trial {trial.number}: {hyperparams_str}")

    # Initialize networks (reuse the code from your setup)
    device = get_device()

    # Load the pre-trained CartPole model
    cartpole_policy_network = PolicyNetwork(max_input_dim, hidden_sizes, max_output_dim).to(device)
    cartpole_policy_network.load_state_dict(torch.load(
        '../Section1/CartPole_AcroBot/models/CartPole-v1/best/policy.pth',
        map_location=device
    ))
    cartpole_policy_network.eval()

    # Initialize the Unified Policy Network
    unified_policy_network = UnifiedPolicyNetwork(
        input_dim=max_input_dim,
        hidden_sizes=hidden_sizes,
        output_dim=max_output_dim
    ).to(device)

    # Transfer hidden layer weights from CartPole model
    unified_policy_network = extract_hidden_layers(cartpole_policy_network, unified_policy_network)
    unified_policy_network.train()  # Set to training mode

    # Initialize the Value Network
    value_network = ValueNetwork(
        input_dim=max_input_dim,
        hidden_sizes=[256],
    ).to(device)
    value_network.train()

    # Run the actor_critic training loop with pre-initialized networks
    policy_network_fine_tuned, value_network_fine_tuned, rewards_per_episode, train_time, best_avg_reward_50 = actor_critic_finetune(
        env_name="MountainCarContinuous-v0",
        input_dim=max_input_dim,
        output_dim=max_output_dim,
        alpha_theta=alpha_theta,
        alpha_w=alpha_w,
        episodes=episodes,
        gamma=gamma,
        entropy_coeff=entropy_coeff,
        start_noise_std=start_noise_std,
        end_noise_std=end_noise_std,
        noise_decay=noise_decay,
        log_dir=log_dir,  # Pass the unique log directory
        policy_network=unified_policy_network,  # Pass the pre-trained policy network
        value_network=value_network,  # Pass the pre-initialized value network
    )

    # Use the best average reward over the last 50 episodes as the metric
    return best_avg_reward_50

# %%
def run_optuna_study(n_trials=50):
    # Create a study object
    study = optuna.create_study(
        direction='maximize',  # We aim to maximize the average reward
        sampler=optuna.samplers.TPESampler(seed=42)  # You can set a seed for reproducibility
    )

    # Optimize the objective function
    study.optimize(objective, n_trials=n_trials, timeout=3600)  # e.g., 50 trials or 1 hour

    # Print study statistics
    print("Number of finished trials: ", len(study.trials))
    print("Best trial:")
    trial = study.best_trial

    print(f"  Value: {trial.value}")

    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")

    return study

# %%
study = run_optuna_study(n_trials=10)
# Out:
# [I 2025-01-07 11:13:45,281] A new study created in memory with name: no-name-acbfe2f0-9e75-4601-a0de-e9598cd08919
# Starting Trial 0: alpha_theta=0.000133, alpha_w=0.007114, gamma=0.972467, entropy_coeff=0.059866, start_noise_std=0.089005, end_noise_std=0.288999, noise_decay=0.905750
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_theta = trial.suggest_loguniform('alpha_theta', 1e-5, 1e-2)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_w = trial.suggest_loguniform('alpha_w', 1e-5, 1e-2)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.90, 0.999)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   entropy_coeff = trial.suggest_uniform('entropy_coeff', 0.0, 0.1)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   start_noise_std = trial.suggest_uniform('start_noise_std', 0.05, 0.3)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   end_noise_std = trial.suggest_uniform('end_noise_std', 0.25, 0.5)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   noise_decay = trial.suggest_uniform('noise_decay', 0.90, 0.999)
# C:\Users\rusanov\AppData\Local\Temp\ipykernel_32828\3089810475.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cartpole_policy_network.load_state_dict(torch.load(
# Episode 1: Reward=-80.89, Avg(100)=-80.89, Avg(50)=-80.89, Noise STD=0.2890
# Episode 2: Reward=-93.81, Avg(100)=-87.35, Avg(50)=-87.35, Noise STD=0.2890
# Episode 3: Reward=18.75, Avg(100)=-51.98, Avg(50)=-51.98, Noise STD=0.2890
# Episode 4: Reward=-92.88, Avg(100)=-62.21, Avg(50)=-62.21, Noise STD=0.2890
# Episode 5: Reward=-93.04, Avg(100)=-68.37, Avg(50)=-68.37, Noise STD=0.2890
# Episode 6: Reward=-93.28, Avg(100)=-72.52, Avg(50)=-72.52, Noise STD=0.2890
# Episode 7: Reward=-91.92, Avg(100)=-75.30, Avg(50)=-75.30, Noise STD=0.2890
# Episode 8: Reward=-92.73, Avg(100)=-77.47, Avg(50)=-77.47, Noise STD=0.2890
# Episode 9: Reward=24.65, Avg(100)=-66.13, Avg(50)=-66.13, Noise STD=0.2890
# Episode 10: Reward=-93.70, Avg(100)=-68.88, Avg(50)=-68.88, Noise STD=0.2890
# Episode 11: Reward=8.11, Avg(100)=-61.88, Avg(50)=-61.88, Noise STD=0.2890
# Episode 12: Reward=24.20, Avg(100)=-54.71, Avg(50)=-54.71, Noise STD=0.2890
# Episode 13: Reward=-91.69, Avg(100)=-57.55, Avg(50)=-57.55, Noise STD=0.2890
# Episode 14: Reward=-92.11, Avg(100)=-60.02, Avg(50)=-60.02, Noise STD=0.2890
# Episode 15: Reward=-91.01, Avg(100)=-62.09, Avg(50)=-62.09, Noise STD=0.2890
# Episode 16: Reward=-94.09, Avg(100)=-64.09, Avg(50)=-64.09, Noise STD=0.2890
# Episode 17: Reward=-94.66, Avg(100)=-65.89, Avg(50)=-65.89, Noise STD=0.2890
# Episode 18: Reward=20.41, Avg(100)=-61.09, Avg(50)=-61.09, Noise STD=0.2890
# Episode 19: Reward=17.77, Avg(100)=-56.94, Avg(50)=-56.94, Noise STD=0.2890
# Episode 20: Reward=-94.08, Avg(100)=-58.80, Avg(50)=-58.80, Noise STD=0.2890
# Episode 21: Reward=41.50, Avg(100)=-54.02, Avg(50)=-54.02, Noise STD=0.2890
# Episode 22: Reward=31.21, Avg(100)=-50.15, Avg(50)=-50.15, Noise STD=0.2890
# Episode 23: Reward=48.26, Avg(100)=-45.87, Avg(50)=-45.87, Noise STD=0.2890
# Episode 24: Reward=34.04, Avg(100)=-42.54, Avg(50)=-42.54, Noise STD=0.2890
# Episode 25: Reward=-98.36, Avg(100)=-44.77, Avg(50)=-44.77, Noise STD=0.2890
# Episode 26: Reward=6.75, Avg(100)=-42.79, Avg(50)=-42.79, Noise STD=0.2890
# Episode 27: Reward=-97.60, Avg(100)=-44.82, Avg(50)=-44.82, Noise STD=0.2890
# Episode 28: Reward=56.95, Avg(100)=-41.19, Avg(50)=-41.19, Noise STD=0.2890
# Episode 29: Reward=18.37, Avg(100)=-39.13, Avg(50)=-39.13, Noise STD=0.2890
# Episode 30: Reward=-99.00, Avg(100)=-41.13, Avg(50)=-41.13, Noise STD=0.2890
# Episode 31: Reward=-98.52, Avg(100)=-42.98, Avg(50)=-42.98, Noise STD=0.2890
# Episode 32: Reward=29.74, Avg(100)=-40.71, Avg(50)=-40.71, Noise STD=0.2890
# Episode 33: Reward=-98.88, Avg(100)=-42.47, Avg(50)=-42.47, Noise STD=0.2890
# Episode 34: Reward=68.78, Avg(100)=-39.20, Avg(50)=-39.20, Noise STD=0.2890
# Episode 35: Reward=-98.96, Avg(100)=-40.91, Avg(50)=-40.91, Noise STD=0.2890
# Episode 36: Reward=-98.76, Avg(100)=-42.51, Avg(50)=-42.51, Noise STD=0.2890
# Episode 37: Reward=-99.39, Avg(100)=-44.05, Avg(50)=-44.05, Noise STD=0.2890
# Episode 38: Reward=-98.94, Avg(100)=-45.49, Avg(50)=-45.49, Noise STD=0.2890
# Episode 39: Reward=-98.91, Avg(100)=-46.86, Avg(50)=-46.86, Noise STD=0.2890
# Episode 40: Reward=-99.24, Avg(100)=-48.17, Avg(50)=-48.17, Noise STD=0.2890
# Episode 41: Reward=7.41, Avg(100)=-46.82, Avg(50)=-46.82, Noise STD=0.2890
# Episode 42: Reward=8.85, Avg(100)=-45.49, Avg(50)=-45.49, Noise STD=0.2890
# Episode 43: Reward=-98.83, Avg(100)=-46.73, Avg(50)=-46.73, Noise STD=0.2890
# Episode 44: Reward=27.17, Avg(100)=-45.05, Avg(50)=-45.05, Noise STD=0.2890
# Episode 45: Reward=50.16, Avg(100)=-42.94, Avg(50)=-42.94, Noise STD=0.2890
# Episode 46: Reward=-99.18, Avg(100)=-44.16, Avg(50)=-44.16, Noise STD=0.2890
# Episode 47: Reward=-98.97, Avg(100)=-45.33, Avg(50)=-45.33, Noise STD=0.2890
# Episode 48: Reward=-99.27, Avg(100)=-46.45, Avg(50)=-46.45, Noise STD=0.2890
# Episode 49: Reward=-99.61, Avg(100)=-47.54, Avg(50)=-47.54, Noise STD=0.2890
# Episode 50: Reward=-99.37, Avg(100)=-48.57, Avg(50)=-48.57, Noise STD=0.2890
# Episode 51: Reward=9.61, Avg(100)=-47.43, Avg(50)=-46.76, Noise STD=0.2890
# Episode 52: Reward=24.39, Avg(100)=-46.05, Avg(50)=-44.40, Noise STD=0.2890
# Episode 53: Reward=-99.64, Avg(100)=-47.06, Avg(50)=-46.77, Noise STD=0.2890
# Episode 54: Reward=-99.09, Avg(100)=-48.02, Avg(50)=-46.89, Noise STD=0.2890
# Episode 55: Reward=-98.92, Avg(100)=-48.95, Avg(50)=-47.01, Noise STD=0.2890
# Episode 56: Reward=6.79, Avg(100)=-47.95, Avg(50)=-45.01, Noise STD=0.2890
# Episode 57: Reward=-99.36, Avg(100)=-48.86, Avg(50)=-45.16, Noise STD=0.2890
# Episode 58: Reward=26.68, Avg(100)=-47.55, Avg(50)=-42.77, Noise STD=0.2890
# Episode 59: Reward=22.53, Avg(100)=-46.37, Avg(50)=-42.81, Noise STD=0.2890
# Episode 60: Reward=-98.98, Avg(100)=-47.24, Avg(50)=-42.92, Noise STD=0.2890
# Episode 61: Reward=26.36, Avg(100)=-46.04, Avg(50)=-42.55, Noise STD=0.2890
# Episode 62: Reward=-99.43, Avg(100)=-46.90, Avg(50)=-45.02, Noise STD=0.2890
# Episode 63: Reward=-99.80, Avg(100)=-47.74, Avg(50)=-45.19, Noise STD=0.2890
# Episode 64: Reward=-99.78, Avg(100)=-48.55, Avg(50)=-45.34, Noise STD=0.2890
# Episode 65: Reward=-99.78, Avg(100)=-49.34, Avg(50)=-45.51, Noise STD=0.2890
# Episode 66: Reward=-99.77, Avg(100)=-50.10, Avg(50)=-45.63, Noise STD=0.2890
# Episode 67: Reward=-99.51, Avg(100)=-50.84, Avg(50)=-45.72, Noise STD=0.2890
# Episode 68: Reward=-99.65, Avg(100)=-51.56, Avg(50)=-48.13, Noise STD=0.2890
# Episode 69: Reward=-99.67, Avg(100)=-52.26, Avg(50)=-50.47, Noise STD=0.2890
# Episode 70: Reward=-99.52, Avg(100)=-52.93, Avg(50)=-50.58, Noise STD=0.2890
# Episode 71: Reward=-99.38, Avg(100)=-53.58, Avg(50)=-53.40, Noise STD=0.2890
# Episode 72: Reward=-99.51, Avg(100)=-54.22, Avg(50)=-56.01, Noise STD=0.2890
# Episode 73: Reward=-99.68, Avg(100)=-54.85, Avg(50)=-58.97, Noise STD=0.2890
# Episode 74: Reward=-99.80, Avg(100)=-55.45, Avg(50)=-61.65, Noise STD=0.2890
# Episode 75: Reward=-99.73, Avg(100)=-56.04, Avg(50)=-61.68, Noise STD=0.2890
# Episode 76: Reward=-99.42, Avg(100)=-56.61, Avg(50)=-63.80, Noise STD=0.2890
# Episode 77: Reward=-99.86, Avg(100)=-57.18, Avg(50)=-63.85, Noise STD=0.2890
# Episode 78: Reward=-99.68, Avg(100)=-57.72, Avg(50)=-66.98, Noise STD=0.2890
# Episode 79: Reward=-99.60, Avg(100)=-58.25, Avg(50)=-69.34, Noise STD=0.2890
# Episode 80: Reward=-99.44, Avg(100)=-58.77, Avg(50)=-69.35, Noise STD=0.2890
# Episode 81: Reward=-99.48, Avg(100)=-59.27, Avg(50)=-69.37, Noise STD=0.2890
# Episode 82: Reward=-99.43, Avg(100)=-59.76, Avg(50)=-71.95, Noise STD=0.2890
# Episode 83: Reward=-99.81, Avg(100)=-60.24, Avg(50)=-71.97, Noise STD=0.2890
# Episode 84: Reward=-99.57, Avg(100)=-60.71, Avg(50)=-75.34, Noise STD=0.2890
# Episode 85: Reward=-99.65, Avg(100)=-61.17, Avg(50)=-75.35, Noise STD=0.2890
# Episode 86: Reward=0.66, Avg(100)=-60.45, Avg(50)=-73.36, Noise STD=0.2890
# Episode 87: Reward=-99.33, Avg(100)=-60.89, Avg(50)=-73.36, Noise STD=0.2890
# Episode 88: Reward=43.31, Avg(100)=-59.71, Avg(50)=-70.51, Noise STD=0.2890
# Episode 89: Reward=34.31, Avg(100)=-58.65, Avg(50)=-67.85, Noise STD=0.2890
# Episode 90: Reward=-99.39, Avg(100)=-59.11, Avg(50)=-67.85, Noise STD=0.2890
# Episode 91: Reward=-98.99, Avg(100)=-59.55, Avg(50)=-69.98, Noise STD=0.2890
# Episode 92: Reward=-99.08, Avg(100)=-59.97, Avg(50)=-72.14, Noise STD=0.2890
# Episode 93: Reward=-99.56, Avg(100)=-60.40, Avg(50)=-72.15, Noise STD=0.2890
# Episode 94: Reward=-99.81, Avg(100)=-60.82, Avg(50)=-74.69, Noise STD=0.2890
# Episode 95: Reward=-99.54, Avg(100)=-61.23, Avg(50)=-77.69, Noise STD=0.2890
# Episode 96: Reward=-99.29, Avg(100)=-61.62, Avg(50)=-77.69, Noise STD=0.2890
# Episode 97: Reward=-99.47, Avg(100)=-62.01, Avg(50)=-77.70, Noise STD=0.2890
# Episode 98: Reward=-99.52, Avg(100)=-62.40, Avg(50)=-77.71, Noise STD=0.2890
# Episode 99: Reward=-99.29, Avg(100)=-62.77, Avg(50)=-77.70, Noise STD=0.2890
# Episode 100: Reward=-98.80, Avg(100)=-63.13, Avg(50)=-77.69, Noise STD=0.2890
# Episode 101: Reward=-99.26, Avg(100)=-63.31, Avg(50)=-79.86, Noise STD=0.2890
# Episode 102: Reward=36.68, Avg(100)=-62.01, Avg(50)=-79.62, Noise STD=0.2890
# Episode 103: Reward=-99.69, Avg(100)=-63.19, Avg(50)=-79.62, Noise STD=0.2890
# Episode 104: Reward=12.14, Avg(100)=-62.14, Avg(50)=-77.40, Noise STD=0.2890
# Episode 105: Reward=-99.75, Avg(100)=-62.21, Avg(50)=-77.41, Noise STD=0.2890
# Episode 106: Reward=-99.80, Avg(100)=-62.28, Avg(50)=-79.54, Noise STD=0.2890
# Episode 107: Reward=-99.79, Avg(100)=-62.35, Avg(50)=-79.55, Noise STD=0.2890
# Episode 108: Reward=-99.48, Avg(100)=-62.42, Avg(50)=-82.08, Noise STD=0.2890
# Episode 109: Reward=-99.09, Avg(100)=-63.66, Avg(50)=-84.51, Noise STD=0.2890
# Episode 110: Reward=19.97, Avg(100)=-62.52, Avg(50)=-82.13, Noise STD=0.2890
# Episode 111: Reward=-99.02, Avg(100)=-63.59, Avg(50)=-84.64, Noise STD=0.2890
# Episode 112: Reward=-99.35, Avg(100)=-64.83, Avg(50)=-84.64, Noise STD=0.2890
# Episode 113: Reward=9.44, Avg(100)=-63.82, Avg(50)=-82.45, Noise STD=0.2890
# Episode 114: Reward=-98.96, Avg(100)=-63.89, Avg(50)=-82.43, Noise STD=0.2890
# Episode 115: Reward=-98.24, Avg(100)=-63.96, Avg(50)=-82.40, Noise STD=0.2890
# Episode 116: Reward=-98.87, Avg(100)=-64.01, Avg(50)=-82.39, Noise STD=0.2890
# Episode 117: Reward=32.67, Avg(100)=-62.73, Avg(50)=-79.74, Noise STD=0.2890
# Episode 118: Reward=-98.88, Avg(100)=-63.93, Avg(50)=-79.73, Noise STD=0.2890
# Episode 119: Reward=-98.84, Avg(100)=-65.09, Avg(50)=-79.71, Noise STD=0.2890
# Episode 120: Reward=-98.72, Avg(100)=-65.14, Avg(50)=-79.69, Noise STD=0.2890
# Episode 121: Reward=65.95, Avg(100)=-64.89, Avg(50)=-76.39, Noise STD=0.2890
# Episode 122: Reward=-99.00, Avg(100)=-66.20, Avg(50)=-76.38, Noise STD=0.2890
# Episode 123: Reward=-99.22, Avg(100)=-67.67, Avg(50)=-76.37, Noise STD=0.2890
# Episode 124: Reward=-99.39, Avg(100)=-69.01, Avg(50)=-76.36, Noise STD=0.2890
# Episode 125: Reward=-98.69, Avg(100)=-69.01, Avg(50)=-76.34, Noise STD=0.2890
# Episode 126: Reward=-99.18, Avg(100)=-70.07, Avg(50)=-76.33, Noise STD=0.2890
# Episode 127: Reward=41.81, Avg(100)=-68.67, Avg(50)=-73.50, Noise STD=0.2890
# Episode 128: Reward=-98.59, Avg(100)=-70.23, Avg(50)=-73.48, Noise STD=0.2890
# Episode 129: Reward=-98.86, Avg(100)=-71.40, Avg(50)=-73.46, Noise STD=0.2890
# Episode 130: Reward=-97.94, Avg(100)=-71.39, Avg(50)=-73.43, Noise STD=0.2890
# Episode 131: Reward=-98.52, Avg(100)=-71.39, Avg(50)=-73.41, Noise STD=0.2890
# Episode 132: Reward=51.36, Avg(100)=-71.17, Avg(50)=-70.40, Noise STD=0.2890
# Episode 133: Reward=-98.46, Avg(100)=-71.17, Avg(50)=-70.37, Noise STD=0.2890
# Episode 134: Reward=-99.01, Avg(100)=-72.85, Avg(50)=-70.36, Noise STD=0.2890
# Episode 135: Reward=-98.66, Avg(100)=-72.85, Avg(50)=-70.34, Noise STD=0.2890
# Episode 136: Reward=-98.06, Avg(100)=-72.84, Avg(50)=-72.32, Noise STD=0.2890
# Episode 137: Reward=41.57, Avg(100)=-71.43, Avg(50)=-69.50, Noise STD=0.2890
# Episode 138: Reward=-98.22, Avg(100)=-71.42, Avg(50)=-72.33, Noise STD=0.2890
# Episode 139: Reward=-98.55, Avg(100)=-71.42, Avg(50)=-74.99, Noise STD=0.2890
# Episode 140: Reward=-99.26, Avg(100)=-71.42, Avg(50)=-74.98, Noise STD=0.2890
# Episode 141: Reward=-98.88, Avg(100)=-72.48, Avg(50)=-74.98, Noise STD=0.2890
# Episode 142: Reward=-98.69, Avg(100)=-73.56, Avg(50)=-74.97, Noise STD=0.2890
# Episode 143: Reward=-98.45, Avg(100)=-73.55, Avg(50)=-74.95, Noise STD=0.2890
# Episode 144: Reward=10.71, Avg(100)=-73.72, Avg(50)=-72.74, Noise STD=0.2890
# Episode 145: Reward=-99.20, Avg(100)=-75.21, Avg(50)=-72.73, Noise STD=0.2890
# Episode 146: Reward=-99.31, Avg(100)=-75.21, Avg(50)=-72.73, Noise STD=0.2890
# Episode 147: Reward=-98.39, Avg(100)=-75.21, Avg(50)=-72.71, Noise STD=0.2890
# Episode 148: Reward=-98.95, Avg(100)=-75.20, Avg(50)=-72.70, Noise STD=0.2890
# Episode 149: Reward=45.91, Avg(100)=-73.75, Avg(50)=-69.80, Noise STD=0.2890
# Episode 150: Reward=-98.57, Avg(100)=-73.74, Avg(50)=-69.79, Noise STD=0.2890
# Episode 151: Reward=-99.23, Avg(100)=-74.83, Avg(50)=-69.79, Noise STD=0.2890
# Episode 152: Reward=-98.64, Avg(100)=-76.06, Avg(50)=-72.50, Noise STD=0.2890
# Episode 153: Reward=22.64, Avg(100)=-74.84, Avg(50)=-70.05, Noise STD=0.2890
# Episode 154: Reward=-98.00, Avg(100)=-74.82, Avg(50)=-72.25, Noise STD=0.2890
# Episode 155: Reward=-98.75, Avg(100)=-74.82, Avg(50)=-72.23, Noise STD=0.2890
# Episode 156: Reward=-97.90, Avg(100)=-75.87, Avg(50)=-72.20, Noise STD=0.2890
# Episode 157: Reward=37.93, Avg(100)=-74.50, Avg(50)=-69.44, Noise STD=0.2890
# Episode 158: Reward=66.39, Avg(100)=-74.10, Avg(50)=-66.12, Noise STD=0.2890
# Episode 159: Reward=-98.99, Avg(100)=-75.32, Avg(50)=-66.12, Noise STD=0.2890
# Episode 160: Reward=-98.63, Avg(100)=-75.31, Avg(50)=-68.49, Noise STD=0.2890
# Episode 161: Reward=68.02, Avg(100)=-74.90, Avg(50)=-65.15, Noise STD=0.2890
# Episode 162: Reward=-99.18, Avg(100)=-74.89, Avg(50)=-65.15, Noise STD=0.2890
# Episode 163: Reward=-99.47, Avg(100)=-74.89, Avg(50)=-67.33, Noise STD=0.2890
# Episode 164: Reward=-99.60, Avg(100)=-74.89, Avg(50)=-67.34, Noise STD=0.2890
# Episode 165: Reward=38.87, Avg(100)=-73.50, Avg(50)=-64.60, Noise STD=0.2890
# Episode 166: Reward=-99.29, Avg(100)=-73.50, Avg(50)=-64.61, Noise STD=0.2890
# Episode 167: Reward=-99.41, Avg(100)=-73.50, Avg(50)=-67.25, Noise STD=0.2890
# Episode 168: Reward=-99.52, Avg(100)=-73.49, Avg(50)=-67.26, Noise STD=0.2890
# Episode 169: Reward=-99.46, Avg(100)=-73.49, Avg(50)=-67.27, Noise STD=0.2890
# Episode 170: Reward=3.98, Avg(100)=-72.46, Avg(50)=-65.22, Noise STD=0.2890
# Episode 171: Reward=-99.72, Avg(100)=-72.46, Avg(50)=-68.53, Noise STD=0.2890
# Episode 172: Reward=-99.14, Avg(100)=-72.46, Avg(50)=-68.54, Noise STD=0.2890
# Episode 173: Reward=65.17, Avg(100)=-70.81, Avg(50)=-65.25, Noise STD=0.2890
# Episode 174: Reward=65.46, Avg(100)=-69.16, Avg(50)=-61.95, Noise STD=0.2890
# Episode 175: Reward=-98.61, Avg(100)=-69.14, Avg(50)=-61.95, Noise STD=0.2890
# Episode 176: Reward=-98.60, Avg(100)=-69.14, Avg(50)=-61.94, Noise STD=0.2890
# Episode 177: Reward=-97.64, Avg(100)=-69.11, Avg(50)=-64.73, Noise STD=0.2890
# Episode 178: Reward=36.17, Avg(100)=-67.76, Avg(50)=-62.03, Noise STD=0.2890
# Episode 179: Reward=-98.49, Avg(100)=-67.74, Avg(50)=-62.02, Noise STD=0.2890
# Episode 180: Reward=-98.42, Avg(100)=-67.73, Avg(50)=-62.03, Noise STD=0.2890
# Episode 181: Reward=4.15, Avg(100)=-66.70, Avg(50)=-59.98, Noise STD=0.2890
# Episode 182: Reward=-99.50, Avg(100)=-66.70, Avg(50)=-63.00, Noise STD=0.2890
# Episode 183: Reward=-99.13, Avg(100)=-66.69, Avg(50)=-63.01, Noise STD=0.2890
# Episode 184: Reward=-99.43, Avg(100)=-66.69, Avg(50)=-63.02, Noise STD=0.2890
# Episode 185: Reward=53.81, Avg(100)=-65.16, Avg(50)=-59.97, Noise STD=0.2890
# Episode 186: Reward=-99.04, Avg(100)=-66.15, Avg(50)=-59.99, Noise STD=0.2890
# Episode 187: Reward=-99.39, Avg(100)=-66.15, Avg(50)=-62.81, Noise STD=0.2890
# Episode 188: Reward=-98.96, Avg(100)=-67.58, Avg(50)=-62.82, Noise STD=0.2890
# Episode 189: Reward=46.00, Avg(100)=-67.46, Avg(50)=-59.93, Noise STD=0.2890
# Episode 190: Reward=-98.85, Avg(100)=-67.45, Avg(50)=-59.92, Noise STD=0.2890
# Episode 191: Reward=-99.15, Avg(100)=-67.46, Avg(50)=-59.93, Noise STD=0.2890
# Episode 192: Reward=-98.98, Avg(100)=-67.45, Avg(50)=-59.94, Noise STD=0.2890
# Episode 193: Reward=-99.49, Avg(100)=-67.45, Avg(50)=-59.96, Noise STD=0.2890
# Episode 194: Reward=-98.82, Avg(100)=-67.44, Avg(50)=-62.15, Noise STD=0.2890
# Episode 195: Reward=11.98, Avg(100)=-66.33, Avg(50)=-59.92, Noise STD=0.2890
# Episode 196: Reward=-99.22, Avg(100)=-66.33, Avg(50)=-59.92, Noise STD=0.2890
# Episode 197: Reward=-99.10, Avg(100)=-66.32, Avg(50)=-59.94, Noise STD=0.2890
# Episode 198: Reward=-99.26, Avg(100)=-66.32, Avg(50)=-59.94, Noise STD=0.2890
# Episode 199: Reward=-99.48, Avg(100)=-66.32, Avg(50)=-62.85, Noise STD=0.2890
# Episode 200: Reward=-99.32, Avg(100)=-66.33, Avg(50)=-62.86, Noise STD=0.2890
# Episode 201: Reward=-99.46, Avg(100)=-66.33, Avg(50)=-62.87, Noise STD=0.2890
# Episode 202: Reward=-99.71, Avg(100)=-67.69, Avg(50)=-62.89, Noise STD=0.2890
# Episode 203: Reward=-99.52, Avg(100)=-67.69, Avg(50)=-65.33, Noise STD=0.2890
# Episode 204: Reward=-99.38, Avg(100)=-68.81, Avg(50)=-65.36, Noise STD=0.2890
# Episode 205: Reward=-99.40, Avg(100)=-68.80, Avg(50)=-65.37, Noise STD=0.2890
# Episode 206: Reward=52.37, Avg(100)=-67.28, Avg(50)=-62.37, Noise STD=0.2890
# Episode 207: Reward=75.13, Avg(100)=-65.53, Avg(50)=-61.62, Noise STD=0.2890
# Episode 208: Reward=-98.89, Avg(100)=-65.53, Avg(50)=-64.93, Noise STD=0.2890
# Episode 209: Reward=52.17, Avg(100)=-64.01, Avg(50)=-61.91, Noise STD=0.2890
# Episode 210: Reward=36.65, Avg(100)=-63.85, Avg(50)=-59.20, Noise STD=0.2890
# Episode 211: Reward=17.23, Avg(100)=-62.69, Avg(50)=-60.22, Noise STD=0.2890
# Episode 212: Reward=35.48, Avg(100)=-61.34, Avg(50)=-57.52, Noise STD=0.2890
# Episode 213: Reward=-98.96, Avg(100)=-62.42, Avg(50)=-57.51, Noise STD=0.2890
# Episode 214: Reward=-99.49, Avg(100)=-62.43, Avg(50)=-57.51, Noise STD=0.2890
# Episode 215: Reward=21.10, Avg(100)=-61.23, Avg(50)=-57.87, Noise STD=0.2890
# Episode 216: Reward=-99.38, Avg(100)=-61.24, Avg(50)=-57.87, Noise STD=0.2890
# Episode 217: Reward=-99.38, Avg(100)=-62.56, Avg(50)=-57.87, Noise STD=0.2890
# Episode 218: Reward=-99.34, Avg(100)=-62.56, Avg(50)=-57.86, Noise STD=0.2890
# Episode 219: Reward=-99.33, Avg(100)=-62.57, Avg(50)=-57.86, Noise STD=0.2890
# Episode 220: Reward=-99.41, Avg(100)=-62.57, Avg(50)=-59.93, Noise STD=0.2890
# Episode 221: Reward=-99.62, Avg(100)=-64.23, Avg(50)=-59.93, Noise STD=0.2890
# Episode 222: Reward=23.42, Avg(100)=-63.01, Avg(50)=-57.48, Noise STD=0.2890
# Episode 223: Reward=-99.24, Avg(100)=-63.01, Avg(50)=-60.76, Noise STD=0.2890
# Episode 224: Reward=-99.88, Avg(100)=-63.01, Avg(50)=-64.07, Noise STD=0.2890
# Episode 225: Reward=-99.83, Avg(100)=-63.02, Avg(50)=-64.10, Noise STD=0.2890
# Episode 226: Reward=22.93, Avg(100)=-61.80, Avg(50)=-61.67, Noise STD=0.2890
# Episode 227: Reward=-99.57, Avg(100)=-63.22, Avg(50)=-61.70, Noise STD=0.2890
# Episode 228: Reward=26.82, Avg(100)=-61.96, Avg(50)=-61.89, Noise STD=0.2890
# Episode 229: Reward=-99.29, Avg(100)=-61.97, Avg(50)=-61.91, Noise STD=0.2890
# Episode 230: Reward=-99.13, Avg(100)=-61.98, Avg(50)=-61.92, Noise STD=0.2890
# Episode 231: Reward=-99.48, Avg(100)=-61.99, Avg(50)=-63.99, Noise STD=0.2890
# Episode 232: Reward=20.69, Avg(100)=-62.29, Avg(50)=-61.59, Noise STD=0.2890
# Episode 233: Reward=-99.05, Avg(100)=-62.30, Avg(50)=-61.59, Noise STD=0.2890
# Episode 234: Reward=-99.10, Avg(100)=-62.30, Avg(50)=-61.58, Noise STD=0.2890
# Episode 235: Reward=-99.09, Avg(100)=-62.31, Avg(50)=-64.64, Noise STD=0.2890
# Episode 236: Reward=-99.02, Avg(100)=-62.31, Avg(50)=-64.64, Noise STD=0.2890
# Episode 237: Reward=-99.17, Avg(100)=-63.72, Avg(50)=-64.64, Noise STD=0.2890
# Episode 238: Reward=-99.19, Avg(100)=-63.73, Avg(50)=-64.64, Noise STD=0.2890
# Episode 239: Reward=-98.57, Avg(100)=-63.73, Avg(50)=-67.53, Noise STD=0.2890
# Episode 240: Reward=64.49, Avg(100)=-62.09, Avg(50)=-64.26, Noise STD=0.2890
# Episode 241: Reward=14.32, Avg(100)=-60.96, Avg(50)=-61.99, Noise STD=0.2890
# Episode 242: Reward=-98.99, Avg(100)=-60.97, Avg(50)=-62.00, Noise STD=0.2890
# Episode 243: Reward=-99.34, Avg(100)=-60.97, Avg(50)=-61.99, Noise STD=0.2890
# Episode 244: Reward=-99.42, Avg(100)=-62.08, Avg(50)=-62.00, Noise STD=0.2890
# Episode 245: Reward=-99.23, Avg(100)=-62.08, Avg(50)=-64.23, Noise STD=0.2890
# Episode 246: Reward=-99.19, Avg(100)=-62.07, Avg(50)=-64.23, Noise STD=0.2890
# Episode 247: Reward=-99.38, Avg(100)=-62.08, Avg(50)=-64.23, Noise STD=0.2890
# Episode 248: Reward=-99.70, Avg(100)=-62.09, Avg(50)=-64.24, Noise STD=0.2890
# Episode 249: Reward=-99.77, Avg(100)=-63.55, Avg(50)=-64.25, Noise STD=0.2890
# Episode 250: Reward=-99.70, Avg(100)=-63.56, Avg(50)=-64.26, Noise STD=0.2890
# Episode 251: Reward=-98.78, Avg(100)=-63.56, Avg(50)=-64.24, Noise STD=0.2890
# Episode 252: Reward=33.76, Avg(100)=-62.23, Avg(50)=-61.57, Noise STD=0.2890
# Episode 253: Reward=-99.45, Avg(100)=-63.45, Avg(50)=-61.57, Noise STD=0.2890
# Episode 254: Reward=-99.25, Avg(100)=-63.47, Avg(50)=-61.57, Noise STD=0.2890
# Episode 255: Reward=-99.35, Avg(100)=-63.47, Avg(50)=-61.57, Noise STD=0.2890
# Episode 256: Reward=-98.98, Avg(100)=-63.48, Avg(50)=-64.59, Noise STD=0.2890
# Episode 257: Reward=-99.65, Avg(100)=-64.86, Avg(50)=-68.09, Noise STD=0.2890
# Episode 258: Reward=-99.38, Avg(100)=-66.52, Avg(50)=-68.10, Noise STD=0.2890
# Episode 259: Reward=-99.34, Avg(100)=-66.52, Avg(50)=-71.13, Noise STD=0.2890
# Episode 260: Reward=-99.07, Avg(100)=-66.52, Avg(50)=-73.85, Noise STD=0.2890
# Episode 261: Reward=-99.52, Avg(100)=-68.20, Avg(50)=-76.18, Noise STD=0.2890
# Episode 262: Reward=-99.31, Avg(100)=-68.20, Avg(50)=-78.88, Noise STD=0.2890
# Episode 263: Reward=-99.60, Avg(100)=-68.20, Avg(50)=-78.89, Noise STD=0.2890
# Episode 264: Reward=-99.48, Avg(100)=-68.20, Avg(50)=-78.89, Noise STD=0.2890
# Episode 265: Reward=2.34, Avg(100)=-68.57, Avg(50)=-79.26, Noise STD=0.2890
# Episode 266: Reward=-99.38, Avg(100)=-68.57, Avg(50)=-79.26, Noise STD=0.2890
# Episode 267: Reward=-97.78, Avg(100)=-68.55, Avg(50)=-79.23, Noise STD=0.2890
# Episode 268: Reward=-98.55, Avg(100)=-68.54, Avg(50)=-79.22, Noise STD=0.2890
# Episode 269: Reward=2.25, Avg(100)=-67.52, Avg(50)=-77.18, Noise STD=0.2890
# Episode 270: Reward=-99.01, Avg(100)=-68.55, Avg(50)=-77.18, Noise STD=0.2890
# Episode 271: Reward=7.09, Avg(100)=-67.49, Avg(50)=-75.04, Noise STD=0.2890
# Episode 272: Reward=-99.47, Avg(100)=-67.49, Avg(50)=-77.50, Noise STD=0.2890
# Episode 273: Reward=1.20, Avg(100)=-68.13, Avg(50)=-75.49, Noise STD=0.2890
# Episode 274: Reward=21.52, Avg(100)=-68.57, Avg(50)=-73.06, Noise STD=0.2890
# Episode 275: Reward=-99.37, Avg(100)=-68.58, Avg(50)=-73.05, Noise STD=0.2890
# Episode 276: Reward=-99.01, Avg(100)=-68.58, Avg(50)=-75.49, Noise STD=0.2890
# Episode 277: Reward=-99.33, Avg(100)=-68.60, Avg(50)=-75.49, Noise STD=0.2890
# Episode 278: Reward=-99.77, Avg(100)=-69.96, Avg(50)=-78.02, Noise STD=0.2890
# Episode 279: Reward=8.72, Avg(100)=-68.88, Avg(50)=-75.86, Noise STD=0.2890
# Episode 280: Reward=-99.65, Avg(100)=-68.90, Avg(50)=-75.87, Noise STD=0.2890
# Episode 281: Reward=-99.82, Avg(100)=-69.94, Avg(50)=-75.88, Noise STD=0.2890
# Episode 282: Reward=-99.67, Avg(100)=-69.94, Avg(50)=-78.28, Noise STD=0.2890
# Episode 283: Reward=-99.13, Avg(100)=-69.94, Avg(50)=-78.29, Noise STD=0.2890
# Episode 284: Reward=-99.73, Avg(100)=-69.94, Avg(50)=-78.30, Noise STD=0.2890
# Episode 285: Reward=-99.62, Avg(100)=-71.47, Avg(50)=-78.31, Noise STD=0.2890
# Episode 286: Reward=-99.58, Avg(100)=-71.48, Avg(50)=-78.32, Noise STD=0.2890
# Episode 287: Reward=-99.84, Avg(100)=-71.48, Avg(50)=-78.33, Noise STD=0.2890
# Episode 288: Reward=-99.65, Avg(100)=-71.49, Avg(50)=-78.34, Noise STD=0.2890
# Episode 289: Reward=-99.90, Avg(100)=-72.95, Avg(50)=-78.37, Noise STD=0.2890
# Episode 290: Reward=-99.82, Avg(100)=-72.96, Avg(50)=-81.66, Noise STD=0.2890
# Episode 291: Reward=-99.63, Avg(100)=-72.96, Avg(50)=-83.93, Noise STD=0.2890
# Episode 292: Reward=-99.53, Avg(100)=-72.97, Avg(50)=-83.94, Noise STD=0.2890
# Episode 293: Reward=-99.57, Avg(100)=-72.97, Avg(50)=-83.95, Noise STD=0.2890
# Episode 294: Reward=-99.31, Avg(100)=-72.98, Avg(50)=-83.95, Noise STD=0.2890
# Episode 295: Reward=-98.58, Avg(100)=-74.08, Avg(50)=-83.93, Noise STD=0.2890
# Episode 296: Reward=-98.57, Avg(100)=-74.07, Avg(50)=-83.92, Noise STD=0.2890
# Episode 297: Reward=65.09, Avg(100)=-72.43, Avg(50)=-80.63, Noise STD=0.2890
# Episode 298: Reward=-98.36, Avg(100)=-72.42, Avg(50)=-80.61, Noise STD=0.2890
# Episode 299: Reward=1.18, Avg(100)=-71.42, Avg(50)=-78.59, Noise STD=0.2890
# Episode 300: Reward=-99.14, Avg(100)=-71.42, Avg(50)=-78.58, Noise STD=0.2890
# Episode 301: Reward=24.77, Avg(100)=-70.17, Avg(50)=-76.10, Noise STD=0.2890
# Episode 302: Reward=-99.22, Avg(100)=-70.17, Avg(50)=-78.76, Noise STD=0.2890
# Episode 303: Reward=-98.80, Avg(100)=-70.16, Avg(50)=-78.75, Noise STD=0.2890
# Episode 304: Reward=-98.93, Avg(100)=-70.16, Avg(50)=-78.74, Noise STD=0.2890
# Episode 305: Reward=-99.51, Avg(100)=-70.16, Avg(50)=-78.75, Noise STD=0.2890
# Episode 306: Reward=-99.46, Avg(100)=-71.68, Avg(50)=-78.76, Noise STD=0.2890
# Episode 307: Reward=-99.22, Avg(100)=-73.42, Avg(50)=-78.75, Noise STD=0.2890
# Episode 308: Reward=-99.16, Avg(100)=-73.42, Avg(50)=-78.74, Noise STD=0.2890
# Episode 309: Reward=-98.95, Avg(100)=-74.93, Avg(50)=-78.74, Noise STD=0.2890
# Episode 310: Reward=39.45, Avg(100)=-74.91, Avg(50)=-75.97, Noise STD=0.2890
# Episode 311: Reward=73.99, Avg(100)=-74.34, Avg(50)=-72.50, Noise STD=0.2890
# Episode 312: Reward=-99.21, Avg(100)=-75.68, Avg(50)=-72.49, Noise STD=0.2890
# Episode 313: Reward=-99.36, Avg(100)=-75.69, Avg(50)=-72.49, Noise STD=0.2890
# Episode 314: Reward=-99.26, Avg(100)=-75.69, Avg(50)=-72.48, Noise STD=0.2890
# Episode 315: Reward=-98.82, Avg(100)=-76.89, Avg(50)=-74.51, Noise STD=0.2890
# Episode 316: Reward=73.76, Avg(100)=-75.15, Avg(50)=-71.04, Noise STD=0.2890
# Episode 317: Reward=-99.10, Avg(100)=-75.15, Avg(50)=-71.07, Noise STD=0.2890
# Episode 318: Reward=-99.39, Avg(100)=-75.15, Avg(50)=-71.09, Noise STD=0.2890
# Episode 319: Reward=-99.53, Avg(100)=-75.15, Avg(50)=-73.12, Noise STD=0.2890
# Episode 320: Reward=77.07, Avg(100)=-73.39, Avg(50)=-69.60, Noise STD=0.2890
# Episode 321: Reward=-98.65, Avg(100)=-73.38, Avg(50)=-71.72, Noise STD=0.2890
# Episode 322: Reward=-99.07, Avg(100)=-74.60, Avg(50)=-71.71, Noise STD=0.2890
# Episode 323: Reward=-99.60, Avg(100)=-74.61, Avg(50)=-73.72, Noise STD=0.2890
# Episode 324: Reward=-99.83, Avg(100)=-74.61, Avg(50)=-76.15, Noise STD=0.2890
# Episode 325: Reward=-99.43, Avg(100)=-74.60, Avg(50)=-76.15, Noise STD=0.2890
# Episode 326: Reward=-99.64, Avg(100)=-75.83, Avg(50)=-76.17, Noise STD=0.2890
# Episode 327: Reward=-99.77, Avg(100)=-75.83, Avg(50)=-76.17, Noise STD=0.2890
# Episode 328: Reward=-99.48, Avg(100)=-77.09, Avg(50)=-76.17, Noise STD=0.2890
# Episode 329: Reward=-99.63, Avg(100)=-77.10, Avg(50)=-78.34, Noise STD=0.2890
# Episode 330: Reward=-99.80, Avg(100)=-77.10, Avg(50)=-78.34, Noise STD=0.2890
# Episode 331: Reward=-99.41, Avg(100)=-77.10, Avg(50)=-78.33, Noise STD=0.2890
# Episode 332: Reward=2.36, Avg(100)=-77.29, Avg(50)=-76.29, Noise STD=0.2890
# Episode 333: Reward=-99.47, Avg(100)=-77.29, Avg(50)=-76.30, Noise STD=0.2890
# Episode 334: Reward=-99.38, Avg(100)=-77.29, Avg(50)=-76.29, Noise STD=0.2890
# Episode 335: Reward=-99.50, Avg(100)=-77.30, Avg(50)=-76.29, Noise STD=0.2890
# Episode 336: Reward=-99.45, Avg(100)=-77.30, Avg(50)=-76.29, Noise STD=0.2890
# Episode 337: Reward=-99.40, Avg(100)=-77.30, Avg(50)=-76.28, Noise STD=0.2890
# Episode 338: Reward=-99.60, Avg(100)=-77.31, Avg(50)=-76.28, Noise STD=0.2890
# Episode 339: Reward=-99.56, Avg(100)=-77.32, Avg(50)=-76.27, Noise STD=0.2890
# Episode 340: Reward=-99.35, Avg(100)=-78.96, Avg(50)=-76.26, Noise STD=0.2890
# Episode 341: Reward=85.18, Avg(100)=-78.25, Avg(50)=-72.56, Noise STD=0.2890
# Episode 342: Reward=-99.39, Avg(100)=-78.25, Avg(50)=-72.56, Noise STD=0.2890
# Episode 343: Reward=-99.26, Avg(100)=-78.25, Avg(50)=-72.55, Noise STD=0.2890
# Episode 344: Reward=-99.46, Avg(100)=-78.25, Avg(50)=-72.56, Noise STD=0.2890
# Episode 345: Reward=12.96, Avg(100)=-77.13, Avg(50)=-70.33, Noise STD=0.2890
# Episode 346: Reward=-99.52, Avg(100)=-77.13, Avg(50)=-70.35, Noise STD=0.2890
# Episode 347: Reward=-99.54, Avg(100)=-77.14, Avg(50)=-73.64, Noise STD=0.2890
# Episode 348: Reward=-99.80, Avg(100)=-77.14, Avg(50)=-73.67, Noise STD=0.2890
# Episode 349: Reward=-99.72, Avg(100)=-77.14, Avg(50)=-75.68, Noise STD=0.2890
# Episode 350: Reward=-99.90, Avg(100)=-77.14, Avg(50)=-75.70, Noise STD=0.2890
# Episode 351: Reward=-99.88, Avg(100)=-77.15, Avg(50)=-78.19, Noise STD=0.2890
# Episode 352: Reward=-99.90, Avg(100)=-78.49, Avg(50)=-78.21, Noise STD=0.2890
# Episode 353: Reward=-99.80, Avg(100)=-78.49, Avg(50)=-78.23, Noise STD=0.2890
# Episode 354: Reward=-99.64, Avg(100)=-78.49, Avg(50)=-78.24, Noise STD=0.2890
# Episode 355: Reward=-99.37, Avg(100)=-78.49, Avg(50)=-78.24, Noise STD=0.2890
# Episode 356: Reward=-99.65, Avg(100)=-78.50, Avg(50)=-78.24, Noise STD=0.2890
# Episode 357: Reward=-99.35, Avg(100)=-78.50, Avg(50)=-78.24, Noise STD=0.2890
# Episode 358: Reward=-99.66, Avg(100)=-78.50, Avg(50)=-78.25, Noise STD=0.2890
# Episode 359: Reward=47.96, Avg(100)=-77.03, Avg(50)=-75.32, Noise STD=0.2890
# Episode 360: Reward=-99.72, Avg(100)=-77.03, Avg(50)=-78.10, Noise STD=0.2890
# Episode 361: Reward=-99.63, Avg(100)=-77.03, Avg(50)=-81.57, Noise STD=0.2890
# Episode 362: Reward=-99.83, Avg(100)=-77.04, Avg(50)=-81.58, Noise STD=0.2890
# Episode 363: Reward=-99.68, Avg(100)=-77.04, Avg(50)=-81.59, Noise STD=0.2890
# Episode 364: Reward=-99.59, Avg(100)=-77.04, Avg(50)=-81.60, Noise STD=0.2890
# Episode 365: Reward=-99.62, Avg(100)=-78.06, Avg(50)=-81.61, Noise STD=0.2890
# Episode 366: Reward=-99.79, Avg(100)=-78.06, Avg(50)=-85.08, Noise STD=0.2890
# Episode 367: Reward=-99.53, Avg(100)=-78.08, Avg(50)=-85.09, Noise STD=0.2890
# Episode 368: Reward=75.39, Avg(100)=-76.34, Avg(50)=-81.60, Noise STD=0.2890
# Episode 369: Reward=4.32, Avg(100)=-76.32, Avg(50)=-79.52, Noise STD=0.2890
# Episode 370: Reward=-99.41, Avg(100)=-76.33, Avg(50)=-83.05, Noise STD=0.2890
# Episode 371: Reward=-99.50, Avg(100)=-77.39, Avg(50)=-83.07, Noise STD=0.2890
# Episode 372: Reward=-99.51, Avg(100)=-77.39, Avg(50)=-83.08, Noise STD=0.2890
# Episode 373: Reward=-99.80, Avg(100)=-78.40, Avg(50)=-83.08, Noise STD=0.2890
# Episode 374: Reward=-99.54, Avg(100)=-79.61, Avg(50)=-83.07, Noise STD=0.2890
# Episode 375: Reward=-99.80, Avg(100)=-79.62, Avg(50)=-83.08, Noise STD=0.2890
# Episode 376: Reward=-99.16, Avg(100)=-79.62, Avg(50)=-83.07, Noise STD=0.2890
# Episode 377: Reward=-99.07, Avg(100)=-79.62, Avg(50)=-83.06, Noise STD=0.2890
# Episode 378: Reward=-99.78, Avg(100)=-79.62, Avg(50)=-83.06, Noise STD=0.2890
# Episode 379: Reward=-99.64, Avg(100)=-80.70, Avg(50)=-83.06, Noise STD=0.2890
# Episode 380: Reward=-99.90, Avg(100)=-80.70, Avg(50)=-83.07, Noise STD=0.2890
# Episode 381: Reward=-99.67, Avg(100)=-80.70, Avg(50)=-83.07, Noise STD=0.2890
# Episode 382: Reward=-99.20, Avg(100)=-80.70, Avg(50)=-85.10, Noise STD=0.2890
# Episode 383: Reward=-99.44, Avg(100)=-80.70, Avg(50)=-85.10, Noise STD=0.2890
# Episode 384: Reward=-99.63, Avg(100)=-80.70, Avg(50)=-85.11, Noise STD=0.2890
# Episode 385: Reward=-98.70, Avg(100)=-80.69, Avg(50)=-85.09, Noise STD=0.2890
# Episode 386: Reward=-98.92, Avg(100)=-80.68, Avg(50)=-85.08, Noise STD=0.2890
# Episode 387: Reward=-99.09, Avg(100)=-80.68, Avg(50)=-85.07, Noise STD=0.2890
# Episode 388: Reward=-98.84, Avg(100)=-80.67, Avg(50)=-85.06, Noise STD=0.2890
# Episode 389: Reward=52.88, Avg(100)=-79.14, Avg(50)=-82.01, Noise STD=0.2890
# Episode 390: Reward=60.29, Avg(100)=-77.54, Avg(50)=-78.82, Noise STD=0.2890
# Episode 391: Reward=75.13, Avg(100)=-75.79, Avg(50)=-79.02, Noise STD=0.2890
# Episode 392: Reward=20.13, Avg(100)=-74.59, Avg(50)=-76.63, Noise STD=0.2890
# Episode 393: Reward=-98.55, Avg(100)=-74.58, Avg(50)=-76.61, Noise STD=0.2890
# Episode 394: Reward=-98.77, Avg(100)=-74.58, Avg(50)=-76.60, Noise STD=0.2890
# Episode 395: Reward=-98.80, Avg(100)=-74.58, Avg(50)=-78.84, Noise STD=0.2890
# Episode 396: Reward=-98.66, Avg(100)=-74.58, Avg(50)=-78.82, Noise STD=0.2890
# Episode 397: Reward=-98.97, Avg(100)=-76.22, Avg(50)=-78.81, Noise STD=0.2890
# Episode 398: Reward=3.53, Avg(100)=-75.20, Avg(50)=-76.74, Noise STD=0.2890
# Episode 399: Reward=-99.74, Avg(100)=-76.21, Avg(50)=-76.74, Noise STD=0.2890
# Episode 400: Reward=-99.39, Avg(100)=-76.21, Avg(50)=-76.73, Noise STD=0.2890
# Episode 401: Reward=-99.87, Avg(100)=-77.46, Avg(50)=-76.73, Noise STD=0.2890
# Episode 402: Reward=-99.56, Avg(100)=-77.46, Avg(50)=-76.72, Noise STD=0.2890
# Episode 403: Reward=-99.81, Avg(100)=-77.47, Avg(50)=-76.72, Noise STD=0.2890
# Episode 404: Reward=-99.71, Avg(100)=-77.48, Avg(50)=-76.72, Noise STD=0.2890
# Episode 405: Reward=-99.90, Avg(100)=-77.49, Avg(50)=-76.74, Noise STD=0.2890
# Episode 406: Reward=-99.81, Avg(100)=-77.49, Avg(50)=-76.74, Noise STD=0.2890
# Episode 407: Reward=-99.71, Avg(100)=-77.50, Avg(50)=-76.75, Noise STD=0.2890
# Episode 408: Reward=-99.80, Avg(100)=-77.50, Avg(50)=-76.75, Noise STD=0.2890
# Episode 409: Reward=-99.73, Avg(100)=-77.51, Avg(50)=-79.70, Noise STD=0.2890
# Episode 410: Reward=-99.65, Avg(100)=-78.90, Avg(50)=-79.70, Noise STD=0.2890
# Episode 411: Reward=-99.47, Avg(100)=-80.63, Avg(50)=-79.70, Noise STD=0.2890
# Episode 412: Reward=-99.90, Avg(100)=-80.64, Avg(50)=-79.70, Noise STD=0.2890
# Episode 413: Reward=15.67, Avg(100)=-79.49, Avg(50)=-77.39, Noise STD=0.2890
# Episode 414: Reward=-99.63, Avg(100)=-79.50, Avg(50)=-77.39, Noise STD=0.2890
# Episode 415: Reward=-99.28, Avg(100)=-79.50, Avg(50)=-77.39, Noise STD=0.2890
# Episode 416: Reward=-99.47, Avg(100)=-81.23, Avg(50)=-77.38, Noise STD=0.2890
# Episode 417: Reward=-99.24, Avg(100)=-81.23, Avg(50)=-77.37, Noise STD=0.2890
# Episode 418: Reward=-99.17, Avg(100)=-81.23, Avg(50)=-80.86, Noise STD=0.2890
# Episode 419: Reward=-99.66, Avg(100)=-81.23, Avg(50)=-82.94, Noise STD=0.2890
# Episode 420: Reward=-99.22, Avg(100)=-83.00, Avg(50)=-82.94, Noise STD=0.2890
# Episode 421: Reward=31.02, Avg(100)=-81.70, Avg(50)=-80.33, Noise STD=0.2890
# Episode 422: Reward=-98.03, Avg(100)=-81.69, Avg(50)=-80.30, Noise STD=0.2890
# Episode 423: Reward=48.59, Avg(100)=-80.21, Avg(50)=-77.33, Noise STD=0.2890
# Episode 424: Reward=6.57, Avg(100)=-79.14, Avg(50)=-75.21, Noise STD=0.2890
# Episode 425: Reward=9.54, Avg(100)=-78.05, Avg(50)=-73.02, Noise STD=0.2890
# Episode 426: Reward=39.27, Avg(100)=-76.66, Avg(50)=-70.26, Noise STD=0.2890
# Episode 427: Reward=-98.74, Avg(100)=-76.65, Avg(50)=-70.25, Noise STD=0.2890
# Episode 428: Reward=-99.29, Avg(100)=-76.65, Avg(50)=-70.24, Noise STD=0.2890
# Episode 429: Reward=-99.50, Avg(100)=-76.65, Avg(50)=-70.24, Noise STD=0.2890
# Episode 430: Reward=65.40, Avg(100)=-75.00, Avg(50)=-66.93, Noise STD=0.2890
# Episode 431: Reward=15.69, Avg(100)=-73.85, Avg(50)=-64.62, Noise STD=0.2890
# Episode 432: Reward=-99.62, Avg(100)=-74.87, Avg(50)=-64.63, Noise STD=0.2890
# Episode 433: Reward=40.46, Avg(100)=-73.47, Avg(50)=-61.83, Noise STD=0.2890
# Episode 434: Reward=-99.64, Avg(100)=-73.47, Avg(50)=-61.83, Noise STD=0.2890
# Episode 435: Reward=27.14, Avg(100)=-72.20, Avg(50)=-59.32, Noise STD=0.2890
# Episode 436: Reward=3.34, Avg(100)=-71.18, Avg(50)=-57.27, Noise STD=0.2890
# Episode 437: Reward=-99.39, Avg(100)=-71.18, Avg(50)=-57.28, Noise STD=0.2890
# Episode 438: Reward=-99.54, Avg(100)=-71.18, Avg(50)=-57.29, Noise STD=0.2890
# Episode 439: Reward=-99.42, Avg(100)=-71.17, Avg(50)=-60.34, Noise STD=0.2890
# Episode 440: Reward=51.94, Avg(100)=-69.66, Avg(50)=-60.50, Noise STD=0.2890
# Episode 441: Reward=57.19, Avg(100)=-69.94, Avg(50)=-60.86, Noise STD=0.2890
# Episode 442: Reward=-99.31, Avg(100)=-69.94, Avg(50)=-63.25, Noise STD=0.2890
# Episode 443: Reward=-99.50, Avg(100)=-69.94, Avg(50)=-63.27, Noise STD=0.2890
# Episode 444: Reward=-99.21, Avg(100)=-69.94, Avg(50)=-63.28, Noise STD=0.2890
# Episode 445: Reward=-99.41, Avg(100)=-71.06, Avg(50)=-63.29, Noise STD=0.2890
# Episode 446: Reward=-98.85, Avg(100)=-71.06, Avg(50)=-63.30, Noise STD=0.2890
# Episode 447: Reward=-98.60, Avg(100)=-71.05, Avg(50)=-63.29, Noise STD=0.2890
# Episode 448: Reward=-99.23, Avg(100)=-71.04, Avg(50)=-65.34, Noise STD=0.2890
# Episode 449: Reward=10.32, Avg(100)=-69.94, Avg(50)=-63.14, Noise STD=0.2890
# Episode 450: Reward=38.15, Avg(100)=-68.56, Avg(50)=-60.39, Noise STD=0.2890
# Episode 451: Reward=2.19, Avg(100)=-67.54, Avg(50)=-58.35, Noise STD=0.2890
# Episode 452: Reward=-99.29, Avg(100)=-67.53, Avg(50)=-58.35, Noise STD=0.2890
# Episode 453: Reward=-99.30, Avg(100)=-67.53, Avg(50)=-58.33, Noise STD=0.2890
# Episode 454: Reward=-99.48, Avg(100)=-67.53, Avg(50)=-58.33, Noise STD=0.2890
# Episode 455: Reward=-99.44, Avg(100)=-67.53, Avg(50)=-58.32, Noise STD=0.2890
# Episode 456: Reward=-99.27, Avg(100)=-67.52, Avg(50)=-58.31, Noise STD=0.2890
# Episode 457: Reward=-99.43, Avg(100)=-67.53, Avg(50)=-58.30, Noise STD=0.2890
# Episode 458: Reward=76.58, Avg(100)=-65.76, Avg(50)=-54.78, Noise STD=0.2890
# Episode 459: Reward=-99.41, Avg(100)=-67.24, Avg(50)=-54.77, Noise STD=0.2890
# Episode 460: Reward=-99.58, Avg(100)=-67.24, Avg(50)=-54.77, Noise STD=0.2890
# Episode 461: Reward=-99.40, Avg(100)=-67.23, Avg(50)=-54.77, Noise STD=0.2890
# Episode 462: Reward=-99.52, Avg(100)=-67.23, Avg(50)=-54.76, Noise STD=0.2890
# Episode 463: Reward=-99.28, Avg(100)=-67.23, Avg(50)=-57.06, Noise STD=0.2890
# Episode 464: Reward=-99.78, Avg(100)=-67.23, Avg(50)=-57.06, Noise STD=0.2890
# Episode 465: Reward=-99.32, Avg(100)=-67.22, Avg(50)=-57.06, Noise STD=0.2890
# Episode 466: Reward=-99.76, Avg(100)=-67.22, Avg(50)=-57.07, Noise STD=0.2890
# Episode 467: Reward=-99.76, Avg(100)=-67.23, Avg(50)=-57.08, Noise STD=0.2890
# Episode 468: Reward=-99.47, Avg(100)=-68.97, Avg(50)=-57.09, Noise STD=0.2890
# Episode 469: Reward=-99.66, Avg(100)=-70.01, Avg(50)=-57.08, Noise STD=0.2890
# Episode 470: Reward=-99.82, Avg(100)=-70.02, Avg(50)=-57.10, Noise STD=0.2890
# Episode 471: Reward=-99.67, Avg(100)=-70.02, Avg(50)=-59.71, Noise STD=0.2890
# Episode 472: Reward=-99.64, Avg(100)=-70.02, Avg(50)=-59.74, Noise STD=0.2890
# Episode 473: Reward=-99.81, Avg(100)=-70.02, Avg(50)=-62.71, Noise STD=0.2890
# Episode 474: Reward=-99.69, Avg(100)=-70.02, Avg(50)=-64.84, Noise STD=0.2890
# Episode 475: Reward=-99.24, Avg(100)=-70.02, Avg(50)=-67.01, Noise STD=0.2890
# Episode 476: Reward=-99.62, Avg(100)=-70.02, Avg(50)=-69.79, Noise STD=0.2890
# Episode 477: Reward=-99.58, Avg(100)=-70.03, Avg(50)=-69.81, Noise STD=0.2890
# Episode 478: Reward=-98.64, Avg(100)=-70.02, Avg(50)=-69.79, Noise STD=0.2890
# Episode 479: Reward=-98.61, Avg(100)=-70.01, Avg(50)=-69.78, Noise STD=0.2890
# Episode 480: Reward=-98.04, Avg(100)=-69.99, Avg(50)=-73.04, Noise STD=0.2890
# Episode 481: Reward=51.21, Avg(100)=-68.48, Avg(50)=-72.33, Noise STD=0.2890
# Episode 482: Reward=20.87, Avg(100)=-67.28, Avg(50)=-69.92, Noise STD=0.2890
# Episode 483: Reward=-98.51, Avg(100)=-67.27, Avg(50)=-72.70, Noise STD=0.2890
# Episode 484: Reward=-97.93, Avg(100)=-67.25, Avg(50)=-72.67, Noise STD=0.2890
# Episode 485: Reward=-98.43, Avg(100)=-67.25, Avg(50)=-75.18, Noise STD=0.2890
# Episode 486: Reward=42.44, Avg(100)=-65.83, Avg(50)=-74.40, Noise STD=0.2890
# Episode 487: Reward=47.36, Avg(100)=-64.37, Avg(50)=-71.46, Noise STD=0.2890
# Episode 488: Reward=-98.76, Avg(100)=-64.37, Avg(50)=-71.45, Noise STD=0.2890
# Episode 489: Reward=-98.37, Avg(100)=-65.88, Avg(50)=-71.43, Noise STD=0.2890
# Episode 490: Reward=-98.99, Avg(100)=-67.47, Avg(50)=-74.45, Noise STD=0.2890
# Episode 491: Reward=-98.31, Avg(100)=-69.21, Avg(50)=-77.56, Noise STD=0.2890
# Episode 492: Reward=36.49, Avg(100)=-69.05, Avg(50)=-74.84, Noise STD=0.2890
# Episode 493: Reward=57.07, Avg(100)=-67.49, Avg(50)=-71.71, Noise STD=0.2890
# Episode 494: Reward=29.22, Avg(100)=-66.21, Avg(50)=-69.14, Noise STD=0.2890
# Episode 495: Reward=-98.75, Avg(100)=-66.21, Avg(50)=-69.13, Noise STD=0.2890
# Episode 496: Reward=-98.62, Avg(100)=-66.21, Avg(50)=-69.12, Noise STD=0.2890
# Episode 497: Reward=-98.70, Avg(100)=-66.21, Avg(50)=-69.12, Noise STD=0.2890
# Episode 498: Reward=-98.15, Avg(100)=-67.22, Avg(50)=-69.10, Noise STD=0.2890
# Episode 499: Reward=59.55, Avg(100)=-65.63, Avg(50)=-68.12, Noise STD=0.2890
# Episode 500: Reward=35.46, Avg(100)=-64.28, Avg(50)=-68.17, Noise STD=0.2890
# Episode 501: Reward=65.38, Avg(100)=-62.63, Avg(50)=-66.91, Noise STD=0.2890
# Episode 502: Reward=-98.34, Avg(100)=-62.62, Avg(50)=-66.89, Noise STD=0.2890
# Episode 503: Reward=25.32, Avg(100)=-61.37, Avg(50)=-64.40, Noise STD=0.2890
# Episode 504: Reward=-98.25, Avg(100)=-61.35, Avg(50)=-64.37, Noise STD=0.2890
# Episode 505: Reward=36.88, Avg(100)=-59.98, Avg(50)=-61.64, Noise STD=0.2890
# Episode 506: Reward=-98.47, Avg(100)=-59.97, Avg(50)=-61.63, Noise STD=0.2890
# Episode 507: Reward=-98.40, Avg(100)=-59.96, Avg(50)=-61.61, Noise STD=0.2890
# Episode 508: Reward=-98.53, Avg(100)=-59.94, Avg(50)=-65.11, Noise STD=0.2890
# Episode 509: Reward=-97.39, Avg(100)=-59.92, Avg(50)=-65.07, Noise STD=0.2890
# Episode 510: Reward=68.86, Avg(100)=-58.24, Avg(50)=-61.70, Noise STD=0.2890
# Episode 511: Reward=-97.92, Avg(100)=-58.22, Avg(50)=-61.67, Noise STD=0.2890
# Episode 512: Reward=-97.25, Avg(100)=-58.19, Avg(50)=-61.63, Noise STD=0.2890
# Episode 513: Reward=23.50, Avg(100)=-58.12, Avg(50)=-59.17, Noise STD=0.2890
# Episode 514: Reward=45.42, Avg(100)=-56.66, Avg(50)=-56.27, Noise STD=0.2890
# Episode 515: Reward=53.54, Avg(100)=-55.14, Avg(50)=-53.21, Noise STD=0.2890
# Episode 516: Reward=-96.25, Avg(100)=-55.10, Avg(50)=-53.14, Noise STD=0.2890
# Episode 517: Reward=37.26, Avg(100)=-53.74, Avg(50)=-50.40, Noise STD=0.2890
# Episode 518: Reward=46.02, Avg(100)=-52.29, Avg(50)=-47.49, Noise STD=0.2890
# Episode 519: Reward=35.82, Avg(100)=-50.93, Avg(50)=-44.78, Noise STD=0.2890
# Episode 520: Reward=-97.67, Avg(100)=-50.92, Avg(50)=-44.74, Noise STD=0.2890
# Episode 521: Reward=40.87, Avg(100)=-50.82, Avg(50)=-41.93, Noise STD=0.2890
# Episode 522: Reward=-98.40, Avg(100)=-50.82, Avg(50)=-41.90, Noise STD=0.2890
# Episode 523: Reward=-98.37, Avg(100)=-52.29, Avg(50)=-41.87, Noise STD=0.2890
# Episode 524: Reward=18.45, Avg(100)=-52.17, Avg(50)=-39.51, Noise STD=0.2890
# Episode 525: Reward=59.59, Avg(100)=-51.67, Avg(50)=-36.33, Noise STD=0.2890
# Episode 526: Reward=41.53, Avg(100)=-51.65, Avg(50)=-33.51, Noise STD=0.2890
# Episode 527: Reward=35.55, Avg(100)=-50.31, Avg(50)=-30.81, Noise STD=0.2890
# Episode 528: Reward=-98.46, Avg(100)=-50.30, Avg(50)=-30.80, Noise STD=0.2890
# Episode 529: Reward=14.27, Avg(100)=-49.16, Avg(50)=-28.55, Noise STD=0.2890
# Episode 530: Reward=45.32, Avg(100)=-49.36, Avg(50)=-25.68, Noise STD=0.2890
# Episode 531: Reward=66.30, Avg(100)=-48.86, Avg(50)=-25.38, Noise STD=0.2890
# Episode 532: Reward=-98.98, Avg(100)=-48.85, Avg(50)=-27.77, Noise STD=0.2890
# Episode 533: Reward=-98.93, Avg(100)=-50.24, Avg(50)=-27.78, Noise STD=0.2890
# Episode 534: Reward=17.30, Avg(100)=-49.07, Avg(50)=-25.48, Noise STD=0.2890
# Episode 535: Reward=46.45, Avg(100)=-48.88, Avg(50)=-22.58, Noise STD=0.2890
# Episode 536: Reward=52.24, Avg(100)=-48.39, Avg(50)=-22.38, Noise STD=0.2890
# Episode 537: Reward=17.28, Avg(100)=-47.22, Avg(50)=-22.99, Noise STD=0.2890
# Episode 538: Reward=-98.65, Avg(100)=-47.22, Avg(50)=-22.98, Noise STD=0.2890
# Episode 539: Reward=-99.38, Avg(100)=-47.22, Avg(50)=-23.00, Noise STD=0.2890
# Episode 540: Reward=41.77, Avg(100)=-47.32, Avg(50)=-20.19, Noise STD=0.2890
# Episode 541: Reward=-99.15, Avg(100)=-48.88, Avg(50)=-20.21, Noise STD=0.2890
# Episode 542: Reward=-99.26, Avg(100)=-48.88, Avg(50)=-22.92, Noise STD=0.2890
# Episode 543: Reward=4.78, Avg(100)=-47.84, Avg(50)=-23.97, Noise STD=0.2890
# Episode 544: Reward=-99.14, Avg(100)=-47.84, Avg(50)=-26.53, Noise STD=0.2890
# Episode 545: Reward=-98.82, Avg(100)=-47.83, Avg(50)=-26.54, Noise STD=0.2890
# Episode 546: Reward=-99.34, Avg(100)=-47.84, Avg(50)=-26.55, Noise STD=0.2890
# Episode 547: Reward=-99.42, Avg(100)=-47.84, Avg(50)=-26.56, Noise STD=0.2890
# Episode 548: Reward=-98.48, Avg(100)=-47.84, Avg(50)=-26.57, Noise STD=0.2890
# Episode 549: Reward=-99.09, Avg(100)=-48.93, Avg(50)=-29.74, Noise STD=0.2890
# Episode 550: Reward=-98.05, Avg(100)=-50.29, Avg(50)=-32.41, Noise STD=0.2890
# Episode 551: Reward=6.59, Avg(100)=-50.25, Avg(50)=-33.59, Noise STD=0.2890
# Episode 552: Reward=69.85, Avg(100)=-48.56, Avg(50)=-30.23, Noise STD=0.2890
# Episode 553: Reward=-97.35, Avg(100)=-48.54, Avg(50)=-32.68, Noise STD=0.2890
# Episode 554: Reward=-98.18, Avg(100)=-48.52, Avg(50)=-32.68, Noise STD=0.2890
# Episode 555: Reward=-98.54, Avg(100)=-48.52, Avg(50)=-35.39, Noise STD=0.2890
# Episode 556: Reward=-98.44, Avg(100)=-48.51, Avg(50)=-35.39, Noise STD=0.2890
# Episode 557: Reward=49.73, Avg(100)=-47.02, Avg(50)=-32.42, Noise STD=0.2890
# Episode 558: Reward=-98.32, Avg(100)=-48.76, Avg(50)=-32.42, Noise STD=0.2890
# Episode 559: Reward=16.80, Avg(100)=-47.60, Avg(50)=-30.13, Noise STD=0.2890
# Episode 560: Reward=18.01, Avg(100)=-46.43, Avg(50)=-31.15, Noise STD=0.2890
# Episode 561: Reward=68.66, Avg(100)=-44.75, Avg(50)=-27.82, Noise STD=0.2890
# Episode 562: Reward=31.78, Avg(100)=-43.43, Avg(50)=-25.24, Noise STD=0.2890
# Episode 563: Reward=-98.14, Avg(100)=-43.42, Avg(50)=-27.67, Noise STD=0.2890
# Episode 564: Reward=-98.11, Avg(100)=-43.40, Avg(50)=-30.54, Noise STD=0.2890
# Episode 565: Reward=-98.04, Avg(100)=-43.39, Avg(50)=-33.57, Noise STD=0.2890
# Episode 566: Reward=-99.01, Avg(100)=-43.38, Avg(50)=-33.63, Noise STD=0.2890
# Episode 567: Reward=7.97, Avg(100)=-42.31, Avg(50)=-34.22, Noise STD=0.2890
# Episode 568: Reward=14.09, Avg(100)=-41.17, Avg(50)=-34.85, Noise STD=0.2890
# Episode 569: Reward=-99.00, Avg(100)=-41.17, Avg(50)=-37.55, Noise STD=0.2890
# Episode 570: Reward=-99.11, Avg(100)=-41.16, Avg(50)=-37.58, Noise STD=0.2890
# Episode 571: Reward=-99.12, Avg(100)=-41.15, Avg(50)=-40.38, Noise STD=0.2890
# Episode 572: Reward=-98.80, Avg(100)=-41.14, Avg(50)=-40.39, Noise STD=0.2890
# Episode 573: Reward=-97.92, Avg(100)=-41.13, Avg(50)=-40.38, Noise STD=0.2890
# ...
# Episode 806: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 807: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 808: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 809: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 810: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 811: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 812: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 813: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 814: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 815: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 816: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 817: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 818: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 819: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 820: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 821: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 822: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 823: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 824: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 825: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 826: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 827: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 828: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 829: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 830: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 831: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 832: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 833: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 834: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 835: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 836: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 837: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 838: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 839: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 840: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 841: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 842: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 843: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 844: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 845: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 846: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 847: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 848: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 849: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 850: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 851: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 852: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 853: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 854: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 855: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 856: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 857: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 858: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 859: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 860: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 861: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 862: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 863: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 864: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 865: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 866: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 867: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 868: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 869: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 870: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 871: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 872: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 873: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 874: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 875: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 876: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 877: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 878: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 879: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 880: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 881: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 882: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 883: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 884: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 885: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 886: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 887: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 888: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 889: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 890: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 891: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 892: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 893: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 894: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 895: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 896: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 897: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 898: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 899: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 900: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 901: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 902: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 903: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 904: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 905: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 906: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 907: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 908: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 909: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 910: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 911: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 912: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 913: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 914: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 915: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 916: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 917: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 918: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 919: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 920: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 921: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 922: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 923: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 924: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 925: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 926: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 927: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 928: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 929: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 930: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 931: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 932: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 933: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 934: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 935: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 936: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 937: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 938: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 939: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 940: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 941: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 942: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 943: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 944: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 945: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 946: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 947: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 948: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 949: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 950: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 951: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 952: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 953: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 954: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 955: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 956: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 957: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 958: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 959: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 960: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 961: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 962: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 963: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 964: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 965: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 966: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 967: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 968: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 969: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 970: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 971: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 972: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 973: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 974: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 975: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 976: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 977: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 978: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 979: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 980: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 981: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 982: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 983: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 984: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 985: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 986: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 987: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 988: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 989: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 990: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 991: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 992: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 993: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 994: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 995: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 996: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 997: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 998: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Episode 999: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# [I 2025-01-07 12:58:49,435] Trial 1 finished with value: -inf and parameters: {'alpha_theta': 0.003967605077052989, 'alpha_w': 0.0006358358856676254, 'gamma': 0.9700991852018085, 'entropy_coeff': 0.0020584494295802446, 'start_noise_std': 0.2924774630404986, 'end_noise_std': 0.45811066020010544, 'noise_decay': 0.9210215719571494}. Best is trial 0 with value: 10.644144751563351.
# Episode 1000: Reward=-99.90, Avg(100)=-99.90, Avg(50)=-99.90, Noise STD=0.4581
# Number of finished trials:  2
# Best trial:
#   Value: 10.644144751563351
#   Params:
#     alpha_theta: 0.0001329291894316216
#     alpha_w: 0.0071144760093434225
#     gamma: 0.9724674002393291
#     entropy_coeff: 0.05986584841970366
#     start_noise_std: 0.08900466011060913
#     end_noise_std: 0.2889986300840507
#     noise_decay: 0.9057502776046518
