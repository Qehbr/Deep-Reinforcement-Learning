# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, hidden_sizes, output_dim):
        super(PolicyNetwork, self).__init__()
        layers = []
        prev_size = input_dim
        for hs in hidden_sizes:
            layers.append(nn.Linear(prev_size, hs))
            layers.append(nn.ReLU())
            prev_size = hs
        layers.append(nn.Linear(prev_size, output_dim))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        logits = self.model(x)
        return torch.softmax(logits, dim=-1)


class ValueNetwork(nn.Module):
    def __init__(self, input_dim, hidden_sizes):
        super(ValueNetwork, self).__init__()
        layers = []
        prev_size = input_dim
        for hs in hidden_sizes:
            layers.append(nn.Linear(prev_size, hs))
            layers.append(nn.ReLU())
            prev_size = hs
        layers.append(nn.Linear(prev_size, 1))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %%
def reinforce(env,
              input_dim,
              output_dim,
              hidden_sizes,
              alpha=0.001,
              beta=0.001,
              episodes=500,
              gamma=0.99,
              log_dir="runs/reinforce_with_baseline"):
    """
    REINFORCE training loop with a baseline (value function).

    Args:
        env: OpenAI gym environment
        input_dim: dimension of input space
        output_dim: number of actions
        hidden_sizes: list of sizes for each hidden layer
        alpha: The learning rate for the policy network
        beta: The learning rate for the value network
        episodes: number of training episodes
        gamma: discount factor
        log_dir: directory for tensorboard logs

    Returns:
        policy_network: the trained policy network
        rewards_per_episode: a list containing the total reward per episode
    """

    writer = SummaryWriter(log_dir=log_dir)

    policy_network = PolicyNetwork(input_dim, hidden_sizes, output_dim).to(device)
    value_network = ValueNetwork(input_dim, hidden_sizes).to(device)

    policy_optimizer = optim.Adam(policy_network.parameters(), lr=alpha)
    value_optimizer = optim.Adam(value_network.parameters(), lr=beta)

    rewards_per_episode = []

    for episode in range(episodes):
        # generate a new episode
        state, _ = env.reset()
        done = False
        truncated = False
        states = []
        actions_log_probs = []
        rewards = []

        while not (done or truncated):
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            action_probs = policy_network(state_tensor)
            action_dist = torch.distributions.Categorical(action_probs)
            action = action_dist.sample()
            log_prob = action_dist.log_prob(action)

            next_state, reward, done, truncated, info = env.step(action.item())

            states.append(state)
            actions_log_probs.append(log_prob)
            rewards.append(reward)

            state = next_state

        # compute the returns (G_t) for the episode (including gamma)
        returns = []
        G = 0
        for r in reversed(rewards):
            G = r + gamma * G
            returns.append(G)
        returns.reverse()

        states_tensor = torch.tensor(states, dtype=torch.float32, device=device)
        returns_tensor = torch.tensor(returns, dtype=torch.float32, device=device).unsqueeze(1)

        # compute value predictions
        values = value_network(states_tensor)

        # compute advantages A_t = G_t - V(s_t)
        advantages = returns_tensor - values.detach()

        # update policy network
        policy_loss = []
        for log_prob, A in zip(actions_log_probs, advantages):
            policy_loss.append(-log_prob * A)
        policy_loss = torch.cat(policy_loss).sum()

        policy_optimizer.zero_grad()
        policy_loss.backward()
        policy_optimizer.step()

        # update value network (MSE loss between returns and values)
        value_loss = nn.MSELoss()(values, returns_tensor)
        value_optimizer.zero_grad()
        value_loss.backward()
        value_optimizer.step()

        total_reward = sum(rewards)
        rewards_per_episode.append(total_reward)

        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}")

        # log metrics to TensorBoard
        writer.add_scalar("Policy Loss", policy_loss.item(), episode)
        writer.add_scalar("Value Loss", value_loss.item(), episode)
        writer.add_scalar("Total Reward", total_reward, episode)

        # early stopping if solved
        if len(rewards_per_episode) >= 100:
            avg_reward = np.mean(rewards_per_episode[-100:])
            print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}, Average Reward: {avg_reward}")
            if avg_reward >= 475.0:
                print(f"Solved in {episode + 1} episodes!")
                break
        else:
            print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}")

    writer.close()
    return policy_network, value_network, rewards_per_episode

# %%
def test_policy(env, policy_network, episodes=10):
    policy_network.eval()
    avg_reward = 0
    for ep in range(episodes):
        state, _ = env.reset()
        total_reward = 0
        done = False
        while not done:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            with torch.no_grad():
                action_probs = policy_network(state_tensor)
            action = torch.argmax(action_probs).item()
            state, reward, done, truncated, info = env.step(action)
            total_reward += reward
            if total_reward >= 10000:
                break

        avg_reward += total_reward
        print(f"Test Episode {ep + 1}, Total Reward: {total_reward}")
    return avg_reward / episodes

# %%
def grid_search(env, input_dim, output_dim, hidden_sizes, gamma_values, alpha_values, episodes=2000):
    best_combination = None
    best_episodes = float('inf')
    best_policy_network = None
    best_value_network = None
    best_reward = float('inf')
    results = []

    for gamma in gamma_values:
        for alpha in alpha_values:
            print(f"Training with gamma={gamma}, alpha={alpha}")
            policy_network, value_network, rewards = reinforce(
                env,
                input_dim=input_dim,
                output_dim=output_dim,
                hidden_sizes=hidden_sizes,
                alpha=alpha,
                episodes=episodes,
                gamma=gamma,
                log_dir=f"runs/reinforce_with_baseline_{alpha}_{gamma}"
            )

            avg_reward = np.mean(rewards[-100:])
            solved_episodes = len(rewards)
            results.append((gamma, alpha, solved_episodes, avg_reward))

            if avg_reward >= 475 and solved_episodes < best_episodes:
                best_combination = (gamma, alpha)
                best_episodes = solved_episodes
                best_policy_network = policy_network
                best_value_network = value_network
                best_reward = avg_reward

            print(f"Gamma={gamma}, Alpha={alpha}, Solved in {solved_episodes} episodes")

    return best_policy_network, best_value_network, best_combination, best_episodes, best_reward, results

# %%
# Define the environment and input/output dimensions
env = gym.make("CartPole-v1")
input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n
hidden_sizes = [16, 32, 16]

# Define the ranges for gamma and alpha
gamma_values = [0.95, 0.99, 0.995]
alpha_values = [0.001, 0.0005, 0.0001]

# Perform grid search
best_policy_network, best_value_network, best_params, best_episodes, best_reward, all_results = grid_search(env,
                                                                                                            input_dim,
                                                                                                            output_dim,
                                                                                                            hidden_sizes,
                                                                                                            gamma_values,
                                                                                                            alpha_values,
                                                                                                            1000)

# Print the best parameters
if best_params:
    print("\nBest Parameters:")
    print(f"Gamma: {best_params[0]}, Alpha: {best_params[1]}, Solved in {best_episodes} episodes\n")

for gamma, alpha, solved_episode, average_reward in all_results:
    print(f"Gamma: {gamma}, Alpha: {alpha}, Solved in: {solved_episode} episodes, Average Reward: {average_reward}")
# Out:
# Training with gamma=0.95, alpha=0.001
# C:\Users\forgedRice\anaconda3\envs\DRL\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# C:\Users\forgedRice\AppData\Local\Temp\ipykernel_35056\3982997751.py:71: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:281.)
#   states_tensor = torch.tensor(states, dtype=torch.float32, device=device)
# Episode 1/1000, Total Reward: 17.0
# Episode 1/1000, Total Reward: 17.0
# Episode 2/1000, Total Reward: 20.0
# Episode 2/1000, Total Reward: 20.0
# Episode 3/1000, Total Reward: 9.0
# Episode 3/1000, Total Reward: 9.0
# Episode 4/1000, Total Reward: 12.0
# Episode 4/1000, Total Reward: 12.0
# Episode 5/1000, Total Reward: 15.0
# Episode 5/1000, Total Reward: 15.0
# Episode 6/1000, Total Reward: 18.0
# Episode 6/1000, Total Reward: 18.0
# Episode 7/1000, Total Reward: 27.0
# Episode 7/1000, Total Reward: 27.0
# Episode 8/1000, Total Reward: 23.0
# Episode 8/1000, Total Reward: 23.0
# Episode 9/1000, Total Reward: 20.0
# Episode 9/1000, Total Reward: 20.0
# Episode 10/1000, Total Reward: 25.0
# Episode 10/1000, Total Reward: 25.0
# Episode 11/1000, Total Reward: 10.0
# Episode 11/1000, Total Reward: 10.0
# Episode 12/1000, Total Reward: 18.0
# Episode 12/1000, Total Reward: 18.0
# Episode 13/1000, Total Reward: 16.0
# Episode 13/1000, Total Reward: 16.0
# Episode 14/1000, Total Reward: 54.0
# Episode 14/1000, Total Reward: 54.0
# Episode 15/1000, Total Reward: 11.0
# Episode 15/1000, Total Reward: 11.0
# Episode 16/1000, Total Reward: 13.0
# Episode 16/1000, Total Reward: 13.0
# Episode 17/1000, Total Reward: 16.0
# Episode 17/1000, Total Reward: 16.0
# Episode 18/1000, Total Reward: 35.0
# Episode 18/1000, Total Reward: 35.0
# Episode 19/1000, Total Reward: 19.0
# Episode 19/1000, Total Reward: 19.0
# Episode 20/1000, Total Reward: 13.0
# Episode 20/1000, Total Reward: 13.0
# Episode 21/1000, Total Reward: 18.0
# Episode 21/1000, Total Reward: 18.0
# Episode 22/1000, Total Reward: 16.0
# Episode 22/1000, Total Reward: 16.0
# Episode 23/1000, Total Reward: 15.0
# Episode 23/1000, Total Reward: 15.0
# Episode 24/1000, Total Reward: 22.0
# Episode 24/1000, Total Reward: 22.0
# Episode 25/1000, Total Reward: 25.0
# Episode 25/1000, Total Reward: 25.0
# Episode 26/1000, Total Reward: 15.0
# Episode 26/1000, Total Reward: 15.0
# Episode 27/1000, Total Reward: 21.0
# Episode 27/1000, Total Reward: 21.0
# Episode 28/1000, Total Reward: 13.0
# Episode 28/1000, Total Reward: 13.0
# Episode 29/1000, Total Reward: 20.0
# Episode 29/1000, Total Reward: 20.0
# Episode 30/1000, Total Reward: 24.0
# Episode 30/1000, Total Reward: 24.0
# Episode 31/1000, Total Reward: 13.0
# Episode 31/1000, Total Reward: 13.0
# Episode 32/1000, Total Reward: 26.0
# Episode 32/1000, Total Reward: 26.0
# Episode 33/1000, Total Reward: 27.0
# Episode 33/1000, Total Reward: 27.0
# Episode 34/1000, Total Reward: 16.0
# Episode 34/1000, Total Reward: 16.0
# Episode 35/1000, Total Reward: 23.0
# Episode 35/1000, Total Reward: 23.0
# Episode 36/1000, Total Reward: 13.0
# Episode 36/1000, Total Reward: 13.0
# Episode 37/1000, Total Reward: 26.0
# Episode 37/1000, Total Reward: 26.0
# Episode 38/1000, Total Reward: 23.0
# Episode 38/1000, Total Reward: 23.0
# Episode 39/1000, Total Reward: 17.0
# Episode 39/1000, Total Reward: 17.0
# Episode 40/1000, Total Reward: 54.0
# Episode 40/1000, Total Reward: 54.0
# Episode 41/1000, Total Reward: 17.0
# Episode 41/1000, Total Reward: 17.0
# Episode 42/1000, Total Reward: 12.0
# Episode 42/1000, Total Reward: 12.0
# Episode 43/1000, Total Reward: 12.0
# Episode 43/1000, Total Reward: 12.0
# Episode 44/1000, Total Reward: 21.0
# Episode 44/1000, Total Reward: 21.0
# Episode 45/1000, Total Reward: 24.0
# Episode 45/1000, Total Reward: 24.0
# Episode 46/1000, Total Reward: 14.0
# Episode 46/1000, Total Reward: 14.0
# Episode 47/1000, Total Reward: 23.0
# Episode 47/1000, Total Reward: 23.0
# Episode 48/1000, Total Reward: 16.0
# Episode 48/1000, Total Reward: 16.0
# Episode 49/1000, Total Reward: 10.0
# Episode 49/1000, Total Reward: 10.0
# Episode 50/1000, Total Reward: 21.0
# Episode 50/1000, Total Reward: 21.0
# Episode 51/1000, Total Reward: 22.0
# Episode 51/1000, Total Reward: 22.0
# Episode 52/1000, Total Reward: 38.0
# Episode 52/1000, Total Reward: 38.0
# Episode 53/1000, Total Reward: 26.0
# Episode 53/1000, Total Reward: 26.0
# Episode 54/1000, Total Reward: 10.0
# Episode 54/1000, Total Reward: 10.0
# Episode 55/1000, Total Reward: 30.0
# Episode 55/1000, Total Reward: 30.0
# Episode 56/1000, Total Reward: 15.0
# Episode 56/1000, Total Reward: 15.0
# Episode 57/1000, Total Reward: 17.0
# Episode 57/1000, Total Reward: 17.0
# Episode 58/1000, Total Reward: 10.0
# Episode 58/1000, Total Reward: 10.0
# Episode 59/1000, Total Reward: 23.0
# Episode 59/1000, Total Reward: 23.0
# Episode 60/1000, Total Reward: 16.0
# Episode 60/1000, Total Reward: 16.0
# Episode 61/1000, Total Reward: 15.0
# Episode 61/1000, Total Reward: 15.0
# Episode 62/1000, Total Reward: 22.0
# Episode 62/1000, Total Reward: 22.0
# Episode 63/1000, Total Reward: 15.0
# Episode 63/1000, Total Reward: 15.0
# Episode 64/1000, Total Reward: 14.0
# Episode 64/1000, Total Reward: 14.0
# Episode 65/1000, Total Reward: 49.0
# Episode 65/1000, Total Reward: 49.0
# Episode 66/1000, Total Reward: 16.0
# Episode 66/1000, Total Reward: 16.0
# Episode 67/1000, Total Reward: 16.0
# Episode 67/1000, Total Reward: 16.0
# Episode 68/1000, Total Reward: 26.0
# Episode 68/1000, Total Reward: 26.0
# Episode 69/1000, Total Reward: 13.0
# Episode 69/1000, Total Reward: 13.0
# Episode 70/1000, Total Reward: 24.0
# Episode 70/1000, Total Reward: 24.0
# Episode 71/1000, Total Reward: 16.0
# Episode 71/1000, Total Reward: 16.0
# Episode 72/1000, Total Reward: 35.0
# Episode 72/1000, Total Reward: 35.0
# Episode 73/1000, Total Reward: 19.0
# Episode 73/1000, Total Reward: 19.0
# Episode 74/1000, Total Reward: 20.0
# Episode 74/1000, Total Reward: 20.0
# Episode 75/1000, Total Reward: 21.0
# Episode 75/1000, Total Reward: 21.0
# Episode 76/1000, Total Reward: 25.0
# Episode 76/1000, Total Reward: 25.0
# Episode 77/1000, Total Reward: 19.0
# Episode 77/1000, Total Reward: 19.0
# Episode 78/1000, Total Reward: 11.0
# Episode 78/1000, Total Reward: 11.0
# Episode 79/1000, Total Reward: 26.0
# Episode 79/1000, Total Reward: 26.0
# Episode 80/1000, Total Reward: 13.0
# Episode 80/1000, Total Reward: 13.0
# Episode 81/1000, Total Reward: 14.0
# Episode 81/1000, Total Reward: 14.0
# Episode 82/1000, Total Reward: 24.0
# Episode 82/1000, Total Reward: 24.0
# Episode 83/1000, Total Reward: 32.0
# Episode 83/1000, Total Reward: 32.0
# Episode 84/1000, Total Reward: 12.0
# Episode 84/1000, Total Reward: 12.0
# Episode 85/1000, Total Reward: 71.0
# Episode 85/1000, Total Reward: 71.0
# Episode 86/1000, Total Reward: 17.0
# Episode 86/1000, Total Reward: 17.0
# Episode 87/1000, Total Reward: 14.0
# Episode 87/1000, Total Reward: 14.0
# Episode 88/1000, Total Reward: 12.0
# Episode 88/1000, Total Reward: 12.0
# Episode 89/1000, Total Reward: 33.0
# Episode 89/1000, Total Reward: 33.0
# Episode 90/1000, Total Reward: 9.0
# Episode 90/1000, Total Reward: 9.0
# Episode 91/1000, Total Reward: 15.0
# Episode 91/1000, Total Reward: 15.0
# Episode 92/1000, Total Reward: 17.0
# Episode 92/1000, Total Reward: 17.0
# Episode 93/1000, Total Reward: 15.0
# Episode 93/1000, Total Reward: 15.0
# Episode 94/1000, Total Reward: 27.0
# Episode 94/1000, Total Reward: 27.0
# Episode 95/1000, Total Reward: 30.0
# Episode 95/1000, Total Reward: 30.0
# Episode 96/1000, Total Reward: 26.0
# Episode 96/1000, Total Reward: 26.0
# Episode 97/1000, Total Reward: 19.0
# Episode 97/1000, Total Reward: 19.0
# Episode 98/1000, Total Reward: 17.0
# Episode 98/1000, Total Reward: 17.0
# Episode 99/1000, Total Reward: 13.0
# Episode 99/1000, Total Reward: 13.0
# Episode 100/1000, Total Reward: 19.0
# Episode 100/1000, Total Reward: 19.0, Average Reward: 20.46
# Episode 101/1000, Total Reward: 14.0
# Episode 101/1000, Total Reward: 14.0, Average Reward: 20.43
# Episode 102/1000, Total Reward: 36.0
# Episode 102/1000, Total Reward: 36.0, Average Reward: 20.59
# Episode 103/1000, Total Reward: 15.0
# Episode 103/1000, Total Reward: 15.0, Average Reward: 20.65
# Episode 104/1000, Total Reward: 25.0
# Episode 104/1000, Total Reward: 25.0, Average Reward: 20.78
# Episode 105/1000, Total Reward: 11.0
# Episode 105/1000, Total Reward: 11.0, Average Reward: 20.74
# Episode 106/1000, Total Reward: 10.0
# Episode 106/1000, Total Reward: 10.0, Average Reward: 20.66
# Episode 107/1000, Total Reward: 19.0
# Episode 107/1000, Total Reward: 19.0, Average Reward: 20.58
# Episode 108/1000, Total Reward: 20.0
# Episode 108/1000, Total Reward: 20.0, Average Reward: 20.55
# Episode 109/1000, Total Reward: 19.0
# Episode 109/1000, Total Reward: 19.0, Average Reward: 20.54
# Episode 110/1000, Total Reward: 47.0
# Episode 110/1000, Total Reward: 47.0, Average Reward: 20.76
# Episode 111/1000, Total Reward: 27.0
# Episode 111/1000, Total Reward: 27.0, Average Reward: 20.93
# Episode 112/1000, Total Reward: 29.0
# Episode 112/1000, Total Reward: 29.0, Average Reward: 21.04
# Episode 113/1000, Total Reward: 14.0
# Episode 113/1000, Total Reward: 14.0, Average Reward: 21.02
# Episode 114/1000, Total Reward: 24.0
# Episode 114/1000, Total Reward: 24.0, Average Reward: 20.72
# Episode 115/1000, Total Reward: 15.0
# Episode 115/1000, Total Reward: 15.0, Average Reward: 20.76
# Episode 116/1000, Total Reward: 16.0
# Episode 116/1000, Total Reward: 16.0, Average Reward: 20.79
# Episode 117/1000, Total Reward: 13.0
# Episode 117/1000, Total Reward: 13.0, Average Reward: 20.76
# Episode 118/1000, Total Reward: 16.0
# Episode 118/1000, Total Reward: 16.0, Average Reward: 20.57
# Episode 119/1000, Total Reward: 16.0
# Episode 119/1000, Total Reward: 16.0, Average Reward: 20.54
# Episode 120/1000, Total Reward: 19.0
# Episode 120/1000, Total Reward: 19.0, Average Reward: 20.6
# Episode 121/1000, Total Reward: 19.0
# Episode 121/1000, Total Reward: 19.0, Average Reward: 20.61
# Episode 122/1000, Total Reward: 10.0
# Episode 122/1000, Total Reward: 10.0, Average Reward: 20.55
# Episode 123/1000, Total Reward: 12.0
# Episode 123/1000, Total Reward: 12.0, Average Reward: 20.52
# Episode 124/1000, Total Reward: 25.0
# Episode 124/1000, Total Reward: 25.0, Average Reward: 20.55
# Episode 125/1000, Total Reward: 9.0
# Episode 125/1000, Total Reward: 9.0, Average Reward: 20.39
# Episode 126/1000, Total Reward: 37.0
# Episode 126/1000, Total Reward: 37.0, Average Reward: 20.61
# Episode 127/1000, Total Reward: 16.0
# Episode 127/1000, Total Reward: 16.0, Average Reward: 20.56
# Episode 128/1000, Total Reward: 42.0
# Episode 128/1000, Total Reward: 42.0, Average Reward: 20.85
# Episode 129/1000, Total Reward: 20.0
# Episode 129/1000, Total Reward: 20.0, Average Reward: 20.85
# Episode 130/1000, Total Reward: 9.0
# Episode 130/1000, Total Reward: 9.0, Average Reward: 20.7
# Episode 131/1000, Total Reward: 30.0
# Episode 131/1000, Total Reward: 30.0, Average Reward: 20.87
# Episode 132/1000, Total Reward: 19.0
# Episode 132/1000, Total Reward: 19.0, Average Reward: 20.8
# Episode 133/1000, Total Reward: 20.0
# Episode 133/1000, Total Reward: 20.0, Average Reward: 20.73
# Episode 134/1000, Total Reward: 15.0
# Episode 134/1000, Total Reward: 15.0, Average Reward: 20.72
# Episode 135/1000, Total Reward: 15.0
# Episode 135/1000, Total Reward: 15.0, Average Reward: 20.64
# Episode 136/1000, Total Reward: 17.0
# Episode 136/1000, Total Reward: 17.0, Average Reward: 20.68
# Episode 137/1000, Total Reward: 40.0
# Episode 137/1000, Total Reward: 40.0, Average Reward: 20.82
# Episode 138/1000, Total Reward: 17.0
# Episode 138/1000, Total Reward: 17.0, Average Reward: 20.76
# Episode 139/1000, Total Reward: 46.0
# Episode 139/1000, Total Reward: 46.0, Average Reward: 21.05
# Episode 140/1000, Total Reward: 41.0
# Episode 140/1000, Total Reward: 41.0, Average Reward: 20.92
# Episode 141/1000, Total Reward: 15.0
# Episode 141/1000, Total Reward: 15.0, Average Reward: 20.9
# Episode 142/1000, Total Reward: 36.0
# Episode 142/1000, Total Reward: 36.0, Average Reward: 21.14
# Episode 143/1000, Total Reward: 81.0
# Episode 143/1000, Total Reward: 81.0, Average Reward: 21.83
# Episode 144/1000, Total Reward: 13.0
# Episode 144/1000, Total Reward: 13.0, Average Reward: 21.75
# Episode 145/1000, Total Reward: 10.0
# Episode 145/1000, Total Reward: 10.0, Average Reward: 21.61
# Episode 146/1000, Total Reward: 47.0
# Episode 146/1000, Total Reward: 47.0, Average Reward: 21.94
# Episode 147/1000, Total Reward: 15.0
# Episode 147/1000, Total Reward: 15.0, Average Reward: 21.86
# Episode 148/1000, Total Reward: 69.0
# Episode 148/1000, Total Reward: 69.0, Average Reward: 22.39
# Episode 149/1000, Total Reward: 25.0
# Episode 149/1000, Total Reward: 25.0, Average Reward: 22.54
# Episode 150/1000, Total Reward: 14.0
# Episode 150/1000, Total Reward: 14.0, Average Reward: 22.47
# Episode 151/1000, Total Reward: 33.0
# Episode 151/1000, Total Reward: 33.0, Average Reward: 22.58
# Episode 152/1000, Total Reward: 45.0
# Episode 152/1000, Total Reward: 45.0, Average Reward: 22.65
# Episode 153/1000, Total Reward: 10.0
# Episode 153/1000, Total Reward: 10.0, Average Reward: 22.49
# Episode 154/1000, Total Reward: 36.0
# Episode 154/1000, Total Reward: 36.0, Average Reward: 22.75
# Episode 155/1000, Total Reward: 25.0
# Episode 155/1000, Total Reward: 25.0, Average Reward: 22.7
# Episode 156/1000, Total Reward: 20.0
# Episode 156/1000, Total Reward: 20.0, Average Reward: 22.75
# Episode 157/1000, Total Reward: 28.0
# Episode 157/1000, Total Reward: 28.0, Average Reward: 22.86
# Episode 158/1000, Total Reward: 44.0
# Episode 158/1000, Total Reward: 44.0, Average Reward: 23.2
# Episode 159/1000, Total Reward: 27.0
# Episode 159/1000, Total Reward: 27.0, Average Reward: 23.24
# Episode 160/1000, Total Reward: 23.0
# Episode 160/1000, Total Reward: 23.0, Average Reward: 23.31
# Episode 161/1000, Total Reward: 57.0
# Episode 161/1000, Total Reward: 57.0, Average Reward: 23.73
# Episode 162/1000, Total Reward: 37.0
# Episode 162/1000, Total Reward: 37.0, Average Reward: 23.88
# Episode 163/1000, Total Reward: 11.0
# Episode 163/1000, Total Reward: 11.0, Average Reward: 23.84
# Episode 164/1000, Total Reward: 45.0
# Episode 164/1000, Total Reward: 45.0, Average Reward: 24.15
# Episode 165/1000, Total Reward: 21.0
# Episode 165/1000, Total Reward: 21.0, Average Reward: 23.87
# Episode 166/1000, Total Reward: 20.0
# Episode 166/1000, Total Reward: 20.0, Average Reward: 23.91
# Episode 167/1000, Total Reward: 18.0
# Episode 167/1000, Total Reward: 18.0, Average Reward: 23.93
# Episode 168/1000, Total Reward: 27.0
# Episode 168/1000, Total Reward: 27.0, Average Reward: 23.94
# Episode 169/1000, Total Reward: 16.0
# Episode 169/1000, Total Reward: 16.0, Average Reward: 23.97
# Episode 170/1000, Total Reward: 39.0
# Episode 170/1000, Total Reward: 39.0, Average Reward: 24.12
# Episode 171/1000, Total Reward: 29.0
# Episode 171/1000, Total Reward: 29.0, Average Reward: 24.25
# Episode 172/1000, Total Reward: 40.0
# Episode 172/1000, Total Reward: 40.0, Average Reward: 24.3
# Episode 173/1000, Total Reward: 26.0
# Episode 173/1000, Total Reward: 26.0, Average Reward: 24.37
# Episode 174/1000, Total Reward: 25.0
# Episode 174/1000, Total Reward: 25.0, Average Reward: 24.42
# Episode 175/1000, Total Reward: 22.0
# Episode 175/1000, Total Reward: 22.0, Average Reward: 24.43
# Episode 176/1000, Total Reward: 51.0
# Episode 176/1000, Total Reward: 51.0, Average Reward: 24.69
# Episode 177/1000, Total Reward: 22.0
# Episode 177/1000, Total Reward: 22.0, Average Reward: 24.72
# Episode 178/1000, Total Reward: 60.0
# Episode 178/1000, Total Reward: 60.0, Average Reward: 25.21
# Episode 179/1000, Total Reward: 26.0
# Episode 179/1000, Total Reward: 26.0, Average Reward: 25.21
# Episode 180/1000, Total Reward: 22.0
# Episode 180/1000, Total Reward: 22.0, Average Reward: 25.3
# Episode 181/1000, Total Reward: 26.0
# Episode 181/1000, Total Reward: 26.0, Average Reward: 25.42
# Episode 182/1000, Total Reward: 62.0
# Episode 182/1000, Total Reward: 62.0, Average Reward: 25.8
# Episode 183/1000, Total Reward: 33.0
# Episode 183/1000, Total Reward: 33.0, Average Reward: 25.81
# Episode 184/1000, Total Reward: 27.0
# Episode 184/1000, Total Reward: 27.0, Average Reward: 25.96
# Episode 185/1000, Total Reward: 24.0
# Episode 185/1000, Total Reward: 24.0, Average Reward: 25.49
# Episode 186/1000, Total Reward: 22.0
# Episode 186/1000, Total Reward: 22.0, Average Reward: 25.54
# Episode 187/1000, Total Reward: 18.0
# Episode 187/1000, Total Reward: 18.0, Average Reward: 25.58
# Episode 188/1000, Total Reward: 49.0
# Episode 188/1000, Total Reward: 49.0, Average Reward: 25.95
# Episode 189/1000, Total Reward: 12.0
# Episode 189/1000, Total Reward: 12.0, Average Reward: 25.74
# Episode 190/1000, Total Reward: 21.0
# Episode 190/1000, Total Reward: 21.0, Average Reward: 25.86
# Episode 191/1000, Total Reward: 79.0
# Episode 191/1000, Total Reward: 79.0, Average Reward: 26.5
# Episode 192/1000, Total Reward: 29.0
# Episode 192/1000, Total Reward: 29.0, Average Reward: 26.62
# Episode 193/1000, Total Reward: 42.0
# Episode 193/1000, Total Reward: 42.0, Average Reward: 26.89
# Episode 194/1000, Total Reward: 33.0
# Episode 194/1000, Total Reward: 33.0, Average Reward: 26.95
# Episode 195/1000, Total Reward: 24.0
# Episode 195/1000, Total Reward: 24.0, Average Reward: 26.89
# Episode 196/1000, Total Reward: 46.0
# Episode 196/1000, Total Reward: 46.0, Average Reward: 27.09
# Episode 197/1000, Total Reward: 31.0
# Episode 197/1000, Total Reward: 31.0, Average Reward: 27.21
# Episode 198/1000, Total Reward: 13.0
# Episode 198/1000, Total Reward: 13.0, Average Reward: 27.17
# Episode 199/1000, Total Reward: 25.0
# Episode 199/1000, Total Reward: 25.0, Average Reward: 27.29
# Episode 200/1000, Total Reward: 24.0
# Episode 200/1000, Total Reward: 24.0, Average Reward: 27.34
# Episode 201/1000, Total Reward: 13.0
# Episode 201/1000, Total Reward: 13.0, Average Reward: 27.33
# Episode 202/1000, Total Reward: 45.0
# Episode 202/1000, Total Reward: 45.0, Average Reward: 27.42
# Episode 203/1000, Total Reward: 56.0
# Episode 203/1000, Total Reward: 56.0, Average Reward: 27.83
# Episode 204/1000, Total Reward: 19.0
# Episode 204/1000, Total Reward: 19.0, Average Reward: 27.77
# Episode 205/1000, Total Reward: 58.0
# Episode 205/1000, Total Reward: 58.0, Average Reward: 28.24
# Episode 206/1000, Total Reward: 38.0
# Episode 206/1000, Total Reward: 38.0, Average Reward: 28.52
# Episode 207/1000, Total Reward: 15.0
# Episode 207/1000, Total Reward: 15.0, Average Reward: 28.48
# Episode 208/1000, Total Reward: 25.0
# Episode 208/1000, Total Reward: 25.0, Average Reward: 28.53
# Episode 209/1000, Total Reward: 52.0
# Episode 209/1000, Total Reward: 52.0, Average Reward: 28.86
# Episode 210/1000, Total Reward: 47.0
# Episode 210/1000, Total Reward: 47.0, Average Reward: 28.86
# Episode 211/1000, Total Reward: 30.0
# Episode 211/1000, Total Reward: 30.0, Average Reward: 28.89
# Episode 212/1000, Total Reward: 35.0
# Episode 212/1000, Total Reward: 35.0, Average Reward: 28.95
# Episode 213/1000, Total Reward: 48.0
# Episode 213/1000, Total Reward: 48.0, Average Reward: 29.29
# Episode 214/1000, Total Reward: 28.0
# Episode 214/1000, Total Reward: 28.0, Average Reward: 29.33
# Episode 215/1000, Total Reward: 37.0
# Episode 215/1000, Total Reward: 37.0, Average Reward: 29.55
# Episode 216/1000, Total Reward: 67.0
# Episode 216/1000, Total Reward: 67.0, Average Reward: 30.06
# Episode 217/1000, Total Reward: 37.0
# Episode 217/1000, Total Reward: 37.0, Average Reward: 30.3
# Episode 218/1000, Total Reward: 106.0
# Episode 218/1000, Total Reward: 106.0, Average Reward: 31.2
# Episode 219/1000, Total Reward: 45.0
# Episode 219/1000, Total Reward: 45.0, Average Reward: 31.49
# Episode 220/1000, Total Reward: 36.0
# Episode 220/1000, Total Reward: 36.0, Average Reward: 31.66
# Episode 221/1000, Total Reward: 34.0
# Episode 221/1000, Total Reward: 34.0, Average Reward: 31.81
# Episode 222/1000, Total Reward: 95.0
# Episode 222/1000, Total Reward: 95.0, Average Reward: 32.66
# Episode 223/1000, Total Reward: 55.0
# Episode 223/1000, Total Reward: 55.0, Average Reward: 33.09
# Episode 224/1000, Total Reward: 75.0
# Episode 224/1000, Total Reward: 75.0, Average Reward: 33.59
# Episode 225/1000, Total Reward: 45.0
# Episode 225/1000, Total Reward: 45.0, Average Reward: 33.95
# Episode 226/1000, Total Reward: 120.0
# Episode 226/1000, Total Reward: 120.0, Average Reward: 34.78
# Episode 227/1000, Total Reward: 81.0
# Episode 227/1000, Total Reward: 81.0, Average Reward: 35.43
# Episode 228/1000, Total Reward: 31.0
# Episode 228/1000, Total Reward: 31.0, Average Reward: 35.32
# Episode 229/1000, Total Reward: 37.0
# Episode 229/1000, Total Reward: 37.0, Average Reward: 35.49
# Episode 230/1000, Total Reward: 50.0
# Episode 230/1000, Total Reward: 50.0, Average Reward: 35.9
# Episode 231/1000, Total Reward: 19.0
# Episode 231/1000, Total Reward: 19.0, Average Reward: 35.79
# Episode 232/1000, Total Reward: 41.0
# Episode 232/1000, Total Reward: 41.0, Average Reward: 36.01
# Episode 233/1000, Total Reward: 104.0
# Episode 233/1000, Total Reward: 104.0, Average Reward: 36.85
# Episode 234/1000, Total Reward: 16.0
# Episode 234/1000, Total Reward: 16.0, Average Reward: 36.86
# Episode 235/1000, Total Reward: 41.0
# Episode 235/1000, Total Reward: 41.0, Average Reward: 37.12
# Episode 236/1000, Total Reward: 90.0
# Episode 236/1000, Total Reward: 90.0, Average Reward: 37.85
# Episode 237/1000, Total Reward: 74.0
# Episode 237/1000, Total Reward: 74.0, Average Reward: 38.19
# Episode 238/1000, Total Reward: 64.0
# Episode 238/1000, Total Reward: 64.0, Average Reward: 38.66
# Episode 239/1000, Total Reward: 41.0
# Episode 239/1000, Total Reward: 41.0, Average Reward: 38.61
# Episode 240/1000, Total Reward: 38.0
# Episode 240/1000, Total Reward: 38.0, Average Reward: 38.58
# Episode 241/1000, Total Reward: 149.0
# Episode 241/1000, Total Reward: 149.0, Average Reward: 39.92
# Episode 242/1000, Total Reward: 27.0
# Episode 242/1000, Total Reward: 27.0, Average Reward: 39.83
# Episode 243/1000, Total Reward: 46.0
# Episode 243/1000, Total Reward: 46.0, Average Reward: 39.48
# Episode 244/1000, Total Reward: 57.0
# Episode 244/1000, Total Reward: 57.0, Average Reward: 39.92
# Episode 245/1000, Total Reward: 33.0
# Episode 245/1000, Total Reward: 33.0, Average Reward: 40.15
# Episode 246/1000, Total Reward: 68.0
# Episode 246/1000, Total Reward: 68.0, Average Reward: 40.36
# Episode 247/1000, Total Reward: 40.0
# Episode 247/1000, Total Reward: 40.0, Average Reward: 40.61
# Episode 248/1000, Total Reward: 154.0
# Episode 248/1000, Total Reward: 154.0, Average Reward: 41.46
# Episode 249/1000, Total Reward: 58.0
# Episode 249/1000, Total Reward: 58.0, Average Reward: 41.79
# Episode 250/1000, Total Reward: 204.0
# Episode 250/1000, Total Reward: 204.0, Average Reward: 43.69
# Episode 251/1000, Total Reward: 44.0
# Episode 251/1000, Total Reward: 44.0, Average Reward: 43.8
# Episode 252/1000, Total Reward: 83.0
# Episode 252/1000, Total Reward: 83.0, Average Reward: 44.18
# Episode 253/1000, Total Reward: 54.0
# Episode 253/1000, Total Reward: 54.0, Average Reward: 44.62
# Episode 254/1000, Total Reward: 104.0
# Episode 254/1000, Total Reward: 104.0, Average Reward: 45.3
# Episode 255/1000, Total Reward: 29.0
# Episode 255/1000, Total Reward: 29.0, Average Reward: 45.34
# Episode 256/1000, Total Reward: 25.0
# Episode 256/1000, Total Reward: 25.0, Average Reward: 45.39
# Episode 257/1000, Total Reward: 68.0
# Episode 257/1000, Total Reward: 68.0, Average Reward: 45.79
# Episode 258/1000, Total Reward: 88.0
# Episode 258/1000, Total Reward: 88.0, Average Reward: 46.23
# Episode 259/1000, Total Reward: 64.0
# Episode 259/1000, Total Reward: 64.0, Average Reward: 46.6
# Episode 260/1000, Total Reward: 52.0
# Episode 260/1000, Total Reward: 52.0, Average Reward: 46.89
# Episode 261/1000, Total Reward: 49.0
# Episode 261/1000, Total Reward: 49.0, Average Reward: 46.81
# Episode 262/1000, Total Reward: 124.0
# Episode 262/1000, Total Reward: 124.0, Average Reward: 47.68
# Episode 263/1000, Total Reward: 45.0
# Episode 263/1000, Total Reward: 45.0, Average Reward: 48.02
# Episode 264/1000, Total Reward: 127.0
# Episode 264/1000, Total Reward: 127.0, Average Reward: 48.84
# Episode 265/1000, Total Reward: 116.0
# Episode 265/1000, Total Reward: 116.0, Average Reward: 49.79
# Episode 266/1000, Total Reward: 58.0
# Episode 266/1000, Total Reward: 58.0, Average Reward: 50.17
# Episode 267/1000, Total Reward: 163.0
# Episode 267/1000, Total Reward: 163.0, Average Reward: 51.62
# Episode 268/1000, Total Reward: 59.0
# Episode 268/1000, Total Reward: 59.0, Average Reward: 51.94
# Episode 269/1000, Total Reward: 71.0
# Episode 269/1000, Total Reward: 71.0, Average Reward: 52.49
# Episode 270/1000, Total Reward: 30.0
# Episode 270/1000, Total Reward: 30.0, Average Reward: 52.4
# Episode 271/1000, Total Reward: 47.0
# Episode 271/1000, Total Reward: 47.0, Average Reward: 52.58
# Episode 272/1000, Total Reward: 87.0
# Episode 272/1000, Total Reward: 87.0, Average Reward: 53.05
# Episode 273/1000, Total Reward: 108.0
# Episode 273/1000, Total Reward: 108.0, Average Reward: 53.87
# Episode 274/1000, Total Reward: 53.0
# Episode 274/1000, Total Reward: 53.0, Average Reward: 54.15
# Episode 275/1000, Total Reward: 68.0
# Episode 275/1000, Total Reward: 68.0, Average Reward: 54.61
# Episode 276/1000, Total Reward: 41.0
# Episode 276/1000, Total Reward: 41.0, Average Reward: 54.51
# Episode 277/1000, Total Reward: 118.0
# Episode 277/1000, Total Reward: 118.0, Average Reward: 55.47
# Episode 278/1000, Total Reward: 100.0
# Episode 278/1000, Total Reward: 100.0, Average Reward: 55.87
# Episode 279/1000, Total Reward: 51.0
# Episode 279/1000, Total Reward: 51.0, Average Reward: 56.12
# Episode 280/1000, Total Reward: 59.0
# Episode 280/1000, Total Reward: 59.0, Average Reward: 56.49
# Episode 281/1000, Total Reward: 90.0
# Episode 281/1000, Total Reward: 90.0, Average Reward: 57.13
# Episode 282/1000, Total Reward: 161.0
# Episode 282/1000, Total Reward: 161.0, Average Reward: 58.12
# Episode 283/1000, Total Reward: 133.0
# Episode 283/1000, Total Reward: 133.0, Average Reward: 59.12
# Episode 284/1000, Total Reward: 87.0
# Episode 284/1000, Total Reward: 87.0, Average Reward: 59.72
# Episode 285/1000, Total Reward: 126.0
# Episode 285/1000, Total Reward: 126.0, Average Reward: 60.74
# Episode 286/1000, Total Reward: 49.0
# Episode 286/1000, Total Reward: 49.0, Average Reward: 61.01
# Episode 287/1000, Total Reward: 137.0
# Episode 287/1000, Total Reward: 137.0, Average Reward: 62.2
# Episode 288/1000, Total Reward: 67.0
# Episode 288/1000, Total Reward: 67.0, Average Reward: 62.38
# Episode 289/1000, Total Reward: 133.0
# Episode 289/1000, Total Reward: 133.0, Average Reward: 63.59
# Episode 290/1000, Total Reward: 72.0
# Episode 290/1000, Total Reward: 72.0, Average Reward: 64.1
# Episode 291/1000, Total Reward: 62.0
# Episode 291/1000, Total Reward: 62.0, Average Reward: 63.93
# Episode 292/1000, Total Reward: 216.0
# Episode 292/1000, Total Reward: 216.0, Average Reward: 65.8
# Episode 293/1000, Total Reward: 25.0
# Episode 293/1000, Total Reward: 25.0, Average Reward: 65.63
# Episode 294/1000, Total Reward: 255.0
# Episode 294/1000, Total Reward: 255.0, Average Reward: 67.85
# Episode 295/1000, Total Reward: 108.0
# Episode 295/1000, Total Reward: 108.0, Average Reward: 68.69
# Episode 296/1000, Total Reward: 31.0
# Episode 296/1000, Total Reward: 31.0, Average Reward: 68.54
# Episode 297/1000, Total Reward: 106.0
# Episode 297/1000, Total Reward: 106.0, Average Reward: 69.29
# Episode 298/1000, Total Reward: 116.0
# Episode 298/1000, Total Reward: 116.0, Average Reward: 70.32
# Episode 299/1000, Total Reward: 93.0
# Episode 299/1000, Total Reward: 93.0, Average Reward: 71.0
# Episode 300/1000, Total Reward: 132.0
# Episode 300/1000, Total Reward: 132.0, Average Reward: 72.08
# Episode 301/1000, Total Reward: 129.0
# Episode 301/1000, Total Reward: 129.0, Average Reward: 73.24
# Episode 302/1000, Total Reward: 184.0
# Episode 302/1000, Total Reward: 184.0, Average Reward: 74.63
# Episode 303/1000, Total Reward: 83.0
# Episode 303/1000, Total Reward: 83.0, Average Reward: 74.9
# Episode 304/1000, Total Reward: 176.0
# Episode 304/1000, Total Reward: 176.0, Average Reward: 76.47
# Episode 305/1000, Total Reward: 182.0
# Episode 305/1000, Total Reward: 182.0, Average Reward: 77.71
# Episode 306/1000, Total Reward: 282.0
# Episode 306/1000, Total Reward: 282.0, Average Reward: 80.15
# Episode 307/1000, Total Reward: 248.0
# Episode 307/1000, Total Reward: 248.0, Average Reward: 82.48
# Episode 308/1000, Total Reward: 160.0
# Episode 308/1000, Total Reward: 160.0, Average Reward: 83.83
# Episode 309/1000, Total Reward: 118.0
# Episode 309/1000, Total Reward: 118.0, Average Reward: 84.49
# Episode 310/1000, Total Reward: 111.0
# Episode 310/1000, Total Reward: 111.0, Average Reward: 85.13
# Episode 311/1000, Total Reward: 253.0
# Episode 311/1000, Total Reward: 253.0, Average Reward: 87.36
# Episode 312/1000, Total Reward: 154.0
# Episode 312/1000, Total Reward: 154.0, Average Reward: 88.55
# Episode 313/1000, Total Reward: 195.0
# Episode 313/1000, Total Reward: 195.0, Average Reward: 90.02
# Episode 314/1000, Total Reward: 174.0
# Episode 314/1000, Total Reward: 174.0, Average Reward: 91.48
# Episode 315/1000, Total Reward: 170.0
# Episode 315/1000, Total Reward: 170.0, Average Reward: 92.81
# Episode 316/1000, Total Reward: 90.0
# Episode 316/1000, Total Reward: 90.0, Average Reward: 93.04
# Episode 317/1000, Total Reward: 130.0
# Episode 317/1000, Total Reward: 130.0, Average Reward: 93.97
# Episode 318/1000, Total Reward: 32.0
# Episode 318/1000, Total Reward: 32.0, Average Reward: 93.23
# Episode 319/1000, Total Reward: 216.0
# Episode 319/1000, Total Reward: 216.0, Average Reward: 94.94
# Episode 320/1000, Total Reward: 276.0
# Episode 320/1000, Total Reward: 276.0, Average Reward: 97.34
# Episode 321/1000, Total Reward: 79.0
# Episode 321/1000, Total Reward: 79.0, Average Reward: 97.79
# Episode 322/1000, Total Reward: 500.0
# Episode 322/1000, Total Reward: 500.0, Average Reward: 101.84
# Episode 323/1000, Total Reward: 136.0
# Episode 323/1000, Total Reward: 136.0, Average Reward: 102.65
# Episode 324/1000, Total Reward: 144.0
# Episode 324/1000, Total Reward: 144.0, Average Reward: 103.34
# Episode 325/1000, Total Reward: 175.0
# Episode 325/1000, Total Reward: 175.0, Average Reward: 104.64
# Episode 326/1000, Total Reward: 283.0
# Episode 326/1000, Total Reward: 283.0, Average Reward: 106.27
# Episode 327/1000, Total Reward: 317.0
# Episode 327/1000, Total Reward: 317.0, Average Reward: 108.63
# Episode 328/1000, Total Reward: 302.0
# Episode 328/1000, Total Reward: 302.0, Average Reward: 111.34
# Episode 329/1000, Total Reward: 117.0
# Episode 329/1000, Total Reward: 117.0, Average Reward: 112.14
# Episode 330/1000, Total Reward: 234.0
# Episode 330/1000, Total Reward: 234.0, Average Reward: 113.98
# Episode 331/1000, Total Reward: 249.0
# Episode 331/1000, Total Reward: 249.0, Average Reward: 116.28
# Episode 332/1000, Total Reward: 324.0
# Episode 332/1000, Total Reward: 324.0, Average Reward: 119.11
# Episode 333/1000, Total Reward: 297.0
# Episode 333/1000, Total Reward: 297.0, Average Reward: 121.04
# Episode 334/1000, Total Reward: 121.0
# Episode 334/1000, Total Reward: 121.0, Average Reward: 122.09
# Episode 335/1000, Total Reward: 195.0
# Episode 335/1000, Total Reward: 195.0, Average Reward: 123.63
# Episode 336/1000, Total Reward: 264.0
# Episode 336/1000, Total Reward: 264.0, Average Reward: 125.37
# Episode 337/1000, Total Reward: 497.0
# Episode 337/1000, Total Reward: 497.0, Average Reward: 129.6
# Episode 338/1000, Total Reward: 156.0
# Episode 338/1000, Total Reward: 156.0, Average Reward: 130.52
# Episode 339/1000, Total Reward: 154.0
# Episode 339/1000, Total Reward: 154.0, Average Reward: 131.65
# Episode 340/1000, Total Reward: 118.0
# Episode 340/1000, Total Reward: 118.0, Average Reward: 132.45
# Episode 341/1000, Total Reward: 203.0
# Episode 341/1000, Total Reward: 203.0, Average Reward: 132.99
# Episode 342/1000, Total Reward: 180.0
# Episode 342/1000, Total Reward: 180.0, Average Reward: 134.52
# Episode 343/1000, Total Reward: 110.0
# Episode 343/1000, Total Reward: 110.0, Average Reward: 135.16
# Episode 344/1000, Total Reward: 291.0
# Episode 344/1000, Total Reward: 291.0, Average Reward: 137.5
# Episode 345/1000, Total Reward: 304.0
# Episode 345/1000, Total Reward: 304.0, Average Reward: 140.21
# Episode 346/1000, Total Reward: 294.0
# Episode 346/1000, Total Reward: 294.0, Average Reward: 142.47
# Episode 347/1000, Total Reward: 217.0
# Episode 347/1000, Total Reward: 217.0, Average Reward: 144.24
# Episode 348/1000, Total Reward: 374.0
# Episode 348/1000, Total Reward: 374.0, Average Reward: 146.44
# Episode 349/1000, Total Reward: 151.0
# Episode 349/1000, Total Reward: 151.0, Average Reward: 147.37
# Episode 350/1000, Total Reward: 165.0
# Episode 350/1000, Total Reward: 165.0, Average Reward: 146.98
# Episode 351/1000, Total Reward: 321.0
# Episode 351/1000, Total Reward: 321.0, Average Reward: 149.75
# Episode 352/1000, Total Reward: 300.0
# Episode 352/1000, Total Reward: 300.0, Average Reward: 151.92
# Episode 353/1000, Total Reward: 414.0
# Episode 353/1000, Total Reward: 414.0, Average Reward: 155.52
# Episode 354/1000, Total Reward: 194.0
# Episode 354/1000, Total Reward: 194.0, Average Reward: 156.42
# Episode 355/1000, Total Reward: 229.0
# Episode 355/1000, Total Reward: 229.0, Average Reward: 158.42
# Episode 356/1000, Total Reward: 176.0
# Episode 356/1000, Total Reward: 176.0, Average Reward: 159.93
# Episode 357/1000, Total Reward: 52.0
# Episode 357/1000, Total Reward: 52.0, Average Reward: 159.77
# Episode 358/1000, Total Reward: 156.0
# Episode 358/1000, Total Reward: 156.0, Average Reward: 160.45
# Episode 359/1000, Total Reward: 213.0
# Episode 359/1000, Total Reward: 213.0, Average Reward: 161.94
# Episode 360/1000, Total Reward: 190.0
# Episode 360/1000, Total Reward: 190.0, Average Reward: 163.32
# Episode 361/1000, Total Reward: 241.0
# Episode 361/1000, Total Reward: 241.0, Average Reward: 165.24
# Episode 362/1000, Total Reward: 136.0
# Episode 362/1000, Total Reward: 136.0, Average Reward: 165.36
# Episode 363/1000, Total Reward: 221.0
# Episode 363/1000, Total Reward: 221.0, Average Reward: 167.12
# Episode 364/1000, Total Reward: 245.0
# Episode 364/1000, Total Reward: 245.0, Average Reward: 168.3
# Episode 365/1000, Total Reward: 354.0
# Episode 365/1000, Total Reward: 354.0, Average Reward: 170.68
# Episode 366/1000, Total Reward: 375.0
# Episode 366/1000, Total Reward: 375.0, Average Reward: 173.85
# Episode 367/1000, Total Reward: 182.0
# Episode 367/1000, Total Reward: 182.0, Average Reward: 174.04
# Episode 368/1000, Total Reward: 157.0
# Episode 368/1000, Total Reward: 157.0, Average Reward: 175.02
# Episode 369/1000, Total Reward: 163.0
# Episode 369/1000, Total Reward: 163.0, Average Reward: 175.94
# Episode 370/1000, Total Reward: 258.0
# Episode 370/1000, Total Reward: 258.0, Average Reward: 178.22
# Episode 371/1000, Total Reward: 257.0
# Episode 371/1000, Total Reward: 257.0, Average Reward: 180.32
# Episode 372/1000, Total Reward: 182.0
# Episode 372/1000, Total Reward: 182.0, Average Reward: 181.27
# Episode 373/1000, Total Reward: 192.0
# Episode 373/1000, Total Reward: 192.0, Average Reward: 182.11
# Episode 374/1000, Total Reward: 138.0
# Episode 374/1000, Total Reward: 138.0, Average Reward: 182.96
# Episode 375/1000, Total Reward: 146.0
# Episode 375/1000, Total Reward: 146.0, Average Reward: 183.74
# Episode 376/1000, Total Reward: 111.0
# Episode 376/1000, Total Reward: 111.0, Average Reward: 184.44
# Episode 377/1000, Total Reward: 208.0
# Episode 377/1000, Total Reward: 208.0, Average Reward: 185.34
# Episode 378/1000, Total Reward: 183.0
# Episode 378/1000, Total Reward: 183.0, Average Reward: 186.17
# Episode 379/1000, Total Reward: 265.0
# Episode 379/1000, Total Reward: 265.0, Average Reward: 188.31
# Episode 380/1000, Total Reward: 21.0
# Episode 380/1000, Total Reward: 21.0, Average Reward: 187.93
# Episode 381/1000, Total Reward: 180.0
# Episode 381/1000, Total Reward: 180.0, Average Reward: 188.83
# Episode 382/1000, Total Reward: 135.0
# Episode 382/1000, Total Reward: 135.0, Average Reward: 188.57
# Episode 383/1000, Total Reward: 200.0
# Episode 383/1000, Total Reward: 200.0, Average Reward: 189.24
# Episode 384/1000, Total Reward: 301.0
# Episode 384/1000, Total Reward: 301.0, Average Reward: 191.38
# Episode 385/1000, Total Reward: 411.0
# Episode 385/1000, Total Reward: 411.0, Average Reward: 194.23
# Episode 386/1000, Total Reward: 218.0
# Episode 386/1000, Total Reward: 218.0, Average Reward: 195.92
# Episode 387/1000, Total Reward: 198.0
# Episode 387/1000, Total Reward: 198.0, Average Reward: 196.53
# Episode 388/1000, Total Reward: 189.0
# Episode 388/1000, Total Reward: 189.0, Average Reward: 197.75
# Episode 389/1000, Total Reward: 237.0
# Episode 389/1000, Total Reward: 237.0, Average Reward: 198.79
# Episode 390/1000, Total Reward: 500.0
# Episode 390/1000, Total Reward: 500.0, Average Reward: 203.07
# Episode 391/1000, Total Reward: 178.0
# Episode 391/1000, Total Reward: 178.0, Average Reward: 204.23
# Episode 392/1000, Total Reward: 171.0
# Episode 392/1000, Total Reward: 171.0, Average Reward: 203.78
# Episode 393/1000, Total Reward: 242.0
# Episode 393/1000, Total Reward: 242.0, Average Reward: 205.95
# Episode 394/1000, Total Reward: 178.0
# Episode 394/1000, Total Reward: 178.0, Average Reward: 205.18
# Episode 395/1000, Total Reward: 279.0
# Episode 395/1000, Total Reward: 279.0, Average Reward: 206.89
# Episode 396/1000, Total Reward: 477.0
# Episode 396/1000, Total Reward: 477.0, Average Reward: 211.35
# Episode 397/1000, Total Reward: 500.0
# Episode 397/1000, Total Reward: 500.0, Average Reward: 215.29
# Episode 398/1000, Total Reward: 236.0
# Episode 398/1000, Total Reward: 236.0, Average Reward: 216.49
# Episode 399/1000, Total Reward: 372.0
# Episode 399/1000, Total Reward: 372.0, Average Reward: 219.28
# Episode 400/1000, Total Reward: 440.0
# Episode 400/1000, Total Reward: 440.0, Average Reward: 222.36
# Episode 401/1000, Total Reward: 191.0
# Episode 401/1000, Total Reward: 191.0, Average Reward: 222.98
# Episode 402/1000, Total Reward: 456.0
# Episode 402/1000, Total Reward: 456.0, Average Reward: 225.7
# Episode 403/1000, Total Reward: 190.0
# Episode 403/1000, Total Reward: 190.0, Average Reward: 226.77
# Episode 404/1000, Total Reward: 405.0
# Episode 404/1000, Total Reward: 405.0, Average Reward: 229.06
# Episode 405/1000, Total Reward: 136.0
# Episode 405/1000, Total Reward: 136.0, Average Reward: 228.6
# Episode 406/1000, Total Reward: 394.0
# Episode 406/1000, Total Reward: 394.0, Average Reward: 229.72
# Episode 407/1000, Total Reward: 241.0
# Episode 407/1000, Total Reward: 241.0, Average Reward: 229.65
# Episode 408/1000, Total Reward: 500.0
# Episode 408/1000, Total Reward: 500.0, Average Reward: 233.05
# Episode 409/1000, Total Reward: 388.0
# Episode 409/1000, Total Reward: 388.0, Average Reward: 235.75
# Episode 410/1000, Total Reward: 357.0
# Episode 410/1000, Total Reward: 357.0, Average Reward: 238.21
# Episode 411/1000, Total Reward: 342.0
# Episode 411/1000, Total Reward: 342.0, Average Reward: 239.1
# Episode 412/1000, Total Reward: 265.0
# Episode 412/1000, Total Reward: 265.0, Average Reward: 240.21
# Episode 413/1000, Total Reward: 341.0
# Episode 413/1000, Total Reward: 341.0, Average Reward: 241.67
# Episode 414/1000, Total Reward: 163.0
# Episode 414/1000, Total Reward: 163.0, Average Reward: 241.56
# Episode 415/1000, Total Reward: 287.0
# Episode 415/1000, Total Reward: 287.0, Average Reward: 242.73
# Episode 416/1000, Total Reward: 273.0
# Episode 416/1000, Total Reward: 273.0, Average Reward: 244.56
# Episode 417/1000, Total Reward: 471.0
# Episode 417/1000, Total Reward: 471.0, Average Reward: 247.97
# Episode 418/1000, Total Reward: 159.0
# Episode 418/1000, Total Reward: 159.0, Average Reward: 249.24
# Episode 419/1000, Total Reward: 229.0
# Episode 419/1000, Total Reward: 229.0, Average Reward: 249.37
# Episode 420/1000, Total Reward: 241.0
# Episode 420/1000, Total Reward: 241.0, Average Reward: 249.02
# Episode 421/1000, Total Reward: 451.0
# Episode 421/1000, Total Reward: 451.0, Average Reward: 252.74
# Episode 422/1000, Total Reward: 307.0
# Episode 422/1000, Total Reward: 307.0, Average Reward: 250.81
# Episode 423/1000, Total Reward: 222.0
# Episode 423/1000, Total Reward: 222.0, Average Reward: 251.67
# Episode 424/1000, Total Reward: 388.0
# Episode 424/1000, Total Reward: 388.0, Average Reward: 254.11
# Episode 425/1000, Total Reward: 150.0
# Episode 425/1000, Total Reward: 150.0, Average Reward: 253.86
# Episode 426/1000, Total Reward: 213.0
# Episode 426/1000, Total Reward: 213.0, Average Reward: 253.16
# Episode 427/1000, Total Reward: 261.0
# Episode 427/1000, Total Reward: 261.0, Average Reward: 252.6
# Episode 428/1000, Total Reward: 349.0
# Episode 428/1000, Total Reward: 349.0, Average Reward: 253.07
# Episode 429/1000, Total Reward: 384.0
# Episode 429/1000, Total Reward: 384.0, Average Reward: 255.74
# Episode 430/1000, Total Reward: 369.0
# Episode 430/1000, Total Reward: 369.0, Average Reward: 257.09
# Episode 431/1000, Total Reward: 286.0
# Episode 431/1000, Total Reward: 286.0, Average Reward: 257.46
# Episode 432/1000, Total Reward: 282.0
# Episode 432/1000, Total Reward: 282.0, Average Reward: 257.04
# Episode 433/1000, Total Reward: 240.0
# Episode 433/1000, Total Reward: 240.0, Average Reward: 256.47
# Episode 434/1000, Total Reward: 233.0
# Episode 434/1000, Total Reward: 233.0, Average Reward: 257.59
# Episode 435/1000, Total Reward: 377.0
# Episode 435/1000, Total Reward: 377.0, Average Reward: 259.41
# Episode 436/1000, Total Reward: 161.0
# Episode 436/1000, Total Reward: 161.0, Average Reward: 258.38
# Episode 437/1000, Total Reward: 304.0
# Episode 437/1000, Total Reward: 304.0, Average Reward: 256.45
# Episode 438/1000, Total Reward: 497.0
# Episode 438/1000, Total Reward: 497.0, Average Reward: 259.86
# Episode 439/1000, Total Reward: 332.0
# Episode 439/1000, Total Reward: 332.0, Average Reward: 261.64
# Episode 440/1000, Total Reward: 219.0
# Episode 440/1000, Total Reward: 219.0, Average Reward: 262.65
# Episode 441/1000, Total Reward: 150.0
# Episode 441/1000, Total Reward: 150.0, Average Reward: 262.12
# Episode 442/1000, Total Reward: 305.0
# Episode 442/1000, Total Reward: 305.0, Average Reward: 263.37
# Episode 443/1000, Total Reward: 277.0
# Episode 443/1000, Total Reward: 277.0, Average Reward: 265.04
# Episode 444/1000, Total Reward: 250.0
# Episode 444/1000, Total Reward: 250.0, Average Reward: 264.63
# Episode 445/1000, Total Reward: 205.0
# Episode 445/1000, Total Reward: 205.0, Average Reward: 263.64
# Episode 446/1000, Total Reward: 357.0
# Episode 446/1000, Total Reward: 357.0, Average Reward: 264.27
# Episode 447/1000, Total Reward: 251.0
# Episode 447/1000, Total Reward: 251.0, Average Reward: 264.61
# Episode 448/1000, Total Reward: 412.0
# Episode 448/1000, Total Reward: 412.0, Average Reward: 264.99
# Episode 449/1000, Total Reward: 135.0
# Episode 449/1000, Total Reward: 135.0, Average Reward: 264.83
# Episode 450/1000, Total Reward: 285.0
# Episode 450/1000, Total Reward: 285.0, Average Reward: 266.03
# Episode 451/1000, Total Reward: 144.0
# Episode 451/1000, Total Reward: 144.0, Average Reward: 264.26
# Episode 452/1000, Total Reward: 165.0
# Episode 452/1000, Total Reward: 165.0, Average Reward: 262.91
# Episode 453/1000, Total Reward: 276.0
# Episode 453/1000, Total Reward: 276.0, Average Reward: 261.53
# Episode 454/1000, Total Reward: 192.0
# Episode 454/1000, Total Reward: 192.0, Average Reward: 261.51
# Episode 455/1000, Total Reward: 222.0
# Episode 455/1000, Total Reward: 222.0, Average Reward: 261.44
# Episode 456/1000, Total Reward: 208.0
# Episode 456/1000, Total Reward: 208.0, Average Reward: 261.76
# Episode 457/1000, Total Reward: 418.0
# Episode 457/1000, Total Reward: 418.0, Average Reward: 265.42
# Episode 458/1000, Total Reward: 331.0
# Episode 458/1000, Total Reward: 331.0, Average Reward: 267.17
# Episode 459/1000, Total Reward: 204.0
# Episode 459/1000, Total Reward: 204.0, Average Reward: 267.08
# Episode 460/1000, Total Reward: 305.0
# Episode 460/1000, Total Reward: 305.0, Average Reward: 268.23
# Episode 461/1000, Total Reward: 314.0
# Episode 461/1000, Total Reward: 314.0, Average Reward: 268.96
# Episode 462/1000, Total Reward: 500.0
# Episode 462/1000, Total Reward: 500.0, Average Reward: 272.6
# Episode 463/1000, Total Reward: 384.0
# Episode 463/1000, Total Reward: 384.0, Average Reward: 274.23
# Episode 464/1000, Total Reward: 249.0
# Episode 464/1000, Total Reward: 249.0, Average Reward: 274.27
# Episode 465/1000, Total Reward: 352.0
# Episode 465/1000, Total Reward: 352.0, Average Reward: 274.25
# Episode 466/1000, Total Reward: 205.0
# Episode 466/1000, Total Reward: 205.0, Average Reward: 272.55
# Episode 467/1000, Total Reward: 227.0
# Episode 467/1000, Total Reward: 227.0, Average Reward: 273.0
# Episode 468/1000, Total Reward: 473.0
# Episode 468/1000, Total Reward: 473.0, Average Reward: 276.16
# Episode 469/1000, Total Reward: 298.0
# Episode 469/1000, Total Reward: 298.0, Average Reward: 277.51
# Episode 470/1000, Total Reward: 500.0
# Episode 470/1000, Total Reward: 500.0, Average Reward: 279.93
# Episode 471/1000, Total Reward: 226.0
# Episode 471/1000, Total Reward: 226.0, Average Reward: 279.62
# Episode 472/1000, Total Reward: 162.0
# Episode 472/1000, Total Reward: 162.0, Average Reward: 279.42
# Episode 473/1000, Total Reward: 191.0
# Episode 473/1000, Total Reward: 191.0, Average Reward: 279.41
# Episode 474/1000, Total Reward: 213.0
# Episode 474/1000, Total Reward: 213.0, Average Reward: 280.16
# Episode 475/1000, Total Reward: 452.0
# Episode 475/1000, Total Reward: 452.0, Average Reward: 283.22
# Episode 476/1000, Total Reward: 391.0
# Episode 476/1000, Total Reward: 391.0, Average Reward: 286.02
# Episode 477/1000, Total Reward: 227.0
# Episode 477/1000, Total Reward: 227.0, Average Reward: 286.21
# Episode 478/1000, Total Reward: 176.0
# Episode 478/1000, Total Reward: 176.0, Average Reward: 286.14
# Episode 479/1000, Total Reward: 205.0
# Episode 479/1000, Total Reward: 205.0, Average Reward: 285.54
# Episode 480/1000, Total Reward: 405.0
# Episode 480/1000, Total Reward: 405.0, Average Reward: 289.38
# Episode 481/1000, Total Reward: 320.0
# Episode 481/1000, Total Reward: 320.0, Average Reward: 290.78
# Episode 482/1000, Total Reward: 356.0
# Episode 482/1000, Total Reward: 356.0, Average Reward: 292.99
# Episode 483/1000, Total Reward: 402.0
# Episode 483/1000, Total Reward: 402.0, Average Reward: 295.01
# Episode 484/1000, Total Reward: 305.0
# Episode 484/1000, Total Reward: 305.0, Average Reward: 295.05
# Episode 485/1000, Total Reward: 308.0
# Episode 485/1000, Total Reward: 308.0, Average Reward: 294.02
# Episode 486/1000, Total Reward: 500.0
# Episode 486/1000, Total Reward: 500.0, Average Reward: 296.84
# Episode 487/1000, Total Reward: 184.0
# Episode 487/1000, Total Reward: 184.0, Average Reward: 296.7
# Episode 488/1000, Total Reward: 196.0
# Episode 488/1000, Total Reward: 196.0, Average Reward: 296.77
# Episode 489/1000, Total Reward: 470.0
# Episode 489/1000, Total Reward: 470.0, Average Reward: 299.1
# Episode 490/1000, Total Reward: 500.0
# Episode 490/1000, Total Reward: 500.0, Average Reward: 299.1
# Episode 491/1000, Total Reward: 298.0
# Episode 491/1000, Total Reward: 298.0, Average Reward: 300.3
# Episode 492/1000, Total Reward: 258.0
# Episode 492/1000, Total Reward: 258.0, Average Reward: 301.17
# Episode 493/1000, Total Reward: 425.0
# Episode 493/1000, Total Reward: 425.0, Average Reward: 303.0
# Episode 494/1000, Total Reward: 331.0
# Episode 494/1000, Total Reward: 331.0, Average Reward: 304.53
# Episode 495/1000, Total Reward: 341.0
# Episode 495/1000, Total Reward: 341.0, Average Reward: 305.15
# Episode 496/1000, Total Reward: 500.0
# Episode 496/1000, Total Reward: 500.0, Average Reward: 305.38
# Episode 497/1000, Total Reward: 422.0
# Episode 497/1000, Total Reward: 422.0, Average Reward: 304.6
# Episode 498/1000, Total Reward: 162.0
# Episode 498/1000, Total Reward: 162.0, Average Reward: 303.86
# Episode 499/1000, Total Reward: 500.0
# Episode 499/1000, Total Reward: 500.0, Average Reward: 305.14
# Episode 500/1000, Total Reward: 295.0
# Episode 500/1000, Total Reward: 295.0, Average Reward: 303.69
# Episode 501/1000, Total Reward: 500.0
# Episode 501/1000, Total Reward: 500.0, Average Reward: 306.78
# Episode 502/1000, Total Reward: 392.0
# Episode 502/1000, Total Reward: 392.0, Average Reward: 306.14
# Episode 503/1000, Total Reward: 394.0
# Episode 503/1000, Total Reward: 394.0, Average Reward: 308.18
# Episode 504/1000, Total Reward: 444.0
# Episode 504/1000, Total Reward: 444.0, Average Reward: 308.57
# Episode 505/1000, Total Reward: 341.0
# Episode 505/1000, Total Reward: 341.0, Average Reward: 310.62
# Episode 506/1000, Total Reward: 329.0
# Episode 506/1000, Total Reward: 329.0, Average Reward: 309.97
# Episode 507/1000, Total Reward: 283.0
# Episode 507/1000, Total Reward: 283.0, Average Reward: 310.39
# ...
# Episode 844/1000, Total Reward: 27.0, Average Reward: 24.54
# Episode 845/1000, Total Reward: 25.0
# Episode 845/1000, Total Reward: 25.0, Average Reward: 24.63
# Episode 846/1000, Total Reward: 19.0
# Episode 846/1000, Total Reward: 19.0, Average Reward: 24.55
# Episode 847/1000, Total Reward: 21.0
# Episode 847/1000, Total Reward: 21.0, Average Reward: 24.59
# Episode 848/1000, Total Reward: 31.0
# Episode 848/1000, Total Reward: 31.0, Average Reward: 24.48
# Episode 849/1000, Total Reward: 16.0
# Episode 849/1000, Total Reward: 16.0, Average Reward: 24.33
# Episode 850/1000, Total Reward: 26.0
# Episode 850/1000, Total Reward: 26.0, Average Reward: 24.35
# Episode 851/1000, Total Reward: 18.0
# Episode 851/1000, Total Reward: 18.0, Average Reward: 24.35
# Episode 852/1000, Total Reward: 59.0
# Episode 852/1000, Total Reward: 59.0, Average Reward: 24.77
# Episode 853/1000, Total Reward: 13.0
# Episode 853/1000, Total Reward: 13.0, Average Reward: 24.53
# Episode 854/1000, Total Reward: 26.0
# Episode 854/1000, Total Reward: 26.0, Average Reward: 24.67
# Episode 855/1000, Total Reward: 12.0
# Episode 855/1000, Total Reward: 12.0, Average Reward: 24.62
# Episode 856/1000, Total Reward: 13.0
# Episode 856/1000, Total Reward: 13.0, Average Reward: 24.27
# Episode 857/1000, Total Reward: 11.0
# Episode 857/1000, Total Reward: 11.0, Average Reward: 24.1
# Episode 858/1000, Total Reward: 25.0
# Episode 858/1000, Total Reward: 25.0, Average Reward: 24.09
# Episode 859/1000, Total Reward: 20.0
# Episode 859/1000, Total Reward: 20.0, Average Reward: 24.03
# Episode 860/1000, Total Reward: 20.0
# Episode 860/1000, Total Reward: 20.0, Average Reward: 24.1
# Episode 861/1000, Total Reward: 25.0
# Episode 861/1000, Total Reward: 25.0, Average Reward: 24.17
# Episode 862/1000, Total Reward: 36.0
# Episode 862/1000, Total Reward: 36.0, Average Reward: 24.34
# Episode 863/1000, Total Reward: 12.0
# Episode 863/1000, Total Reward: 12.0, Average Reward: 24.14
# Episode 864/1000, Total Reward: 29.0
# Episode 864/1000, Total Reward: 29.0, Average Reward: 24.0
# Episode 865/1000, Total Reward: 18.0
# Episode 865/1000, Total Reward: 18.0, Average Reward: 23.89
# Episode 866/1000, Total Reward: 15.0
# Episode 866/1000, Total Reward: 15.0, Average Reward: 23.79
# Episode 867/1000, Total Reward: 22.0
# Episode 867/1000, Total Reward: 22.0, Average Reward: 23.83
# Episode 868/1000, Total Reward: 15.0
# Episode 868/1000, Total Reward: 15.0, Average Reward: 23.81
# Episode 869/1000, Total Reward: 26.0
# Episode 869/1000, Total Reward: 26.0, Average Reward: 23.96
# Episode 870/1000, Total Reward: 26.0
# Episode 870/1000, Total Reward: 26.0, Average Reward: 23.89
# Episode 871/1000, Total Reward: 42.0
# Episode 871/1000, Total Reward: 42.0, Average Reward: 24.11
# Episode 872/1000, Total Reward: 10.0
# Episode 872/1000, Total Reward: 10.0, Average Reward: 23.57
# Episode 873/1000, Total Reward: 16.0
# Episode 873/1000, Total Reward: 16.0, Average Reward: 23.59
# Episode 874/1000, Total Reward: 12.0
# Episode 874/1000, Total Reward: 12.0, Average Reward: 23.22
# Episode 875/1000, Total Reward: 13.0
# Episode 875/1000, Total Reward: 13.0, Average Reward: 22.79
# Episode 876/1000, Total Reward: 22.0
# Episode 876/1000, Total Reward: 22.0, Average Reward: 22.86
# Episode 877/1000, Total Reward: 18.0
# Episode 877/1000, Total Reward: 18.0, Average Reward: 22.79
# Episode 878/1000, Total Reward: 41.0
# Episode 878/1000, Total Reward: 41.0, Average Reward: 23.02
# Episode 879/1000, Total Reward: 17.0
# Episode 879/1000, Total Reward: 17.0, Average Reward: 23.03
# Episode 880/1000, Total Reward: 11.0
# Episode 880/1000, Total Reward: 11.0, Average Reward: 22.88
# Episode 881/1000, Total Reward: 27.0
# Episode 881/1000, Total Reward: 27.0, Average Reward: 22.78
# Episode 882/1000, Total Reward: 10.0
# Episode 882/1000, Total Reward: 10.0, Average Reward: 22.63
# Episode 883/1000, Total Reward: 53.0
# Episode 883/1000, Total Reward: 53.0, Average Reward: 22.93
# Episode 884/1000, Total Reward: 35.0
# Episode 884/1000, Total Reward: 35.0, Average Reward: 23.1
# Episode 885/1000, Total Reward: 22.0
# Episode 885/1000, Total Reward: 22.0, Average Reward: 23.05
# Episode 886/1000, Total Reward: 32.0
# Episode 886/1000, Total Reward: 32.0, Average Reward: 23.09
# Episode 887/1000, Total Reward: 14.0
# Episode 887/1000, Total Reward: 14.0, Average Reward: 22.65
# Episode 888/1000, Total Reward: 23.0
# Episode 888/1000, Total Reward: 23.0, Average Reward: 22.69
# Episode 889/1000, Total Reward: 22.0
# Episode 889/1000, Total Reward: 22.0, Average Reward: 22.63
# Episode 890/1000, Total Reward: 24.0
# Episode 890/1000, Total Reward: 24.0, Average Reward: 22.77
# Episode 891/1000, Total Reward: 16.0
# Episode 891/1000, Total Reward: 16.0, Average Reward: 22.82
# Episode 892/1000, Total Reward: 19.0
# Episode 892/1000, Total Reward: 19.0, Average Reward: 22.89
# Episode 893/1000, Total Reward: 48.0
# Episode 893/1000, Total Reward: 48.0, Average Reward: 23.2
# Episode 894/1000, Total Reward: 43.0
# Episode 894/1000, Total Reward: 43.0, Average Reward: 23.51
# Episode 895/1000, Total Reward: 12.0
# Episode 895/1000, Total Reward: 12.0, Average Reward: 23.02
# Episode 896/1000, Total Reward: 30.0
# Episode 896/1000, Total Reward: 30.0, Average Reward: 22.9
# Episode 897/1000, Total Reward: 14.0
# Episode 897/1000, Total Reward: 14.0, Average Reward: 22.94
# Episode 898/1000, Total Reward: 20.0
# Episode 898/1000, Total Reward: 20.0, Average Reward: 23.0
# Episode 899/1000, Total Reward: 16.0
# Episode 899/1000, Total Reward: 16.0, Average Reward: 22.98
# Episode 900/1000, Total Reward: 12.0
# Episode 900/1000, Total Reward: 12.0, Average Reward: 22.95
# Episode 901/1000, Total Reward: 34.0
# Episode 901/1000, Total Reward: 34.0, Average Reward: 23.14
# Episode 902/1000, Total Reward: 20.0
# Episode 902/1000, Total Reward: 20.0, Average Reward: 23.11
# Episode 903/1000, Total Reward: 42.0
# Episode 903/1000, Total Reward: 42.0, Average Reward: 23.43
# Episode 904/1000, Total Reward: 11.0
# Episode 904/1000, Total Reward: 11.0, Average Reward: 23.35
# Episode 905/1000, Total Reward: 10.0
# Episode 905/1000, Total Reward: 10.0, Average Reward: 23.22
# Episode 906/1000, Total Reward: 9.0
# Episode 906/1000, Total Reward: 9.0, Average Reward: 22.64
# Episode 907/1000, Total Reward: 43.0
# Episode 907/1000, Total Reward: 43.0, Average Reward: 22.98
# Episode 908/1000, Total Reward: 69.0
# Episode 908/1000, Total Reward: 69.0, Average Reward: 23.54
# Episode 909/1000, Total Reward: 11.0
# Episode 909/1000, Total Reward: 11.0, Average Reward: 23.49
# Episode 910/1000, Total Reward: 53.0
# Episode 910/1000, Total Reward: 53.0, Average Reward: 23.56
# Episode 911/1000, Total Reward: 12.0
# Episode 911/1000, Total Reward: 12.0, Average Reward: 23.5
# Episode 912/1000, Total Reward: 28.0
# Episode 912/1000, Total Reward: 28.0, Average Reward: 23.58
# Episode 913/1000, Total Reward: 23.0
# Episode 913/1000, Total Reward: 23.0, Average Reward: 23.64
# Episode 914/1000, Total Reward: 21.0
# Episode 914/1000, Total Reward: 21.0, Average Reward: 23.69
# Episode 915/1000, Total Reward: 33.0
# Episode 915/1000, Total Reward: 33.0, Average Reward: 23.79
# Episode 916/1000, Total Reward: 19.0
# Episode 916/1000, Total Reward: 19.0, Average Reward: 23.79
# Episode 917/1000, Total Reward: 20.0
# Episode 917/1000, Total Reward: 20.0, Average Reward: 23.54
# Episode 918/1000, Total Reward: 20.0
# Episode 918/1000, Total Reward: 20.0, Average Reward: 23.61
# Episode 919/1000, Total Reward: 23.0
# Episode 919/1000, Total Reward: 23.0, Average Reward: 23.68
# Episode 920/1000, Total Reward: 20.0
# Episode 920/1000, Total Reward: 20.0, Average Reward: 23.6
# Episode 921/1000, Total Reward: 13.0
# Episode 921/1000, Total Reward: 13.0, Average Reward: 23.6
# Episode 922/1000, Total Reward: 19.0
# Episode 922/1000, Total Reward: 19.0, Average Reward: 23.63
# Episode 923/1000, Total Reward: 13.0
# Episode 923/1000, Total Reward: 13.0, Average Reward: 23.66
# Episode 924/1000, Total Reward: 31.0
# Episode 924/1000, Total Reward: 31.0, Average Reward: 23.83
# Episode 925/1000, Total Reward: 14.0
# Episode 925/1000, Total Reward: 14.0, Average Reward: 23.87
# Episode 926/1000, Total Reward: 19.0
# Episode 926/1000, Total Reward: 19.0, Average Reward: 22.79
# Episode 927/1000, Total Reward: 23.0
# Episode 927/1000, Total Reward: 23.0, Average Reward: 22.84
# Episode 928/1000, Total Reward: 11.0
# Episode 928/1000, Total Reward: 11.0, Average Reward: 22.82
# Episode 929/1000, Total Reward: 31.0
# Episode 929/1000, Total Reward: 31.0, Average Reward: 22.75
# Episode 930/1000, Total Reward: 36.0
# Episode 930/1000, Total Reward: 36.0, Average Reward: 22.97
# Episode 931/1000, Total Reward: 19.0
# Episode 931/1000, Total Reward: 19.0, Average Reward: 22.91
# Episode 932/1000, Total Reward: 25.0
# Episode 932/1000, Total Reward: 25.0, Average Reward: 22.91
# Episode 933/1000, Total Reward: 47.0
# Episode 933/1000, Total Reward: 47.0, Average Reward: 23.2
# Episode 934/1000, Total Reward: 14.0
# Episode 934/1000, Total Reward: 14.0, Average Reward: 23.12
# Episode 935/1000, Total Reward: 12.0
# Episode 935/1000, Total Reward: 12.0, Average Reward: 23.1
# Episode 936/1000, Total Reward: 44.0
# Episode 936/1000, Total Reward: 44.0, Average Reward: 23.41
# Episode 937/1000, Total Reward: 47.0
# Episode 937/1000, Total Reward: 47.0, Average Reward: 23.55
# Episode 938/1000, Total Reward: 35.0
# Episode 938/1000, Total Reward: 35.0, Average Reward: 23.77
# Episode 939/1000, Total Reward: 41.0
# Episode 939/1000, Total Reward: 41.0, Average Reward: 23.85
# Episode 940/1000, Total Reward: 11.0
# Episode 940/1000, Total Reward: 11.0, Average Reward: 23.84
# Episode 941/1000, Total Reward: 17.0
# Episode 941/1000, Total Reward: 17.0, Average Reward: 23.86
# Episode 942/1000, Total Reward: 20.0
# Episode 942/1000, Total Reward: 20.0, Average Reward: 23.88
# Episode 943/1000, Total Reward: 20.0
# Episode 943/1000, Total Reward: 20.0, Average Reward: 23.83
# Episode 944/1000, Total Reward: 13.0
# Episode 944/1000, Total Reward: 13.0, Average Reward: 23.69
# Episode 945/1000, Total Reward: 11.0
# Episode 945/1000, Total Reward: 11.0, Average Reward: 23.55
# Episode 946/1000, Total Reward: 12.0
# Episode 946/1000, Total Reward: 12.0, Average Reward: 23.48
# Episode 947/1000, Total Reward: 45.0
# Episode 947/1000, Total Reward: 45.0, Average Reward: 23.72
# Episode 948/1000, Total Reward: 19.0
# Episode 948/1000, Total Reward: 19.0, Average Reward: 23.6
# Episode 949/1000, Total Reward: 9.0
# Episode 949/1000, Total Reward: 9.0, Average Reward: 23.53
# Episode 950/1000, Total Reward: 15.0
# Episode 950/1000, Total Reward: 15.0, Average Reward: 23.42
# Episode 951/1000, Total Reward: 24.0
# Episode 951/1000, Total Reward: 24.0, Average Reward: 23.48
# Episode 952/1000, Total Reward: 46.0
# Episode 952/1000, Total Reward: 46.0, Average Reward: 23.35
# Episode 953/1000, Total Reward: 22.0
# Episode 953/1000, Total Reward: 22.0, Average Reward: 23.44
# Episode 954/1000, Total Reward: 25.0
# Episode 954/1000, Total Reward: 25.0, Average Reward: 23.43
# Episode 955/1000, Total Reward: 36.0
# Episode 955/1000, Total Reward: 36.0, Average Reward: 23.67
# Episode 956/1000, Total Reward: 20.0
# Episode 956/1000, Total Reward: 20.0, Average Reward: 23.74
# Episode 957/1000, Total Reward: 19.0
# Episode 957/1000, Total Reward: 19.0, Average Reward: 23.82
# Episode 958/1000, Total Reward: 12.0
# Episode 958/1000, Total Reward: 12.0, Average Reward: 23.69
# Episode 959/1000, Total Reward: 24.0
# Episode 959/1000, Total Reward: 24.0, Average Reward: 23.73
# Episode 960/1000, Total Reward: 19.0
# Episode 960/1000, Total Reward: 19.0, Average Reward: 23.72
# Episode 961/1000, Total Reward: 21.0
# Episode 961/1000, Total Reward: 21.0, Average Reward: 23.68
# Episode 962/1000, Total Reward: 40.0
# Episode 962/1000, Total Reward: 40.0, Average Reward: 23.72
# Episode 963/1000, Total Reward: 24.0
# Episode 963/1000, Total Reward: 24.0, Average Reward: 23.84
# Episode 964/1000, Total Reward: 11.0
# Episode 964/1000, Total Reward: 11.0, Average Reward: 23.66
# Episode 965/1000, Total Reward: 24.0
# Episode 965/1000, Total Reward: 24.0, Average Reward: 23.72
# Episode 966/1000, Total Reward: 22.0
# Episode 966/1000, Total Reward: 22.0, Average Reward: 23.79
# Episode 967/1000, Total Reward: 28.0
# Episode 967/1000, Total Reward: 28.0, Average Reward: 23.85
# Episode 968/1000, Total Reward: 27.0
# Episode 968/1000, Total Reward: 27.0, Average Reward: 23.97
# Episode 969/1000, Total Reward: 29.0
# Episode 969/1000, Total Reward: 29.0, Average Reward: 24.0
# Episode 970/1000, Total Reward: 12.0
# Episode 970/1000, Total Reward: 12.0, Average Reward: 23.86
# Episode 971/1000, Total Reward: 21.0
# Episode 971/1000, Total Reward: 21.0, Average Reward: 23.65
# Episode 972/1000, Total Reward: 15.0
# Episode 972/1000, Total Reward: 15.0, Average Reward: 23.7
# Episode 973/1000, Total Reward: 34.0
# Episode 973/1000, Total Reward: 34.0, Average Reward: 23.88
# Episode 974/1000, Total Reward: 27.0
# Episode 974/1000, Total Reward: 27.0, Average Reward: 24.03
# Episode 975/1000, Total Reward: 17.0
# Episode 975/1000, Total Reward: 17.0, Average Reward: 24.07
# Episode 976/1000, Total Reward: 18.0
# Episode 976/1000, Total Reward: 18.0, Average Reward: 24.03
# Episode 977/1000, Total Reward: 32.0
# Episode 977/1000, Total Reward: 32.0, Average Reward: 24.17
# Episode 978/1000, Total Reward: 17.0
# Episode 978/1000, Total Reward: 17.0, Average Reward: 23.93
# Episode 979/1000, Total Reward: 36.0
# Episode 979/1000, Total Reward: 36.0, Average Reward: 24.12
# Episode 980/1000, Total Reward: 38.0
# Episode 980/1000, Total Reward: 38.0, Average Reward: 24.39
# Episode 981/1000, Total Reward: 19.0
# Episode 981/1000, Total Reward: 19.0, Average Reward: 24.31
# Episode 982/1000, Total Reward: 67.0
# Episode 982/1000, Total Reward: 67.0, Average Reward: 24.88
# Episode 983/1000, Total Reward: 47.0
# Episode 983/1000, Total Reward: 47.0, Average Reward: 24.82
# Episode 984/1000, Total Reward: 19.0
# Episode 984/1000, Total Reward: 19.0, Average Reward: 24.66
# Episode 985/1000, Total Reward: 16.0
# Episode 985/1000, Total Reward: 16.0, Average Reward: 24.6
# Episode 986/1000, Total Reward: 22.0
# Episode 986/1000, Total Reward: 22.0, Average Reward: 24.5
# Episode 987/1000, Total Reward: 16.0
# Episode 987/1000, Total Reward: 16.0, Average Reward: 24.52
# Episode 988/1000, Total Reward: 13.0
# Episode 988/1000, Total Reward: 13.0, Average Reward: 24.42
# Episode 989/1000, Total Reward: 20.0
# Episode 989/1000, Total Reward: 20.0, Average Reward: 24.4
# Episode 990/1000, Total Reward: 11.0
# Episode 990/1000, Total Reward: 11.0, Average Reward: 24.27
# Episode 991/1000, Total Reward: 16.0
# Episode 991/1000, Total Reward: 16.0, Average Reward: 24.27
# Episode 992/1000, Total Reward: 21.0
# Episode 992/1000, Total Reward: 21.0, Average Reward: 24.29
# Episode 993/1000, Total Reward: 43.0
# Episode 993/1000, Total Reward: 43.0, Average Reward: 24.24
# Episode 994/1000, Total Reward: 16.0
# Episode 994/1000, Total Reward: 16.0, Average Reward: 23.97
# Episode 995/1000, Total Reward: 27.0
# Episode 995/1000, Total Reward: 27.0, Average Reward: 24.12
# Episode 996/1000, Total Reward: 16.0
# Episode 996/1000, Total Reward: 16.0, Average Reward: 23.98
# Episode 997/1000, Total Reward: 25.0
# Episode 997/1000, Total Reward: 25.0, Average Reward: 24.09
# Episode 998/1000, Total Reward: 18.0
# Episode 998/1000, Total Reward: 18.0, Average Reward: 24.07
# Episode 999/1000, Total Reward: 43.0
# Episode 999/1000, Total Reward: 43.0, Average Reward: 24.34
# Episode 1000/1000, Total Reward: 11.0
# Episode 1000/1000, Total Reward: 11.0, Average Reward: 24.33
# Gamma=0.995, Alpha=0.0001, Solved in 1000 episodes
#
# Best Parameters:
# Gamma: 0.995, Alpha: 0.001, Solved in 588 episodes
#
# Gamma: 0.95, Alpha: 0.001, Solved in: 1000 episodes, Average Reward: 248.7
# Gamma: 0.95, Alpha: 0.0005, Solved in: 1000 episodes, Average Reward: 305.63
# Gamma: 0.95, Alpha: 0.0001, Solved in: 1000 episodes, Average Reward: 25.7
# Gamma: 0.99, Alpha: 0.001, Solved in: 825 episodes, Average Reward: 475.66
# Gamma: 0.99, Alpha: 0.0005, Solved in: 958 episodes, Average Reward: 475.01
# Gamma: 0.99, Alpha: 0.0001, Solved in: 1000 episodes, Average Reward: 28.61
# Gamma: 0.995, Alpha: 0.001, Solved in: 588 episodes, Average Reward: 475.54
# Gamma: 0.995, Alpha: 0.0005, Solved in: 799 episodes, Average Reward: 475.39
# Gamma: 0.995, Alpha: 0.0001, Solved in: 1000 episodes, Average Reward: 24.33

# %%
# test the trained policy
print("Testing the policy...")
test_avg_reward = test_policy(env, best_policy_network, episodes=10)
print(f"Average Test Reward: {test_avg_reward}")
# Out:
# Testing the policy...
# Test Episode 1, Total Reward: 10000.0
# Test Episode 2, Total Reward: 10000.0
# Test Episode 3, Total Reward: 10000.0
# Test Episode 4, Total Reward: 10000.0
# Test Episode 5, Total Reward: 10000.0
# Test Episode 6, Total Reward: 10000.0
# Test Episode 7, Total Reward: 10000.0
# Test Episode 8, Total Reward: 10000.0
# Test Episode 9, Total Reward: 10000.0
# Test Episode 10, Total Reward: 10000.0
# Average Test Reward: 10000.0

# %%
# Save the policy
torch.save(best_policy_network.state_dict(), 'reinforce_with_baseline_policy.pth')
torch.save(best_value_network.state_dict(), 'reinforce_with_baseline_value.pth')
