# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, hidden_sizes, output_dim):
        super(PolicyNetwork, self).__init__()
        layers = []
        prev_size = input_dim
        for hs in hidden_sizes:
            layers.append(nn.Linear(prev_size, hs))
            layers.append(nn.ReLU())
            prev_size = hs
        layers.append(nn.Linear(prev_size, output_dim))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        logits = self.model(x)
        return torch.softmax(logits, dim=-1)

# %%
def reinforce(env,
              input_dim,
              output_dim,
              hidden_sizes,
              alpha=0.001,
              episodes=500,
              gamma=0.99,
              log_dir="runs/reinforce"):
    """
    REINFORCE training loop.

    Args:
        env: OpenAI gym environment
        input_dim: dimension of input space
        output_dim: number of actions
        hidden_sizes: list of sizes for each hidden layer
        alpha: The learning rate
        episodes: number of training episodes
        gamma: discount factor
        log_dir: directory for tensorboard logs

    Returns:
        policy_network: the trained policy network
        rewards_per_episode: a list containing the total reward per episode
    """

    writer = SummaryWriter(log_dir=log_dir)

    policy_network = PolicyNetwork(input_dim, hidden_sizes, output_dim).to(device)
    optimizer = optim.Adam(policy_network.parameters(), lr=alpha)
    rewards_per_episode = []

    for episode in range(episodes):
        # generate a new episode
        state, _ = env.reset()
        done = False
        episode_log_probs = []
        episode_rewards = []

        while not done:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            action_probs = policy_network(state_tensor)
            action_dist = torch.distributions.Categorical(action_probs)
            action = action_dist.sample()
            log_prob = action_dist.log_prob(action)

            next_state, reward, done, truncated, info = env.step(action.item())

            episode_log_probs.append(log_prob)
            episode_rewards.append(reward)

            state = next_state

        # compute the returns (G_t) for the episode (including gamma)
        returns = []
        G = 0
        for r in reversed(episode_rewards):
            G = r + gamma * G
            returns.append(G)

        returns.reverse()
        returns = torch.tensor(returns, dtype=torch.float32, device=device)

        # compute policy gradient and update
        policy_loss = []
        for log_prob, R in zip(episode_log_probs, returns):
            policy_loss.append(-log_prob * R)
        policy_loss = torch.cat(policy_loss).sum()

        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()

        total_reward = sum(episode_rewards)
        rewards_per_episode.append(total_reward)

        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}")

        # log metrics to TensorBoard
        writer.add_scalar("Policy Loss", policy_loss.item(), episode)
        writer.add_scalar("Total Reward", total_reward, episode)

        # early stopping if solved
        if len(rewards_per_episode) >= 100 and np.mean(rewards_per_episode[-100:]) >= 475.0:
            print(f"Solved in {episode + 1} episodes!")
            break

    writer.close()
    return policy_network, rewards_per_episode

# %%
def test_policy(env, policy_network, episodes=10):
    policy_network.eval()
    avg_reward = 0
    for ep in range(episodes):
        state, _ = env.reset()
        total_reward = 0
        done = False
        while not done:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            with torch.no_grad():
                action_probs = policy_network(state_tensor)
            action = torch.argmax(action_probs).item()
            state, reward, done, truncated, info = env.step(action)
            total_reward += reward
            if total_reward >= 10000:
                break

        avg_reward += total_reward
        print(f"Test Episode {ep + 1}, Total Reward: {total_reward}")
    return avg_reward / episodes

# %%
env = gym.make("CartPole-v1")

input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n
hidden_sizes = [16, 32, 16]

episodes = 2000
gamma = 0.99
alpha = 0.001

policy_network, rewards = reinforce(env, input_dim=input_dim, output_dim=output_dim, hidden_sizes=hidden_sizes,
                                    alpha=alpha, episodes=episodes, gamma=gamma)

# plot the rewards
plt.figure()
plt.plot(rewards)
plt.title("Total Rewards per Episode (REINFORCE)")
plt.xlabel("Episodes")
plt.ylabel("Total Reward")
plt.show()
# Out:
# C:\Users\forgedRice\anaconda3\envs\DRL\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 1/2000, Total Reward: 18.0
# Episode 2/2000, Total Reward: 30.0
# Episode 3/2000, Total Reward: 23.0
# Episode 4/2000, Total Reward: 15.0
# Episode 5/2000, Total Reward: 15.0
# Episode 6/2000, Total Reward: 21.0
# Episode 7/2000, Total Reward: 41.0
# Episode 8/2000, Total Reward: 13.0
# Episode 9/2000, Total Reward: 14.0
# Episode 10/2000, Total Reward: 18.0
# Episode 11/2000, Total Reward: 19.0
# Episode 12/2000, Total Reward: 17.0
# Episode 13/2000, Total Reward: 49.0
# Episode 14/2000, Total Reward: 15.0
# Episode 15/2000, Total Reward: 28.0
# Episode 16/2000, Total Reward: 24.0
# Episode 17/2000, Total Reward: 27.0
# Episode 18/2000, Total Reward: 36.0
# Episode 19/2000, Total Reward: 27.0
# Episode 20/2000, Total Reward: 29.0
# Episode 21/2000, Total Reward: 17.0
# Episode 22/2000, Total Reward: 12.0
# Episode 23/2000, Total Reward: 10.0
# Episode 24/2000, Total Reward: 16.0
# Episode 25/2000, Total Reward: 16.0
# Episode 26/2000, Total Reward: 9.0
# Episode 27/2000, Total Reward: 27.0
# Episode 28/2000, Total Reward: 55.0
# Episode 29/2000, Total Reward: 27.0
# Episode 30/2000, Total Reward: 20.0
# Episode 31/2000, Total Reward: 12.0
# Episode 32/2000, Total Reward: 18.0
# Episode 33/2000, Total Reward: 21.0
# Episode 34/2000, Total Reward: 73.0
# Episode 35/2000, Total Reward: 12.0
# Episode 36/2000, Total Reward: 31.0
# Episode 37/2000, Total Reward: 54.0
# Episode 38/2000, Total Reward: 17.0
# Episode 39/2000, Total Reward: 15.0
# Episode 40/2000, Total Reward: 47.0
# Episode 41/2000, Total Reward: 25.0
# Episode 42/2000, Total Reward: 28.0
# Episode 43/2000, Total Reward: 24.0
# Episode 44/2000, Total Reward: 9.0
# Episode 45/2000, Total Reward: 57.0
# Episode 46/2000, Total Reward: 14.0
# Episode 47/2000, Total Reward: 33.0
# Episode 48/2000, Total Reward: 14.0
# Episode 49/2000, Total Reward: 9.0
# Episode 50/2000, Total Reward: 50.0
# Episode 51/2000, Total Reward: 49.0
# Episode 52/2000, Total Reward: 13.0
# Episode 53/2000, Total Reward: 12.0
# Episode 54/2000, Total Reward: 21.0
# Episode 55/2000, Total Reward: 25.0
# Episode 56/2000, Total Reward: 33.0
# Episode 57/2000, Total Reward: 36.0
# Episode 58/2000, Total Reward: 40.0
# Episode 59/2000, Total Reward: 35.0
# Episode 60/2000, Total Reward: 25.0
# Episode 61/2000, Total Reward: 15.0
# Episode 62/2000, Total Reward: 18.0
# Episode 63/2000, Total Reward: 29.0
# Episode 64/2000, Total Reward: 22.0
# Episode 65/2000, Total Reward: 23.0
# Episode 66/2000, Total Reward: 16.0
# Episode 67/2000, Total Reward: 11.0
# Episode 68/2000, Total Reward: 45.0
# Episode 69/2000, Total Reward: 34.0
# Episode 70/2000, Total Reward: 21.0
# Episode 71/2000, Total Reward: 22.0
# Episode 72/2000, Total Reward: 24.0
# Episode 73/2000, Total Reward: 26.0
# Episode 74/2000, Total Reward: 35.0
# Episode 75/2000, Total Reward: 17.0
# Episode 76/2000, Total Reward: 40.0
# Episode 77/2000, Total Reward: 16.0
# Episode 78/2000, Total Reward: 19.0
# Episode 79/2000, Total Reward: 25.0
# Episode 80/2000, Total Reward: 28.0
# Episode 81/2000, Total Reward: 19.0
# Episode 82/2000, Total Reward: 52.0
# Episode 83/2000, Total Reward: 11.0
# Episode 84/2000, Total Reward: 9.0
# Episode 85/2000, Total Reward: 10.0
# Episode 86/2000, Total Reward: 30.0
# Episode 87/2000, Total Reward: 48.0
# Episode 88/2000, Total Reward: 18.0
# Episode 89/2000, Total Reward: 42.0
# Episode 90/2000, Total Reward: 29.0
# Episode 91/2000, Total Reward: 60.0
# Episode 92/2000, Total Reward: 49.0
# Episode 93/2000, Total Reward: 11.0
# Episode 94/2000, Total Reward: 19.0
# Episode 95/2000, Total Reward: 23.0
# Episode 96/2000, Total Reward: 19.0
# Episode 97/2000, Total Reward: 13.0
# Episode 98/2000, Total Reward: 14.0
# Episode 99/2000, Total Reward: 38.0
# Episode 100/2000, Total Reward: 14.0
# Episode 101/2000, Total Reward: 26.0
# Episode 102/2000, Total Reward: 11.0
# Episode 103/2000, Total Reward: 13.0
# Episode 104/2000, Total Reward: 63.0
# Episode 105/2000, Total Reward: 11.0
# Episode 106/2000, Total Reward: 14.0
# Episode 107/2000, Total Reward: 33.0
# Episode 108/2000, Total Reward: 15.0
# Episode 109/2000, Total Reward: 34.0
# Episode 110/2000, Total Reward: 20.0
# Episode 111/2000, Total Reward: 21.0
# Episode 112/2000, Total Reward: 23.0
# Episode 113/2000, Total Reward: 12.0
# Episode 114/2000, Total Reward: 53.0
# Episode 115/2000, Total Reward: 13.0
# Episode 116/2000, Total Reward: 18.0
# Episode 117/2000, Total Reward: 50.0
# Episode 118/2000, Total Reward: 37.0
# Episode 119/2000, Total Reward: 15.0
# Episode 120/2000, Total Reward: 23.0
# Episode 121/2000, Total Reward: 21.0
# Episode 122/2000, Total Reward: 23.0
# Episode 123/2000, Total Reward: 12.0
# Episode 124/2000, Total Reward: 46.0
# Episode 125/2000, Total Reward: 33.0
# Episode 126/2000, Total Reward: 16.0
# Episode 127/2000, Total Reward: 10.0
# Episode 128/2000, Total Reward: 39.0
# Episode 129/2000, Total Reward: 15.0
# Episode 130/2000, Total Reward: 20.0
# Episode 131/2000, Total Reward: 19.0
# Episode 132/2000, Total Reward: 47.0
# Episode 133/2000, Total Reward: 59.0
# Episode 134/2000, Total Reward: 28.0
# Episode 135/2000, Total Reward: 15.0
# Episode 136/2000, Total Reward: 16.0
# Episode 137/2000, Total Reward: 17.0
# Episode 138/2000, Total Reward: 10.0
# Episode 139/2000, Total Reward: 9.0
# Episode 140/2000, Total Reward: 20.0
# Episode 141/2000, Total Reward: 35.0
# Episode 142/2000, Total Reward: 28.0
# Episode 143/2000, Total Reward: 40.0
# Episode 144/2000, Total Reward: 15.0
# Episode 145/2000, Total Reward: 11.0
# Episode 146/2000, Total Reward: 22.0
# Episode 147/2000, Total Reward: 37.0
# Episode 148/2000, Total Reward: 51.0
# Episode 149/2000, Total Reward: 30.0
# Episode 150/2000, Total Reward: 14.0
# Episode 151/2000, Total Reward: 54.0
# Episode 152/2000, Total Reward: 33.0
# Episode 153/2000, Total Reward: 13.0
# Episode 154/2000, Total Reward: 19.0
# Episode 155/2000, Total Reward: 19.0
# Episode 156/2000, Total Reward: 18.0
# Episode 157/2000, Total Reward: 29.0
# Episode 158/2000, Total Reward: 9.0
# Episode 159/2000, Total Reward: 9.0
# Episode 160/2000, Total Reward: 32.0
# Episode 161/2000, Total Reward: 16.0
# Episode 162/2000, Total Reward: 13.0
# Episode 163/2000, Total Reward: 40.0
# Episode 164/2000, Total Reward: 9.0
# Episode 165/2000, Total Reward: 21.0
# Episode 166/2000, Total Reward: 19.0
# Episode 167/2000, Total Reward: 43.0
# Episode 168/2000, Total Reward: 27.0
# Episode 169/2000, Total Reward: 13.0
# Episode 170/2000, Total Reward: 16.0
# Episode 171/2000, Total Reward: 15.0
# Episode 172/2000, Total Reward: 59.0
# Episode 173/2000, Total Reward: 49.0
# Episode 174/2000, Total Reward: 19.0
# Episode 175/2000, Total Reward: 13.0
# Episode 176/2000, Total Reward: 62.0
# Episode 177/2000, Total Reward: 14.0
# Episode 178/2000, Total Reward: 38.0
# Episode 179/2000, Total Reward: 16.0
# Episode 180/2000, Total Reward: 27.0
# Episode 181/2000, Total Reward: 41.0
# Episode 182/2000, Total Reward: 15.0
# Episode 183/2000, Total Reward: 27.0
# Episode 184/2000, Total Reward: 13.0
# Episode 185/2000, Total Reward: 91.0
# Episode 186/2000, Total Reward: 16.0
# Episode 187/2000, Total Reward: 19.0
# Episode 188/2000, Total Reward: 17.0
# Episode 189/2000, Total Reward: 14.0
# Episode 190/2000, Total Reward: 22.0
# Episode 191/2000, Total Reward: 14.0
# Episode 192/2000, Total Reward: 66.0
# Episode 193/2000, Total Reward: 37.0
# Episode 194/2000, Total Reward: 16.0
# Episode 195/2000, Total Reward: 13.0
# Episode 196/2000, Total Reward: 34.0
# Episode 197/2000, Total Reward: 27.0
# Episode 198/2000, Total Reward: 12.0
# Episode 199/2000, Total Reward: 18.0
# Episode 200/2000, Total Reward: 19.0
# Episode 201/2000, Total Reward: 15.0
# Episode 202/2000, Total Reward: 35.0
# Episode 203/2000, Total Reward: 24.0
# Episode 204/2000, Total Reward: 34.0
# Episode 205/2000, Total Reward: 32.0
# Episode 206/2000, Total Reward: 24.0
# Episode 207/2000, Total Reward: 11.0
# Episode 208/2000, Total Reward: 34.0
# Episode 209/2000, Total Reward: 16.0
# Episode 210/2000, Total Reward: 77.0
# Episode 211/2000, Total Reward: 45.0
# Episode 212/2000, Total Reward: 39.0
# Episode 213/2000, Total Reward: 19.0
# Episode 214/2000, Total Reward: 35.0
# Episode 215/2000, Total Reward: 16.0
# Episode 216/2000, Total Reward: 28.0
# Episode 217/2000, Total Reward: 35.0
# Episode 218/2000, Total Reward: 88.0
# Episode 219/2000, Total Reward: 18.0
# Episode 220/2000, Total Reward: 38.0
# Episode 221/2000, Total Reward: 27.0
# Episode 222/2000, Total Reward: 35.0
# Episode 223/2000, Total Reward: 25.0
# Episode 224/2000, Total Reward: 32.0
# Episode 225/2000, Total Reward: 22.0
# Episode 226/2000, Total Reward: 58.0
# Episode 227/2000, Total Reward: 33.0
# Episode 228/2000, Total Reward: 19.0
# Episode 229/2000, Total Reward: 27.0
# Episode 230/2000, Total Reward: 30.0
# Episode 231/2000, Total Reward: 56.0
# Episode 232/2000, Total Reward: 46.0
# Episode 233/2000, Total Reward: 17.0
# Episode 234/2000, Total Reward: 59.0
# Episode 235/2000, Total Reward: 16.0
# Episode 236/2000, Total Reward: 19.0
# Episode 237/2000, Total Reward: 16.0
# Episode 238/2000, Total Reward: 31.0
# Episode 239/2000, Total Reward: 41.0
# Episode 240/2000, Total Reward: 12.0
# Episode 241/2000, Total Reward: 30.0
# Episode 242/2000, Total Reward: 13.0
# Episode 243/2000, Total Reward: 16.0
# Episode 244/2000, Total Reward: 48.0
# Episode 245/2000, Total Reward: 66.0
# Episode 246/2000, Total Reward: 14.0
# Episode 247/2000, Total Reward: 99.0
# Episode 248/2000, Total Reward: 23.0
# Episode 249/2000, Total Reward: 48.0
# Episode 250/2000, Total Reward: 86.0
# Episode 251/2000, Total Reward: 30.0
# Episode 252/2000, Total Reward: 17.0
# Episode 253/2000, Total Reward: 48.0
# Episode 254/2000, Total Reward: 17.0
# Episode 255/2000, Total Reward: 49.0
# Episode 256/2000, Total Reward: 33.0
# Episode 257/2000, Total Reward: 15.0
# Episode 258/2000, Total Reward: 34.0
# Episode 259/2000, Total Reward: 28.0
# Episode 260/2000, Total Reward: 33.0
# Episode 261/2000, Total Reward: 33.0
# Episode 262/2000, Total Reward: 50.0
# Episode 263/2000, Total Reward: 11.0
# Episode 264/2000, Total Reward: 58.0
# Episode 265/2000, Total Reward: 17.0
# Episode 266/2000, Total Reward: 74.0
# Episode 267/2000, Total Reward: 16.0
# Episode 268/2000, Total Reward: 25.0
# Episode 269/2000, Total Reward: 40.0
# Episode 270/2000, Total Reward: 23.0
# Episode 271/2000, Total Reward: 53.0
# Episode 272/2000, Total Reward: 57.0
# Episode 273/2000, Total Reward: 20.0
# Episode 274/2000, Total Reward: 43.0
# Episode 275/2000, Total Reward: 53.0
# Episode 276/2000, Total Reward: 21.0
# Episode 277/2000, Total Reward: 95.0
# Episode 278/2000, Total Reward: 19.0
# Episode 279/2000, Total Reward: 24.0
# Episode 280/2000, Total Reward: 51.0
# Episode 281/2000, Total Reward: 112.0
# Episode 282/2000, Total Reward: 14.0
# Episode 283/2000, Total Reward: 49.0
# Episode 284/2000, Total Reward: 144.0
# Episode 285/2000, Total Reward: 32.0
# Episode 286/2000, Total Reward: 41.0
# Episode 287/2000, Total Reward: 87.0
# Episode 288/2000, Total Reward: 86.0
# Episode 289/2000, Total Reward: 43.0
# Episode 290/2000, Total Reward: 38.0
# Episode 291/2000, Total Reward: 43.0
# Episode 292/2000, Total Reward: 38.0
# Episode 293/2000, Total Reward: 120.0
# Episode 294/2000, Total Reward: 43.0
# Episode 295/2000, Total Reward: 79.0
# Episode 296/2000, Total Reward: 27.0
# Episode 297/2000, Total Reward: 100.0
# Episode 298/2000, Total Reward: 44.0
# Episode 299/2000, Total Reward: 54.0
# Episode 300/2000, Total Reward: 37.0
# Episode 301/2000, Total Reward: 43.0
# Episode 302/2000, Total Reward: 160.0
# Episode 303/2000, Total Reward: 159.0
# Episode 304/2000, Total Reward: 66.0
# Episode 305/2000, Total Reward: 27.0
# Episode 306/2000, Total Reward: 136.0
# Episode 307/2000, Total Reward: 25.0
# Episode 308/2000, Total Reward: 87.0
# Episode 309/2000, Total Reward: 56.0
# Episode 310/2000, Total Reward: 53.0
# Episode 311/2000, Total Reward: 35.0
# Episode 312/2000, Total Reward: 105.0
# Episode 313/2000, Total Reward: 158.0
# Episode 314/2000, Total Reward: 57.0
# Episode 315/2000, Total Reward: 106.0
# Episode 316/2000, Total Reward: 64.0
# Episode 317/2000, Total Reward: 63.0
# Episode 318/2000, Total Reward: 55.0
# Episode 319/2000, Total Reward: 227.0
# Episode 320/2000, Total Reward: 207.0
# Episode 321/2000, Total Reward: 63.0
# Episode 322/2000, Total Reward: 73.0
# Episode 323/2000, Total Reward: 54.0
# Episode 324/2000, Total Reward: 141.0
# Episode 325/2000, Total Reward: 107.0
# Episode 326/2000, Total Reward: 98.0
# Episode 327/2000, Total Reward: 123.0
# Episode 328/2000, Total Reward: 135.0
# Episode 329/2000, Total Reward: 42.0
# Episode 330/2000, Total Reward: 56.0
# Episode 331/2000, Total Reward: 249.0
# Episode 332/2000, Total Reward: 204.0
# Episode 333/2000, Total Reward: 97.0
# Episode 334/2000, Total Reward: 185.0
# Episode 335/2000, Total Reward: 94.0
# Episode 336/2000, Total Reward: 178.0
# Episode 337/2000, Total Reward: 45.0
# Episode 338/2000, Total Reward: 104.0
# Episode 339/2000, Total Reward: 141.0
# Episode 340/2000, Total Reward: 93.0
# Episode 341/2000, Total Reward: 112.0
# Episode 342/2000, Total Reward: 87.0
# Episode 343/2000, Total Reward: 185.0
# Episode 344/2000, Total Reward: 110.0
# Episode 345/2000, Total Reward: 191.0
# Episode 346/2000, Total Reward: 121.0
# Episode 347/2000, Total Reward: 29.0
# Episode 348/2000, Total Reward: 74.0
# Episode 349/2000, Total Reward: 173.0
# Episode 350/2000, Total Reward: 93.0
# Episode 351/2000, Total Reward: 230.0
# Episode 352/2000, Total Reward: 144.0
# Episode 353/2000, Total Reward: 125.0
# Episode 354/2000, Total Reward: 143.0
# Episode 355/2000, Total Reward: 58.0
# Episode 356/2000, Total Reward: 77.0
# Episode 357/2000, Total Reward: 95.0
# Episode 358/2000, Total Reward: 68.0
# Episode 359/2000, Total Reward: 23.0
# Episode 360/2000, Total Reward: 237.0
# Episode 361/2000, Total Reward: 123.0
# Episode 362/2000, Total Reward: 58.0
# Episode 363/2000, Total Reward: 85.0
# Episode 364/2000, Total Reward: 146.0
# Episode 365/2000, Total Reward: 150.0
# Episode 366/2000, Total Reward: 180.0
# Episode 367/2000, Total Reward: 78.0
# Episode 368/2000, Total Reward: 161.0
# Episode 369/2000, Total Reward: 139.0
# Episode 370/2000, Total Reward: 131.0
# Episode 371/2000, Total Reward: 187.0
# Episode 372/2000, Total Reward: 124.0
# Episode 373/2000, Total Reward: 125.0
# Episode 374/2000, Total Reward: 111.0
# Episode 375/2000, Total Reward: 173.0
# Episode 376/2000, Total Reward: 47.0
# Episode 377/2000, Total Reward: 78.0
# Episode 378/2000, Total Reward: 151.0
# Episode 379/2000, Total Reward: 78.0
# Episode 380/2000, Total Reward: 64.0
# Episode 381/2000, Total Reward: 84.0
# Episode 382/2000, Total Reward: 71.0
# Episode 383/2000, Total Reward: 36.0
# Episode 384/2000, Total Reward: 118.0
# Episode 385/2000, Total Reward: 101.0
# Episode 386/2000, Total Reward: 85.0
# Episode 387/2000, Total Reward: 112.0
# Episode 388/2000, Total Reward: 51.0
# Episode 389/2000, Total Reward: 39.0
# Episode 390/2000, Total Reward: 122.0
# Episode 391/2000, Total Reward: 37.0
# Episode 392/2000, Total Reward: 131.0
# Episode 393/2000, Total Reward: 58.0
# Episode 394/2000, Total Reward: 117.0
# Episode 395/2000, Total Reward: 51.0
# Episode 396/2000, Total Reward: 108.0
# Episode 397/2000, Total Reward: 100.0
# Episode 398/2000, Total Reward: 37.0
# Episode 399/2000, Total Reward: 35.0
# Episode 400/2000, Total Reward: 65.0
# Episode 401/2000, Total Reward: 86.0
# Episode 402/2000, Total Reward: 125.0
# Episode 403/2000, Total Reward: 57.0
# Episode 404/2000, Total Reward: 110.0
# Episode 405/2000, Total Reward: 128.0
# Episode 406/2000, Total Reward: 127.0
# Episode 407/2000, Total Reward: 51.0
# Episode 408/2000, Total Reward: 37.0
# Episode 409/2000, Total Reward: 101.0
# Episode 410/2000, Total Reward: 148.0
# Episode 411/2000, Total Reward: 45.0
# Episode 412/2000, Total Reward: 125.0
# Episode 413/2000, Total Reward: 120.0
# Episode 414/2000, Total Reward: 129.0
# Episode 415/2000, Total Reward: 116.0
# Episode 416/2000, Total Reward: 162.0
# Episode 417/2000, Total Reward: 84.0
# Episode 418/2000, Total Reward: 84.0
# Episode 419/2000, Total Reward: 154.0
# Episode 420/2000, Total Reward: 144.0
# Episode 421/2000, Total Reward: 164.0
# Episode 422/2000, Total Reward: 272.0
# Episode 423/2000, Total Reward: 191.0
# Episode 424/2000, Total Reward: 228.0
# Episode 425/2000, Total Reward: 168.0
# Episode 426/2000, Total Reward: 162.0
# Episode 427/2000, Total Reward: 326.0
# Episode 428/2000, Total Reward: 158.0
# Episode 429/2000, Total Reward: 257.0
# Episode 430/2000, Total Reward: 158.0
# Episode 431/2000, Total Reward: 151.0
# Episode 432/2000, Total Reward: 140.0
# Episode 433/2000, Total Reward: 322.0
# Episode 434/2000, Total Reward: 164.0
# Episode 435/2000, Total Reward: 97.0
# Episode 436/2000, Total Reward: 114.0
# Episode 437/2000, Total Reward: 149.0
# Episode 438/2000, Total Reward: 290.0
# Episode 439/2000, Total Reward: 143.0
# Episode 440/2000, Total Reward: 213.0
# Episode 441/2000, Total Reward: 102.0
# Episode 442/2000, Total Reward: 264.0
# Episode 443/2000, Total Reward: 205.0
# Episode 444/2000, Total Reward: 120.0
# Episode 445/2000, Total Reward: 403.0
# Episode 446/2000, Total Reward: 228.0
# Episode 447/2000, Total Reward: 71.0
# Episode 448/2000, Total Reward: 40.0
# Episode 449/2000, Total Reward: 220.0
# Episode 450/2000, Total Reward: 194.0
# Episode 451/2000, Total Reward: 192.0
# Episode 452/2000, Total Reward: 134.0
# Episode 453/2000, Total Reward: 133.0
# Episode 454/2000, Total Reward: 91.0
# Episode 455/2000, Total Reward: 124.0
# Episode 456/2000, Total Reward: 123.0
# Episode 457/2000, Total Reward: 112.0
# Episode 458/2000, Total Reward: 30.0
# Episode 459/2000, Total Reward: 38.0
# Episode 460/2000, Total Reward: 43.0
# Episode 461/2000, Total Reward: 105.0
# Episode 462/2000, Total Reward: 118.0
# Episode 463/2000, Total Reward: 99.0
# Episode 464/2000, Total Reward: 61.0
# Episode 465/2000, Total Reward: 49.0
# Episode 466/2000, Total Reward: 95.0
# Episode 467/2000, Total Reward: 43.0
# Episode 468/2000, Total Reward: 37.0
# Episode 469/2000, Total Reward: 85.0
# Episode 470/2000, Total Reward: 19.0
# Episode 471/2000, Total Reward: 115.0
# Episode 472/2000, Total Reward: 25.0
# Episode 473/2000, Total Reward: 45.0
# Episode 474/2000, Total Reward: 42.0
# Episode 475/2000, Total Reward: 119.0
# Episode 476/2000, Total Reward: 23.0
# Episode 477/2000, Total Reward: 124.0
# Episode 478/2000, Total Reward: 36.0
# Episode 479/2000, Total Reward: 115.0
# Episode 480/2000, Total Reward: 21.0
# Episode 481/2000, Total Reward: 136.0
# Episode 482/2000, Total Reward: 123.0
# Episode 483/2000, Total Reward: 23.0
# Episode 484/2000, Total Reward: 62.0
# Episode 485/2000, Total Reward: 117.0
# Episode 486/2000, Total Reward: 117.0
# Episode 487/2000, Total Reward: 28.0
# Episode 488/2000, Total Reward: 132.0
# Episode 489/2000, Total Reward: 54.0
# Episode 490/2000, Total Reward: 46.0
# Episode 491/2000, Total Reward: 146.0
# Episode 492/2000, Total Reward: 129.0
# Episode 493/2000, Total Reward: 30.0
# Episode 494/2000, Total Reward: 151.0
# Episode 495/2000, Total Reward: 71.0
# Episode 496/2000, Total Reward: 96.0
# Episode 497/2000, Total Reward: 134.0
# Episode 498/2000, Total Reward: 169.0
# Episode 499/2000, Total Reward: 156.0
# Episode 500/2000, Total Reward: 176.0
# Episode 501/2000, Total Reward: 135.0
# Episode 502/2000, Total Reward: 118.0
# Episode 503/2000, Total Reward: 193.0
# Episode 504/2000, Total Reward: 125.0
# Episode 505/2000, Total Reward: 186.0
# Episode 506/2000, Total Reward: 181.0
# Episode 507/2000, Total Reward: 160.0
# Episode 508/2000, Total Reward: 184.0
# Episode 509/2000, Total Reward: 146.0
# Episode 510/2000, Total Reward: 182.0
# Episode 511/2000, Total Reward: 31.0
# Episode 512/2000, Total Reward: 178.0
# Episode 513/2000, Total Reward: 173.0
# Episode 514/2000, Total Reward: 190.0
# Episode 515/2000, Total Reward: 160.0
# Episode 516/2000, Total Reward: 141.0
# Episode 517/2000, Total Reward: 129.0
# Episode 518/2000, Total Reward: 157.0
# Episode 519/2000, Total Reward: 228.0
# Episode 520/2000, Total Reward: 146.0
# Episode 521/2000, Total Reward: 167.0
# Episode 522/2000, Total Reward: 218.0
# Episode 523/2000, Total Reward: 162.0
# Episode 524/2000, Total Reward: 145.0
# Episode 525/2000, Total Reward: 179.0
# Episode 526/2000, Total Reward: 148.0
# Episode 527/2000, Total Reward: 185.0
# Episode 528/2000, Total Reward: 140.0
# Episode 529/2000, Total Reward: 47.0
# Episode 530/2000, Total Reward: 228.0
# Episode 531/2000, Total Reward: 198.0
# Episode 532/2000, Total Reward: 198.0
# Episode 533/2000, Total Reward: 188.0
# Episode 534/2000, Total Reward: 196.0
# Episode 535/2000, Total Reward: 167.0
# Episode 536/2000, Total Reward: 191.0
# Episode 537/2000, Total Reward: 212.0
# Episode 538/2000, Total Reward: 231.0
# Episode 539/2000, Total Reward: 186.0
# Episode 540/2000, Total Reward: 413.0
# Episode 541/2000, Total Reward: 295.0
# Episode 542/2000, Total Reward: 196.0
# Episode 543/2000, Total Reward: 274.0
# Episode 544/2000, Total Reward: 357.0
# Episode 545/2000, Total Reward: 218.0
# Episode 546/2000, Total Reward: 251.0
# Episode 547/2000, Total Reward: 269.0
# Episode 548/2000, Total Reward: 268.0
# Episode 549/2000, Total Reward: 150.0
# Episode 550/2000, Total Reward: 209.0
# Episode 551/2000, Total Reward: 237.0
# Episode 552/2000, Total Reward: 292.0
# Episode 553/2000, Total Reward: 167.0
# Episode 554/2000, Total Reward: 178.0
# Episode 555/2000, Total Reward: 142.0
# Episode 556/2000, Total Reward: 148.0
# Episode 557/2000, Total Reward: 152.0
# Episode 558/2000, Total Reward: 186.0
# Episode 559/2000, Total Reward: 141.0
# Episode 560/2000, Total Reward: 152.0
# Episode 561/2000, Total Reward: 103.0
# Episode 562/2000, Total Reward: 137.0
# Episode 563/2000, Total Reward: 118.0
# Episode 564/2000, Total Reward: 197.0
# Episode 565/2000, Total Reward: 136.0
# Episode 566/2000, Total Reward: 159.0
# Episode 567/2000, Total Reward: 159.0
# Episode 568/2000, Total Reward: 137.0
# Episode 569/2000, Total Reward: 196.0
# Episode 570/2000, Total Reward: 153.0
# Episode 571/2000, Total Reward: 172.0
# Episode 572/2000, Total Reward: 157.0
# Episode 573/2000, Total Reward: 170.0
# Episode 574/2000, Total Reward: 158.0
# Episode 575/2000, Total Reward: 189.0
# Episode 576/2000, Total Reward: 144.0
# Episode 577/2000, Total Reward: 247.0
# Episode 578/2000, Total Reward: 174.0
# Episode 579/2000, Total Reward: 170.0
# Episode 580/2000, Total Reward: 281.0
# Episode 581/2000, Total Reward: 213.0
# Episode 582/2000, Total Reward: 149.0
# Episode 583/2000, Total Reward: 219.0
# Episode 584/2000, Total Reward: 187.0
# Episode 585/2000, Total Reward: 153.0
# Episode 586/2000, Total Reward: 232.0
# Episode 587/2000, Total Reward: 343.0
# Episode 588/2000, Total Reward: 293.0
# Episode 589/2000, Total Reward: 245.0
# Episode 590/2000, Total Reward: 516.0
# Episode 591/2000, Total Reward: 728.0
# Episode 592/2000, Total Reward: 1744.0
# Episode 593/2000, Total Reward: 354.0
# Episode 594/2000, Total Reward: 249.0
# Episode 595/2000, Total Reward: 322.0
# Episode 596/2000, Total Reward: 434.0
# Episode 597/2000, Total Reward: 220.0
# Episode 598/2000, Total Reward: 256.0
# Episode 599/2000, Total Reward: 286.0
# Episode 600/2000, Total Reward: 200.0
# Episode 601/2000, Total Reward: 196.0
# Episode 602/2000, Total Reward: 167.0
# Episode 603/2000, Total Reward: 203.0
# Episode 604/2000, Total Reward: 223.0
# Episode 605/2000, Total Reward: 190.0
# Episode 606/2000, Total Reward: 207.0
# Episode 607/2000, Total Reward: 190.0
# Episode 608/2000, Total Reward: 265.0
# Episode 609/2000, Total Reward: 232.0
# Episode 610/2000, Total Reward: 153.0
# Episode 611/2000, Total Reward: 199.0
# Episode 612/2000, Total Reward: 308.0
# Episode 613/2000, Total Reward: 254.0
# Episode 614/2000, Total Reward: 157.0
# Episode 615/2000, Total Reward: 194.0
# Episode 616/2000, Total Reward: 231.0
# Episode 617/2000, Total Reward: 175.0
# Episode 618/2000, Total Reward: 247.0
# Episode 619/2000, Total Reward: 201.0
# Episode 620/2000, Total Reward: 241.0
# Episode 621/2000, Total Reward: 254.0
# Episode 622/2000, Total Reward: 293.0
# Episode 623/2000, Total Reward: 183.0
# Episode 624/2000, Total Reward: 233.0
# Episode 625/2000, Total Reward: 252.0
# Episode 626/2000, Total Reward: 212.0
# Episode 627/2000, Total Reward: 269.0
# Episode 628/2000, Total Reward: 236.0
# Episode 629/2000, Total Reward: 318.0
# Episode 630/2000, Total Reward: 275.0
# Episode 631/2000, Total Reward: 405.0
# Episode 632/2000, Total Reward: 319.0
# Episode 633/2000, Total Reward: 214.0
# Episode 634/2000, Total Reward: 242.0
# Episode 635/2000, Total Reward: 495.0
# Episode 636/2000, Total Reward: 258.0
# Episode 637/2000, Total Reward: 286.0
# Episode 638/2000, Total Reward: 355.0
# Episode 639/2000, Total Reward: 823.0
# Episode 640/2000, Total Reward: 515.0
# Episode 641/2000, Total Reward: 1044.0
# Episode 642/2000, Total Reward: 300.0
# Episode 643/2000, Total Reward: 189.0
# Episode 644/2000, Total Reward: 389.0
# Episode 645/2000, Total Reward: 1347.0
# Episode 646/2000, Total Reward: 274.0
# Episode 647/2000, Total Reward: 225.0
# Episode 648/2000, Total Reward: 332.0
# Episode 649/2000, Total Reward: 222.0
# Episode 650/2000, Total Reward: 411.0
# Episode 651/2000, Total Reward: 371.0
# Episode 652/2000, Total Reward: 433.0
# Episode 653/2000, Total Reward: 307.0
# Episode 654/2000, Total Reward: 293.0
# Episode 655/2000, Total Reward: 410.0
# Episode 656/2000, Total Reward: 296.0
# Episode 657/2000, Total Reward: 343.0
# Episode 658/2000, Total Reward: 410.0
# Episode 659/2000, Total Reward: 463.0
# Episode 660/2000, Total Reward: 217.0
# Episode 661/2000, Total Reward: 250.0
# Episode 662/2000, Total Reward: 350.0
# Episode 663/2000, Total Reward: 279.0
# Episode 664/2000, Total Reward: 250.0
# Episode 665/2000, Total Reward: 386.0
# Episode 666/2000, Total Reward: 281.0
# Episode 667/2000, Total Reward: 282.0
# Episode 668/2000, Total Reward: 429.0
# Episode 669/2000, Total Reward: 269.0
# Episode 670/2000, Total Reward: 235.0
# Episode 671/2000, Total Reward: 398.0
# Episode 672/2000, Total Reward: 237.0
# Episode 673/2000, Total Reward: 490.0
# Episode 674/2000, Total Reward: 289.0
# Episode 675/2000, Total Reward: 347.0
# Episode 676/2000, Total Reward: 524.0
# Episode 677/2000, Total Reward: 268.0
# Episode 678/2000, Total Reward: 277.0
# Episode 679/2000, Total Reward: 245.0
# Episode 680/2000, Total Reward: 310.0
# Episode 681/2000, Total Reward: 495.0
# Episode 682/2000, Total Reward: 295.0
# Episode 683/2000, Total Reward: 256.0
# Episode 684/2000, Total Reward: 489.0
# Episode 685/2000, Total Reward: 277.0
# Episode 686/2000, Total Reward: 324.0
# Episode 687/2000, Total Reward: 448.0
# Episode 688/2000, Total Reward: 391.0
# Episode 689/2000, Total Reward: 333.0
# Episode 690/2000, Total Reward: 223.0
# Episode 691/2000, Total Reward: 374.0
# Episode 692/2000, Total Reward: 447.0
# Episode 693/2000, Total Reward: 563.0
# Episode 694/2000, Total Reward: 221.0
# Episode 695/2000, Total Reward: 519.0
# Episode 696/2000, Total Reward: 311.0
# Episode 697/2000, Total Reward: 502.0
# Episode 698/2000, Total Reward: 413.0
# Episode 699/2000, Total Reward: 254.0
# Episode 700/2000, Total Reward: 381.0
# Episode 701/2000, Total Reward: 289.0
# Episode 702/2000, Total Reward: 340.0
# Episode 703/2000, Total Reward: 361.0
# Episode 704/2000, Total Reward: 268.0
# Episode 705/2000, Total Reward: 235.0
# Episode 706/2000, Total Reward: 193.0
# Episode 707/2000, Total Reward: 219.0
# Episode 708/2000, Total Reward: 230.0
# Episode 709/2000, Total Reward: 382.0
# Episode 710/2000, Total Reward: 182.0
# Episode 711/2000, Total Reward: 338.0
# Episode 712/2000, Total Reward: 205.0
# Episode 713/2000, Total Reward: 315.0
# Episode 714/2000, Total Reward: 205.0
# Episode 715/2000, Total Reward: 288.0
# Episode 716/2000, Total Reward: 301.0
# Episode 717/2000, Total Reward: 263.0
# Episode 718/2000, Total Reward: 264.0
# Episode 719/2000, Total Reward: 221.0
# Episode 720/2000, Total Reward: 515.0
# Episode 721/2000, Total Reward: 237.0
# Episode 722/2000, Total Reward: 240.0
# Episode 723/2000, Total Reward: 282.0
# Episode 724/2000, Total Reward: 517.0
# Episode 725/2000, Total Reward: 896.0
# Episode 726/2000, Total Reward: 361.0
# Episode 727/2000, Total Reward: 380.0
# Episode 728/2000, Total Reward: 441.0
# Episode 729/2000, Total Reward: 365.0
# Episode 730/2000, Total Reward: 956.0
# Episode 731/2000, Total Reward: 975.0
# Episode 732/2000, Total Reward: 2930.0
# Episode 733/2000, Total Reward: 1993.0
# Episode 734/2000, Total Reward: 1172.0
# Episode 735/2000, Total Reward: 294.0
# Episode 736/2000, Total Reward: 1106.0
# Episode 737/2000, Total Reward: 481.0
# Episode 738/2000, Total Reward: 353.0
# Episode 739/2000, Total Reward: 612.0
# Episode 740/2000, Total Reward: 483.0
# Episode 741/2000, Total Reward: 248.0
# Episode 742/2000, Total Reward: 248.0
# Episode 743/2000, Total Reward: 722.0
# Episode 744/2000, Total Reward: 295.0
# Episode 745/2000, Total Reward: 259.0
# Episode 746/2000, Total Reward: 186.0
# Episode 747/2000, Total Reward: 173.0
# Episode 748/2000, Total Reward: 274.0
# Episode 749/2000, Total Reward: 224.0
# Episode 750/2000, Total Reward: 229.0
# Episode 751/2000, Total Reward: 197.0
# Episode 752/2000, Total Reward: 213.0
# Episode 753/2000, Total Reward: 262.0
# Episode 754/2000, Total Reward: 210.0
# Episode 755/2000, Total Reward: 196.0
# Episode 756/2000, Total Reward: 248.0
# Episode 757/2000, Total Reward: 240.0
# Episode 758/2000, Total Reward: 241.0
# Episode 759/2000, Total Reward: 238.0
# Episode 760/2000, Total Reward: 226.0
# Episode 761/2000, Total Reward: 381.0
# Episode 762/2000, Total Reward: 269.0
# Episode 763/2000, Total Reward: 212.0
# Episode 764/2000, Total Reward: 364.0
# Episode 765/2000, Total Reward: 600.0
# Episode 766/2000, Total Reward: 416.0
# Episode 767/2000, Total Reward: 496.0
# Episode 768/2000, Total Reward: 835.0
# Episode 769/2000, Total Reward: 278.0
# Episode 770/2000, Total Reward: 777.0
# Episode 771/2000, Total Reward: 345.0
# Episode 772/2000, Total Reward: 666.0
# Episode 773/2000, Total Reward: 683.0
# Episode 774/2000, Total Reward: 230.0
# Episode 775/2000, Total Reward: 1467.0
# Episode 776/2000, Total Reward: 1378.0
# Episode 777/2000, Total Reward: 666.0
# Episode 778/2000, Total Reward: 949.0
# Episode 779/2000, Total Reward: 472.0
# Episode 780/2000, Total Reward: 451.0
# Episode 781/2000, Total Reward: 1155.0
# Episode 782/2000, Total Reward: 773.0
# Episode 783/2000, Total Reward: 1490.0
# Solved in 783 episodes!

# %%
# test the trained policy
print("Testing the policy...")
test_avg_reward = test_policy(env, policy_network, episodes=100)
print(f"Average Test Reward: {test_avg_reward}")
# Out:
# Testing the policy...
# Test Episode 1, Total Reward: 10000.0
# Test Episode 2, Total Reward: 10000.0
# Test Episode 3, Total Reward: 10000.0
# Test Episode 4, Total Reward: 10000.0
# Test Episode 5, Total Reward: 10000.0
# Test Episode 6, Total Reward: 10000.0
# Test Episode 7, Total Reward: 10000.0
# Test Episode 8, Total Reward: 10000.0
# Test Episode 9, Total Reward: 10000.0
# Test Episode 10, Total Reward: 10000.0
# Test Episode 11, Total Reward: 10000.0
# Test Episode 12, Total Reward: 10000.0
# Test Episode 13, Total Reward: 1056.0
# Test Episode 14, Total Reward: 10000.0
# Test Episode 15, Total Reward: 10000.0
# Test Episode 16, Total Reward: 10000.0
# Test Episode 17, Total Reward: 10000.0
# Test Episode 18, Total Reward: 10000.0
# Test Episode 19, Total Reward: 10000.0
# Test Episode 20, Total Reward: 10000.0
# Test Episode 21, Total Reward: 10000.0
# Test Episode 22, Total Reward: 1426.0
# Test Episode 23, Total Reward: 10000.0
# Test Episode 24, Total Reward: 10000.0
# Test Episode 25, Total Reward: 10000.0
# Test Episode 26, Total Reward: 10000.0
# Test Episode 27, Total Reward: 10000.0
# Test Episode 28, Total Reward: 10000.0
# Test Episode 29, Total Reward: 10000.0
# Test Episode 30, Total Reward: 10000.0
# Test Episode 31, Total Reward: 10000.0
# Test Episode 32, Total Reward: 10000.0
# Test Episode 33, Total Reward: 10000.0
# Test Episode 34, Total Reward: 10000.0
# Test Episode 35, Total Reward: 10000.0
# Test Episode 36, Total Reward: 10000.0
# Test Episode 37, Total Reward: 10000.0
# Test Episode 38, Total Reward: 10000.0
# Test Episode 39, Total Reward: 10000.0
# Test Episode 40, Total Reward: 10000.0
# Test Episode 41, Total Reward: 10000.0
# Test Episode 42, Total Reward: 541.0
# Test Episode 43, Total Reward: 10000.0
# Test Episode 44, Total Reward: 10000.0
# Test Episode 45, Total Reward: 10000.0
# Test Episode 46, Total Reward: 10000.0
# Test Episode 47, Total Reward: 10000.0
# Test Episode 48, Total Reward: 10000.0
# Test Episode 49, Total Reward: 10000.0
# Test Episode 50, Total Reward: 10000.0
# Test Episode 51, Total Reward: 10000.0
# Test Episode 52, Total Reward: 10000.0
# Test Episode 53, Total Reward: 10000.0
# Test Episode 54, Total Reward: 10000.0
# Test Episode 55, Total Reward: 555.0
# Test Episode 56, Total Reward: 10000.0
# Test Episode 57, Total Reward: 10000.0
# Test Episode 58, Total Reward: 10000.0
# Test Episode 59, Total Reward: 10000.0
# Test Episode 60, Total Reward: 10000.0
# Test Episode 61, Total Reward: 10000.0
# Test Episode 62, Total Reward: 10000.0
# Test Episode 63, Total Reward: 10000.0
# Test Episode 64, Total Reward: 10000.0
# Test Episode 65, Total Reward: 10000.0
# Test Episode 66, Total Reward: 10000.0
# Test Episode 67, Total Reward: 1522.0
# Test Episode 68, Total Reward: 10000.0
# Test Episode 69, Total Reward: 10000.0
# Test Episode 70, Total Reward: 10000.0
# Test Episode 71, Total Reward: 10000.0
# Test Episode 72, Total Reward: 10000.0
# Test Episode 73, Total Reward: 10000.0
# Test Episode 74, Total Reward: 10000.0
# Test Episode 75, Total Reward: 10000.0
# Test Episode 76, Total Reward: 579.0
# Test Episode 77, Total Reward: 10000.0
# Test Episode 78, Total Reward: 10000.0
# Test Episode 79, Total Reward: 10000.0
# Test Episode 80, Total Reward: 10000.0
# Test Episode 81, Total Reward: 10000.0
# Test Episode 82, Total Reward: 10000.0
# Test Episode 83, Total Reward: 1672.0
# Test Episode 84, Total Reward: 522.0
# Test Episode 85, Total Reward: 10000.0
# Test Episode 86, Total Reward: 10000.0
# Test Episode 87, Total Reward: 10000.0
# Test Episode 88, Total Reward: 10000.0
# Test Episode 89, Total Reward: 10000.0
# Test Episode 90, Total Reward: 10000.0
# Test Episode 91, Total Reward: 10000.0
# Test Episode 92, Total Reward: 10000.0
# Test Episode 93, Total Reward: 10000.0
# Test Episode 94, Total Reward: 10000.0
# Test Episode 95, Total Reward: 1052.0
# Test Episode 96, Total Reward: 10000.0
# Test Episode 97, Total Reward: 10000.0
# Test Episode 98, Total Reward: 10000.0
# Test Episode 99, Total Reward: 10000.0
# Test Episode 100, Total Reward: 10000.0
# Average Test Reward: 9189.25

# %%
# save the policy
torch.save(policy_network.state_dict(), 'reinforce_policy.pth')
